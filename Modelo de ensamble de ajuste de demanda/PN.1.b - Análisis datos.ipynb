# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_excel("prediccion/Comparando prediccion c-TPOP.xls")
df.head()
# Out:
#          Fecha  PedidosReales  TotalesPred     predicc
# 718 2017-12-22            135          142  140.447740
# 719 2017-12-23             96          141  132.425907
# 720 2017-12-26             93           92   73.177350
# 721 2017-12-27             91          112   86.568579
# 722 2017-12-28            110          129   95.142657

# %%
ErrorOrigMed = df["TotalesPred"].mean()
ErrorPredMed = df["predicc"].mean()

print("Error: Original {:0.2f} vs Nuevo {:0.2f}".format(ErrorOrigMed,ErrorPredMed))
# Out:
# Error: Original 111.70 vs Nuevo 101.12

# %%
df.set_index("Fecha", inplace=True)

# %%
# Set up the matplotlib figure
df[["PedidosReales","TotalesPred"]].plot(figsize=(20,10))
plt.show()

# %%
df[["PedidosReales","predicc"]].plot(figsize=(20,10))
plt.show()

# %%
df[["PedidosReales","TotalesPred","predicc"]].plot(figsize=(20,10))
plt.show()

# %%
df[["PedidosReales","predicc"]].head(21)
# Out:
#             PedidosReales     predicc
# Fecha
# 2017-12-22            135  140.447740
# 2017-12-23             96  132.425907
# 2017-12-26             93   73.177350
# 2017-12-27             91   86.568579
# 2017-12-28            110   95.142657
# 2017-12-29            119  142.146901
# 2017-12-30            109  142.255236
# 2017-12-31            112  127.865276
# 2018-01-01            156   88.343185
# 2018-01-02             92   87.487675
# 2018-01-03             81   88.396117
# 2018-01-04             94   95.329463
# 2018-01-05            132  134.890457
# 2018-01-06            136  132.787424
# 2018-01-07            137  135.055407
# 2018-01-08             91   85.852677
# 2018-01-09             74   86.539804
# 2018-01-10             97   86.874840
# 2018-01-11            125   96.698016
# 2018-01-12            140  135.184146
# 2018-01-13            129  131.871078
