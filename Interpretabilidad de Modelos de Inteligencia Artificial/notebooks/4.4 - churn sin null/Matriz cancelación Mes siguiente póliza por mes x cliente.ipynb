# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table("../../data/raw/TB_BAJAS_CL.tsv", encoding="latin-1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99025 entries, 0 to 99024
# Data columns (total 3 columns):
# POLICY_NUMBER          99025 non-null int64
# CANCELLATION_DATE      99025 non-null object
# CANCELLATION_REASON    16917 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    POLICY_NUMBER CANCELLATION_DATE CANCELLATION_REASON
# 0  1436751829999        31/08/2015                 NaN
# 1  1378134259999        28/02/2015                 NaN
# 2   278935929999        29/02/2004                 NaN
# 3  1256190669999        31/03/2014                 NaN
# 4  1345439839999        30/11/2014                 NaN

# %%
df_poliza = pd.read_table("../../data/raw/TB_POLIZAS_CL.tsv", encoding="latin-1")
df_poliza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4070858 entries, 0 to 4070857
# Data columns (total 20 columns):
# PROCESS_DATE            object
# CUSTOMER_ID             int64
# POLICY_ORIGINAL         float64
# POLICY_NUMBER           int64
# DATE_ISSUE              object
# DATE_COMMENCENT_RISK    object
# SUM_ASSURED             float64
# PREMIUM                 object
# PAYMENT_FREQUENCY       object
# COD_VEH_MAKE            int64
# VEH_MAKE                object
# VEH_MODEL               object
# VEH_YEAR                int64
# CHANEL_ID               int64
# CHANNEL                 object
# NAME_OF_PRODUCT         object
# TYPE_PRODUCT            object
# COVERAGE_DETAILS        object
# AGENT_ID                float64
# SUB_AGENT_ID            float64
# dtypes: float64(4), int64(5), object(11)
# memory usage: 621.2+ MB

# %%
df_can_pol = df.merge(df_poliza[["POLICY_NUMBER", "CUSTOMER_ID"]], how="inner", left_on=["POLICY_NUMBER"], 
                             right_on=["POLICY_NUMBER"], suffixes=['', '_poliza'])
df_can_pol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116564 entries, 0 to 116563
# Data columns (total 4 columns):
# POLICY_NUMBER          116564 non-null int64
# CANCELLATION_DATE      116564 non-null object
# CANCELLATION_REASON    20056 non-null object
# CUSTOMER_ID            116564 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 4.4+ MB

# %%
df_can_pol[df_can_pol.duplicated()].sort_values(by="POLICY_NUMBER")
# Out:
#         POLICY_NUMBER CANCELLATION_DATE CANCELLATION_REASON  CUSTOMER_ID
# 70341     77320269999        31/08/2004                 NaN      5519768
# 70342     77320269999        31/08/2004                 NaN      5519768
# 70343     77320269999        31/08/2004                 NaN      5519768
# 70344     77320269999        31/08/2004                 NaN      5519768
# 70340     77320269999        31/08/2004                 NaN      5519768
# 2916      79741709999        30/09/2004                 NaN      1406154
# 2921      79741709999        30/09/2004                 NaN      1406154
# 2920      79741709999        30/09/2004                 NaN      1406154
# 2919      79741709999        30/09/2004                 NaN      1406154
# 2917      79741709999        30/09/2004                 NaN      1406154
# 2918      79741709999        30/09/2004                 NaN      1406154
# 56990     86520099999        30/11/2004                 NaN      3191732
# 56991     86520099999        30/11/2004                 NaN      3191732
# 56992     86520099999        30/11/2004                 NaN      3191732
# 56993     86520099999        30/11/2004                 NaN      3191732
# 56994     86520099999        30/11/2004                 NaN      3191732
# 56995     86520099999        30/11/2004                 NaN      3191732
# 56996     86520099999        30/11/2004                 NaN      3191732
# 56989     86520099999        30/11/2004                 NaN      3191732
# 2926      92068329999        31/01/2005                 NaN      1406154
# 2924      92068329999        31/01/2005                 NaN      1406154
# 2925      92068329999        31/01/2005                 NaN      1406154
# 2927      92068329999        31/01/2005                 NaN      1406154
# 2931      92068329999        31/01/2005                 NaN      1406154
# 2929      92068329999        31/01/2005                 NaN      1406154
# 2930      92068329999        31/01/2005                 NaN      1406154
# 2932      92068329999        31/01/2005                 NaN      1406154
# 2933      92068329999        31/01/2005                 NaN      1406154
# 2928      92068329999        31/01/2005                 NaN      1406154
# 17973    100004239999        30/06/2004                 NaN      5926562
# ...               ...               ...                 ...          ...
# 102526  1705350469999        30/11/2017                 NaN     20461966
# 38206   1705437859999        30/11/2017               Venta     11197789
# 114601  1708806749999        31/12/2017                 NaN      8435706
# 114602  1708806749999        31/12/2017                 NaN      8435706
# 48090   1710155189999        31/12/2017                 NaN     20914807
# 48089   1710155189999        31/12/2017                 NaN     20914807
# 7911    1712101239999        30/11/2017                 NaN     20618770
# 35608   1712104069999        31/12/2017                 NaN     13949635
# 110654  1712119969999        31/12/2017                 NaN     20623221
# 110655  1712119969999        31/12/2017                 NaN     20623221
# 9169    1712125459999        30/11/2017                 NaN      1469553
# 35354   1712542649999        31/12/2017               Venta     15193838
# 36293   1712618719999        31/12/2017                 NaN     21044047
# 5387    1712649569999        31/12/2017                 NaN      8701736
# 67328   1712650639999        31/12/2017                 NaN     20927239
# 67329   1712650639999        31/12/2017                 NaN     20927239
# 24934   1712656029999        31/12/2017                 NaN      8708677
# 74814   1712716349999        30/11/2017                 NaN     19251302
# 113141  1713054659999        31/12/2017                 NaN     14036787
# 46862   1714253739999        31/12/2017                 NaN     20932423
# 46863   1714253739999        31/12/2017                 NaN     20932423
# 15920   1714692899999        31/12/2017                 NaN      8742935
# 14121   1715674279999        31/12/2017                 NaN     14011236
# 11234   1715861199999        31/12/2017                 NaN     14810353
# 30144   1715861369999        31/12/2017                 NaN     20503246
# 8294    1715878959999        31/12/2017                 NaN     19425605
# 87557   1716164639999        31/12/2017                 NaN     20504799
# 46683   1723556239999        31/12/2017                 NaN     20486541
# 14889   1727298219999        30/11/2017                 NaN      8612037
# 40403   1732418789999        31/12/2017                 NaN     10960362
#
# [17768 rows x 4 columns]

# %%
bd = df_can_pol.drop_duplicates()
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98796 entries, 0 to 116563
# Data columns (total 4 columns):
# POLICY_NUMBER          98796 non-null int64
# CANCELLATION_DATE      98796 non-null object
# CANCELLATION_REASON    16917 non-null object
# CUSTOMER_ID            98796 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 3.8+ MB

# %%
#convierto el due_date en fecha, para luego obtener el siguiente mes (correspondiente al servicio)
from datetime import datetime, timedelta
bd["fecha"] = bd.apply(lambda x : datetime.strptime(x.CANCELLATION_DATE, "%d/%m/%Y"), axis=1)
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98796 entries, 0 to 116563
# Data columns (total 5 columns):
# POLICY_NUMBER          98796 non-null int64
# CANCELLATION_DATE      98796 non-null object
# CANCELLATION_REASON    16917 non-null object
# CUSTOMER_ID            98796 non-null int64
# fecha                  98796 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 4.5+ MB
# /home/seba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
bd.head()
# Out:
#    POLICY_NUMBER CANCELLATION_DATE CANCELLATION_REASON  CUSTOMER_ID      fecha
# 0  1436751829999        31/08/2015                 NaN      6131994 2015-08-31
# 1  1378134259999        28/02/2015                 NaN      3144725 2015-02-28
# 2  1256190669999        31/03/2014                 NaN     11752620 2014-03-31
# 3  1345439839999        30/11/2014                 NaN      3165817 2014-11-30
# 4   711055139999        31/05/2009                 NaN     13146367 2009-05-31

# %%
bd["mes"] = bd.fecha.apply(lambda x : x if pd.isnull(x) else int(x.month) )
bd["anio"] = bd.fecha.apply(lambda x : x if pd.isnull(x) else int(x.year) )
bd["corresp_date"] = bd.fecha.apply(lambda x : x if pd.isnull(x) else "{}-{:02}".format(x.year, x.month) )
bd.info()
# Out:
# /home/seba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/seba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98796 entries, 0 to 116563
# Data columns (total 8 columns):
# POLICY_NUMBER          98796 non-null int64
# CANCELLATION_DATE      98796 non-null object
# CANCELLATION_REASON    16917 non-null object
# CUSTOMER_ID            98796 non-null int64
# fecha                  98796 non-null datetime64[ns]
# mes                    98796 non-null int64
# anio                   98796 non-null int64
# corresp_date           98796 non-null object
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 6.8+ MB
# /home/seba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_poliza[df_poliza["POLICY_NUMBER"] == 1436751829999]
# Out:
#         PROCESS_DATE  CUSTOMER_ID  POLICY_ORIGINAL  POLICY_NUMBER  DATE_ISSUE  \
# 3455191   31/07/2015      6131994     8.070117e+12  1436751829999  27/06/2015
#
#         DATE_COMMENCENT_RISK  SUM_ASSURED PREMIUM PAYMENT_FREQUENCY  \
# 3455191           19/09/2000      27300.0  437,20           MENSUAL
#
#          COD_VEH_MAKE VEH_MAKE VEH_MODEL  VEH_YEAR  CHANEL_ID CHANNEL  \
# 3455191          6614     FORD    SIERRA      1989          0     Aca
#
#         NAME_OF_PRODUCT                                       TYPE_PRODUCT  \
# 3455191            AUTO  RC, ROBO E INCENDIO PARCIAL Y TOTAL Y DESTRUCC...
#
#         COVERAGE_DETAILS  AGENT_ID  SUB_AGENT_ID
# 3455191    DISCONTINUADO       NaN           NaN

# %%
bd.sort_values(["anio", "mes"], inplace=True)
bd.head()
# Out:
# /home/seba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#       POLICY_NUMBER CANCELLATION_DATE CANCELLATION_REASON  CUSTOMER_ID  \
# 122    279811759999        31/03/2004                 NaN      1387814
# 717    257502869999        31/03/2004                 NaN      1782094
# 921    263038699999        31/03/2004                 NaN      1429159
# 1338   266126589999        31/03/2004                 NaN      8707059
# 1378   282654169999        31/03/2004                 NaN     10741277
#
#           fecha  mes  anio corresp_date
# 122  2004-03-31    3  2004      2004-03
# 717  2004-03-31    3  2004      2004-03
# 921  2004-03-31    3  2004      2004-03
# 1338 2004-03-31    3  2004      2004-03
# 1378 2004-03-31    3  2004      2004-03

# %%
#ver las razones de cancelación
bd.CANCELLATION_REASON.value_counts().index[3]
# Out:
# 'VV - Vta. Vehículo - Ya Aseguro en LA CAJA'

# %%
columns = bd.corresp_date.unique()
row = bd.CUSTOMER_ID.unique()

# %% [markdown]
# # creando matriz cancelación mes x cliente

# %%
#creo el dataset vacio
df_m = pd.DataFrame(columns=columns)
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Columns: 166 entries, 2004-03 to 2017-12
# dtypes: object(166)
# memory usage: 0.0+ bytes

# %%
#agrupo por cliente y mes_anio y cuento cuantas polizas distintas tiene
groups = bd.groupby(["CUSTOMER_ID", "corresp_date"])["POLICY_NUMBER"].count()

# %%
groups
# Out:
# CUSTOMER_ID  corresp_date
# 1690         2005-09         1
#              2006-03         1
#              2007-06         1
#              2009-03         1
#              2010-01         1
#              2015-01         1
#              2015-07         1
# 5575         2012-01         1
#              2012-10         1
#              2015-08         1
#              2016-01         1
#              2017-09         2
# 7968         2011-12         1
# 9028         2013-02         1
#              2016-09         1
#              2016-10         1
# 9860         2009-09         1
#              2017-09         1
# 11820        2016-05         1
# 14923        2007-03         1
#              2010-07         1
#              2011-01         1
#              2011-04         1
#              2012-06         1
#              2014-01         1
#              2014-06         1
#              2014-07         1
#              2014-11         1
#              2014-12         1
#              2015-03         1
#                             ..
# 21079290     2016-12         1
#              2017-08         1
# 21079346     2016-02         1
# 21079537     2016-05         1
# 21079727     2017-04         1
#              2017-08         1
# 21080010     2016-10         1
# 21080534     2016-02         1
# 21080547     2016-03         1
#              2017-10         1
# 21080679     2017-06         1
# 21081698     2016-03         1
# 21081753     2016-08         1
# 21081997     2017-04         1
#              2017-10         1
# 21082644     2016-03         1
# 21082824     2016-06         1
# 21083403     2017-03         1
# 21083405     2017-03         1
#              2017-05         1
# 21092051     2016-03         1
# 21095329     2016-03         1
# 21095429     2016-04         1
# 21095480     2016-04         1
#              2016-12         1
# 21095944     2016-10         1
# 21096026     2017-08         1
# 21096066     2016-03         1
# 21096072     2016-03         1
# 21260067     2004-04         1
# Name: POLICY_NUMBER, Length: 96905, dtype: int64

# %%
for id_cliente in groups.index.levels[0]:
    df_m.loc[id_cliente] = groups[id_cliente].T

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41754 entries, 1690 to 21260067
# Columns: 166 entries, 2004-03 to 2017-12
# dtypes: float64(166)
# memory usage: 53.2 MB

# %%
df_m.head()
# Out:
#       2004-03  2004-04  2004-05  2004-06  2004-07  2004-08  2004-09  2004-10  \
# 1690      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5575      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 7968      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9028      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9860      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2004-11  2004-12   ...     2017-03  2017-04  2017-05  2017-06  2017-07  \
# 1690      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 5575      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 7968      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 9028      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 9860      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
#
#       2017-08  2017-09  2017-10  2017-11  2017-12
# 1690      NaN      NaN      NaN      NaN      NaN
# 5575      NaN      2.0      NaN      NaN      NaN
# 7968      NaN      NaN      NaN      NaN      NaN
# 9028      NaN      NaN      NaN      NaN      NaN
# 9860      NaN      1.0      NaN      NaN      NaN
#
# [5 rows x 166 columns]

# %%
df_m.to_csv("../../data/processed/BD_ID_CLIENTE_N.CANCELACIONES_X_MES.csv")

# %% [markdown]
# # Creando matriz cancelación segun motivo
#
# retomo de arriba (antes de la cabecera previa)

# %%
#Si la cancelación, no es negativa (es decir, va a volver a la empresa) => 0, sino 1
bd["MotivoN"] = 1
bd.loc[bd.CANCELLATION_REASON == "VV - Vta. Vehículo - Ya Aseguro en LA CAJA", "MotivoN"] = 0
# Out:
# /home/seba/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/seba/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
bd.head()
# Out:
#       POLICY_NUMBER CANCELLATION_DATE CANCELLATION_REASON  CUSTOMER_ID  \
# 122    279811759999        31/03/2004                 NaN      1387814
# 717    257502869999        31/03/2004                 NaN      1782094
# 921    263038699999        31/03/2004                 NaN      1429159
# 1338   266126589999        31/03/2004                 NaN      8707059
# 1378   282654169999        31/03/2004                 NaN     10741277
#
#           fecha  mes  anio corresp_date  MotivoN
# 122  2004-03-31    3  2004      2004-03        1
# 717  2004-03-31    3  2004      2004-03        1
# 921  2004-03-31    3  2004      2004-03        1
# 1338 2004-03-31    3  2004      2004-03        1
# 1378 2004-03-31    3  2004      2004-03        1

# %%
#creo el dataset vacio
df_m = pd.DataFrame(columns=columns)
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Columns: 166 entries, 2004-03 to 2017-12
# dtypes: object(166)
# memory usage: 0.0+ bytes

# %%
#agrupo por cliente y mes_anio y cuento cuantas polizas distintas tiene
groups = bd.groupby(["CUSTOMER_ID", "corresp_date"])["MotivoN"].sum()

# %%
for id_cliente in groups.index.levels[0]:
    df_m.loc[id_cliente] = groups[id_cliente].T

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41754 entries, 1690 to 21260067
# Columns: 166 entries, 2004-03 to 2017-12
# dtypes: float64(166)
# memory usage: 53.2 MB

# %%
df_m.head()
# Out:
#       2004-03  2004-04  2004-05  2004-06  2004-07  2004-08  2004-09  2004-10  \
# 1690      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5575      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 7968      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9028      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9860      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       2004-11  2004-12   ...     2017-03  2017-04  2017-05  2017-06  2017-07  \
# 1690      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 5575      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 7968      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 9028      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
# 9860      NaN      NaN   ...         NaN      NaN      NaN      NaN      NaN
#
#       2017-08  2017-09  2017-10  2017-11  2017-12
# 1690      NaN      NaN      NaN      NaN      NaN
# 5575      NaN      2.0      NaN      NaN      NaN
# 7968      NaN      NaN      NaN      NaN      NaN
# 9028      NaN      NaN      NaN      NaN      NaN
# 9860      NaN      1.0      NaN      NaN      NaN
#
# [5 rows x 166 columns]

# %%
df_m.to_csv("../../data/processed/BD_ID_CLIENTE_N.CANCELACIONES.negativas_X_MES.csv")
