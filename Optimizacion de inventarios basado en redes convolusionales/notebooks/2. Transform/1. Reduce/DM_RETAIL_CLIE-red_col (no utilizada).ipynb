# %%
import os

import pandas as pd

# %%
# display tables options
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %%
# creating the path
path = "../../../data/raw"
save_to_path = "../../../data/interim/1. col_red"
# file
filename = "DM_RETAIL_CLIE.csv"
filename_to_save = os.path.join(save_to_path, filename.split(".")[0]+"-red_col.feather")
filename_to_save
# Out:
# '../../../data/interim/1. col_red/DM_RETAIL_CLIE-red_col.feather'

# %%
# checking the path
file = os.path.join(path, filename)
if not(os.path.exists(file) and os.path.isfile(file)):
    raise Exception("File {} doesn't exists.".format(file))
else:
    print("ok")
# Out:
# ok

# %%
usecols = ['ACA', 'ANTIG_MESES', 'APTO_E_MAIL', 'CANAL', 'CANAL_ORIGEN', 'CIF_ID', 'COBERTURA_PLAN', 'COD_MARCA', 'COD_MOD', 'DESC_EQUIPO', 'ES_ELEGIBLE', 'FLAG_EBILLING', 'FLAG_ROBO_CONTENIDO', 'FOR_COBRO', 'GRUPO_COMBUSTIBLE', 'MARCA', 'MARCA_SIMPLIFICADA', 'MCA_0KM', 'MODELO', 'NEGOCIO', 'NUM_SECU_POL', 'ORIGEN_DESC', 'PERIODO_FACT', 'PREMIO', 'PRIMA', 'PRODUCTO_PLAN', 'PROVEEDOR_EQUIPO', 'SCORE_PLAN', 'SUMA_ASEG', 'VENC_PRENDA', 'ZONA_RETAIL', ]

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv(file, usecols=usecols)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798517 entries, 0 to 798516
# Data columns (total 31 columns):
# ACA                    798517 non-null object
# NUM_SECU_POL           798517 non-null int64
# FOR_COBRO              798517 non-null object
# COD_MOD                770270 non-null float64
# COD_MARCA              770270 non-null float64
# MCA_0KM                785862 non-null object
# MARCA                  770270 non-null object
# SUMA_ASEG              797157 non-null object
# PRIMA                  798517 non-null object
# PREMIO                 798517 non-null object
# CIF_ID                 798245 non-null float64
# PERIODO_FACT           798517 non-null int64
# CANAL                  794443 non-null object
# ZONA_RETAIL            794443 non-null object
# PRODUCTO_PLAN          770270 non-null object
# COBERTURA_PLAN         770270 non-null object
# ES_ELEGIBLE            798517 non-null object
# APTO_E_MAIL            798517 non-null object
# CANAL_ORIGEN           798517 non-null object
# ORIGEN_DESC            798514 non-null object
# PROVEEDOR_EQUIPO       175587 non-null float64
# DESC_EQUIPO            175587 non-null object
# MARCA_SIMPLIFICADA     770270 non-null object
# MODELO                 770270 non-null object
# GRUPO_COMBUSTIBLE      769789 non-null float64
# SCORE_PLAN             444930 non-null object
# FLAG_ROBO_CONTENIDO    798517 non-null object
# FLAG_EBILLING          798517 non-null object
# VENC_PRENDA            217393 non-null object
# ANTIG_MESES            798021 non-null float64
# NEGOCIO                791241 non-null object
# dtypes: float64(6), int64(2), object(23)
# memory usage: 188.9+ MB

# %%
df = df[df.columns.sort_values()]
df.head(3).append(df.tail())
# Out:
#        ACA  ANTIG_MESES APTO_E_MAIL             CANAL CANAL_ORIGEN  \
# 0        N         17.0           N  CANAL INDIRECTOS    INDIRECTO
# 1        N         29.0           S  CANAL INDIRECTOS    INDIRECTO
# 2        N         16.0           N  CANAL INDIRECTOS    INDIRECTO
# 798512   N         31.0           S  CANAL INDIRECTOS    INDIRECTO
# 798513   N         18.0           S  CANAL INDIRECTOS    INDIRECTO
# 798514   N         20.0           N  CANAL INDIRECTOS    INDIRECTO
# 798515   N          9.0           N  CANAL INDIRECTOS    INDIRECTO
# 798516   N         30.0           S  CANAL INDIRECTOS    INDIRECTO
#
#             CIF_ID COBERTURA_PLAN  COD_MARCA  COD_MOD DESC_EQUIPO ES_ELEGIBLE  \
# 0       22336385.0    Pack Ahorro    18386.0   2017.0         NaN           O
# 1        7835527.0    Pack Ahorro     2434.0   2009.0         NaN           M
# 2       22367166.0    Pack Ahorro    14176.0   2007.0         NaN           O
# 798512  21459602.0    Pack Comodo    12717.0   2016.0         NaN           O
# 798513  22301939.0    Pack Comodo    12718.0   2017.0         NaN           M
# 798514  22182150.0    Pack Comodo    12717.0   2017.0         NaN           M
# 798515  22759590.0    Pack Comodo    12771.0   2018.0         NaN           M
# 798516  20967682.0    Pack Comodo    12749.0   2016.0         NaN           A
#
#        FLAG_EBILLING FLAG_ROBO_CONTENIDO FOR_COBRO  GRUPO_COMBUSTIBLE  \
# 0                  N                   N        PP                2.0
# 1                  S                   N        PP                2.0
# 2                  N                   N        PP                1.0
# 798512             N                   N        PP                2.0
# 798513             N                   N        PP                2.0
# 798514             N                   N        PP                2.0
# 798515             N                   N        PP                2.0
# 798516             S                   N        PP                2.0
#
#                                  MARCA MARCA_SIMPLIFICADA MCA_0KM     MODELO  \
# 0       VOLKSWAGEN GOL TREND 1.6 5P L/         VOLKSWAGEN       N  GOL TREND
# 1       CITROEN C4 1.6/1.4 I X 5 PTAS.            CITROEN       N         C4
# 2       RENAULT MEGANE FAIRWAY 1.6 (TR            RENAULT       N     MEGANE
# 798512       PEUGEOT 208 ALLURE 1.6 5P            PEUGEOT       N        208
# 798513       PEUGEOT 208 FELINE 1.6 5P            PEUGEOT       N        208
# 798514       PEUGEOT 208 ALLURE 1.6 5P            PEUGEOT       N        208
# 798515     PEUGEOT 301 1.6 ALLURE PLUS            PEUGEOT       N        301
# 798516      PEUGEOT 308 1.6 THP FELINE            PEUGEOT       N        308
#
#        NEGOCIO   NUM_SECU_POL ORIGEN_DESC  PERIODO_FACT   PREMIO    PRIMA  \
# 0           PP  1894655649999       Banc.             6  5729,00  4610,00
# 1           PP  1894644699999       Banc.             6  5875,00  4712,00
# 2           PP  1894644719999       Banc.             6  5647,00  4528,00
# 798512    PRES  1958917859999       Term.             1  1463,00  1182,00
# 798513    PRES  1958917869999       Term.             1  5108,00  4097,00
# 798514    PRES  1958917969999       Term.             1  3479,00  2790,00
# 798515    PRES  1958917979999       Term.             1  4187,00  3358,00
# 798516    PRES  1958917989999       Term.             1  3166,00  3100,00
#
#        PRODUCTO_PLAN  PROVEEDOR_EQUIPO SCORE_PLAN  SUMA_ASEG VENC_PRENDA  \
# 0           Terceros               NaN        NaN  316200,00    2/1/2022
# 1           Terceros               NaN      MALTO  183600,00    2/1/2020
# 2           Terceros               NaN      MEDIO  147900,00    2/1/2021
# 798512      Terceros               NaN        NaN  390000,00    1/1/2010
# 798513            TR               NaN        NaN  490000,00    1/1/2010
# 798514      Terceros               NaN        NaN  425000,00    1/1/2010
# 798515            TR               NaN        NaN  782700,00    1/1/2010
# 798516            TR               NaN        NaN  487603,00    1/1/2010
#
#         ZONA_RETAIL
# 0       ZONA  OTRAS
# 1       ZONA  OTRAS
# 2       ZONA  OTRAS
# 798512  ZONA  OTRAS
# 798513  ZONA  OTRAS
# 798514  ZONA  OTRAS
# 798515  ZONA  OTRAS
# 798516  ZONA  OTRAS

# %%
idx = "COD_MOD"
df[idx].value_counts(dropna=False)
# Out:
# 2017.0    101346
# 2018.0     96413
# 2016.0     71287
# 2013.0     57079
# 2015.0     56265
# 2012.0     47658
# 2014.0     47045
# 2011.0     45830
# 2010.0     34389
# NaN        28247
# 2008.0     25964
# 2009.0     25030
# 2019.0     23726
# 2007.0     22961
# 2006.0     17455
# 2005.0     13954
# 2004.0      9208
# 1999.0      8278
# 2000.0      8036
# 1998.0      7876
# 1997.0      5812
# 2001.0      5459
# 1994.0      4329
# 1996.0      4321
# 1995.0      4224
# 2003.0      3976
# 1993.0      3142
# 2002.0      2950
# 1992.0      2261
# 1981.0      1260
# 1980.0      1121
# 1991.0       830
# 1989.0       724
# 1987.0       721
# 1988.0       692
# 1986.0       606
# 1990.0       568
# 1979.0       549
# 1985.0       497
# 1974.0       487
# 1984.0       475
# 1983.0       452
# 1982.0       449
# 1973.0       429
# 1971.0       401
# 1977.0       379
# 1972.0       359
# 1975.0       355
# 1978.0       351
# 1970.0       289
# 1969.0       261
# 1976.0       255
# 1966.0       177
# 1968.0       173
# 1967.0       164
# 1965.0       134
# 1964.0       126
# 1962.0       107
# 1958.0       106
# 1961.0        93
# 1960.0        82
# 1963.0        57
# 1957.0        48
# 1947.0        29
# 1956.0        26
# 1959.0        25
# 1946.0        24
# 1951.0        21
# 1955.0         8
# 1937.0         8
# 1931.0         7
# 1954.0         7
# 1938.0         7
# 1928.0         5
# 1930.0         5
# 1943.0         5
# 1942.0         5
# 1953.0         4
# 1939.0         4
# 1941.0         4
# 1945.0         4
# 1950.0         4
# 1929.0         3
# 1952.0         3
# 1940.0         2
# 1934.0         2
# 1948.0         2
# 1936.0         1
# 1933.0         1
# 1949.0         1
# 1927.0         1
# 1924.0         1
# Name: COD_MOD, dtype: int64

# %% [markdown]
# ### Feature Format

# %%
to_date = ['VENC_PRENDA', ]
date_format = "%d/%m/%Y"
# for is faster
# df.loc[:, to_date] = df.loc[:, to_date].apply(pd.to_datetime(format=date_format))

# %%
# %%time 
for col in to_date:
    df[col] = pd.to_datetime(df[col], format=date_format, errors="coerce")
# Out:
# CPU times: user 1.32 s, sys: 100 ms, total: 1.42 s
# Wall time: 805 ms

# %% [markdown]
# # saving into feather file

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798517 entries, 0 to 798516
# Data columns (total 31 columns):
# ACA                    798517 non-null object
# ANTIG_MESES            798021 non-null float64
# APTO_E_MAIL            798517 non-null object
# CANAL                  794443 non-null object
# CANAL_ORIGEN           798517 non-null object
# CIF_ID                 798245 non-null float64
# COBERTURA_PLAN         770270 non-null object
# COD_MARCA              770270 non-null float64
# COD_MOD                770270 non-null float64
# DESC_EQUIPO            175587 non-null object
# ES_ELEGIBLE            798517 non-null object
# FLAG_EBILLING          798517 non-null object
# FLAG_ROBO_CONTENIDO    798517 non-null object
# FOR_COBRO              798517 non-null object
# GRUPO_COMBUSTIBLE      769789 non-null float64
# MARCA                  770270 non-null object
# MARCA_SIMPLIFICADA     770270 non-null object
# MCA_0KM                785862 non-null object
# MODELO                 770270 non-null object
# NEGOCIO                791241 non-null object
# NUM_SECU_POL           798517 non-null int64
# ORIGEN_DESC            798514 non-null object
# PERIODO_FACT           798517 non-null int64
# PREMIO                 798517 non-null object
# PRIMA                  798517 non-null object
# PRODUCTO_PLAN          770270 non-null object
# PROVEEDOR_EQUIPO       175587 non-null float64
# SCORE_PLAN             444930 non-null object
# SUMA_ASEG              797157 non-null object
# VENC_PRENDA            217393 non-null datetime64[ns]
# ZONA_RETAIL            794443 non-null object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(22)
# memory usage: 188.9+ MB

# %%
# df["CONV_COMISIONARIO"].value_counts()

# %%
# fixing to_feather error
# df["CONV_COMISIONARIO"] = df["CONV_COMISIONARIO"].astype(str)

# %%
df.to_feather(filename_to_save)
