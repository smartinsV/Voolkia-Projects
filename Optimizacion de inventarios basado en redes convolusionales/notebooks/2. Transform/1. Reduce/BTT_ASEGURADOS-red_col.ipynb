# %%
import os

import pandas as pd

# %%
# display tables options
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %%
# creating the path
path = "../../../data/raw"
save_to_path = "../../../data/interim/1. col_red"
# file
filename = "BTT_ASEGURADOS.csv"
filename_to_save = os.path.join(save_to_path, filename.split(".")[0]+"-red_col.feather")
filename_to_save
# Out:
# '../../../data/interim/1. col_red/BTT_ASEGURADOS-red_col.feather'

# %%
# checking the path
file = os.path.join(path, filename)
if not(os.path.exists(file) and os.path.isfile(file)):
    raise Exception("File {} doesn't exists.".format(file))
else:
    print("ok")
# Out:
# ok

# %%
usecols = ['CIF_ID', 'COD_EST_CIVIL', 'FECHA_DESDE', 'FECHA_NACIMIENTO', 'SEXO_ASEG', 'TIPO_ACTIVIDAD', ]

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv(file, usecols=usecols)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479842 entries, 0 to 3479841
# Data columns (total 6 columns):
# CIF_ID              float64
# COD_EST_CIVIL       object
# FECHA_DESDE         object
# FECHA_NACIMIENTO    object
# SEXO_ASEG           object
# TIPO_ACTIVIDAD      object
# dtypes: float64(1), object(5)
# memory usage: 159.3+ MB

# %%
df.head(3).append(df.tail())
# Out:
#              CIF_ID COD_EST_CIVIL FECHA_DESDE FECHA_NACIMIENTO SEXO_ASEG  \
# 0         5562708.0            SO    8/9/1999       14/10/1977         F
# 1         3808145.0           NaN   16/9/1998        5/11/1968         M
# 2         2465845.0            CA   14/9/1998        5/11/1970         M
# 3479837  18992777.0            CA   23/5/2019        27/4/1951         M
# 3479838     60263.0            CA  25/11/2006        16/5/1951         M
# 3479839  21313384.0           NaN   10/8/2016         1/1/1900         M
# 3479840   3468840.0            SO   30/5/2019        24/8/1951         M
# 3479841  11345327.0            CA   10/5/2019         2/6/1951         M
#
#         TIPO_ACTIVIDAD
# 0              SinDato
# 1              SinDato
# 2                 EMPL
# 3479837           CONT
# 3479838           ESCR
# 3479839        SinDato
# 3479840           ESCR
# 3479841           EMPL

# %%
df = df[usecols]

# %% [markdown]
# ### Feature Format

# %%
to_date = ["FECHA_DESDE", "FECHA_NACIMIENTO"]
date_format = "%d/%m/%Y"
# for is faster
# df.loc[:, to_date] = df.loc[:, to_date].apply(pd.to_datetime(format=date_format))

# %%
# %%time 
for col in to_date:
    df[col] = pd.to_datetime(df[col], format=date_format, errors="coerce")
# Out:
# CPU times: user 14.9 s, sys: 194 ms, total: 15.1 s
# Wall time: 13.8 s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479842 entries, 0 to 3479841
# Data columns (total 6 columns):
# CIF_ID              float64
# COD_EST_CIVIL       object
# FECHA_DESDE         datetime64[ns]
# FECHA_NACIMIENTO    datetime64[ns]
# SEXO_ASEG           object
# TIPO_ACTIVIDAD      object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 159.3+ MB

# %%
df["CIF_ID"].nunique()
# Out:
# 3385271

# %%
df["CIF_ID"].value_counts(dropna=False)
# Out:
# 19552070.0    1547
# NaN           1071
# 18408293.0     652
# 19094921.0     423
# 22751283.0     349
# 17709623.0     242
# 14707147.0     182
# 16615924.0     179
# 19905411.0     120
# 16606057.0      86
# 13880356.0      84
# 11230935.0      72
# 14632684.0      69
# 19607007.0      67
# 10931159.0      66
# 19125577.0      61
# 19144692.0      56
# 10646985.0      53
# 16025804.0      49
# 18897758.0      49
# 11256095.0      38
# 19801700.0      37
# 17798443.0      31
# 10430331.0      29
# 20536367.0      27
# 12096953.0      24
# 18058395.0      24
# 13862732.0      23
# 22029991.0      22
# 22948323.0      20
# 19545977.0      20
# 18658114.0      20
# 13782138.0      19
# 11078538.0      19
# 21343173.0      19
# 20732470.0      16
# 19459878.0      15
# 10582312.0      14
# 10548825.0      14
# 13597039.0      13
# 22919064.0      13
# 10553782.0      12
# 15019385.0      11
# 10690115.0      11
# 14212645.0      11
# 22976139.0      11
# 2140768.0       10
# 12303851.0      10
# 14025959.0      10
# 8422704.0       10
# 13366320.0      10
# 11464992.0      10
# 11539834.0      10
# 11391996.0      10
# 10429465.0       9
# 11502102.0       9
# 3143254.0        9
# 13366335.0       9
# 10427072.0       8
# 11117446.0       8
# 1171195.0        8
# 10660874.0       8
# 10969089.0       8
# 10430141.0       8
# 2121858.0        7
# 10683801.0       7
# 11391319.0       7
# 14628986.0       7
# 11204889.0       7
# 10766049.0       7
# 10931186.0       7
# 10989760.0       7
# 21418766.0       7
# 11077631.0       7
# 14435438.0       6
# 13743052.0       6
# 21728965.0       6
# 3138860.0        6
# 13765955.0       6
# 13952986.0       6
# 17748594.0       6
# 1092940.0        6
# 11296187.0       6
# 17911806.0       6
# 13421132.0       6
# 12886339.0       6
# 2122216.0        6
# 14632163.0       6
# 13724954.0       5
# 11414808.0       5
# 3135347.0        5
# 10581107.0       5
# 11592764.0       5
# 11166909.0       5
# 11115659.0       5
# 16524257.0       5
# 10583575.0       5
# 3134346.0        5
# 11170826.0       5
# 10427055.0       5
# 3713518.0        5
# 14684608.0       5
# 10427097.0       5
# 1016948.0        5
# 14611232.0       5
# 11096048.0       5
# 11111903.0       5
# 11008845.0       5
# 11048097.0       5
# 20717406.0       5
# 13982227.0       5
# 14025953.0       5
# 11035742.0       5
# 10430518.0       5
# 14163529.0       5
# 10800982.0       5
# 21599987.0       5
# 11047441.0       5
# 3159958.0        5
# 11745326.0       5
# 11628101.0       5
# 12829629.0       5
# 3146954.0        4
# 969874.0         4
# 11319563.0       4
# 2000857.0        4
# 995165.0         4
# 3160480.0        4
# 928431.0         4
# 879368.0         4
# 3192610.0        4
# 3169333.0        4
# 3158914.0        4
# 3169194.0        4
# 1165874.0        4
# 3157233.0        4
# 997673.0         4
# 10662006.0       4
# 2558932.0        4
# 21415116.0       4
# 3159551.0        4
# 2790681.0        4
# 3133321.0        4
# 3194039.0        4
# 3193198.0        4
# 3187636.0        4
# 3039123.0        4
# 3164093.0        4
# 3144555.0        4
# 3161152.0        4
# 3064923.0        4
# 3189548.0        4
# 18006322.0       4
# 3169135.0        4
# 3155289.0        4
# 1692777.0        4
# 11008190.0       4
# 3193976.0        4
# 3168541.0        4
# 3159081.0        4
# 992765.0         4
# 867421.0         4
# 3159572.0        4
# 3159633.0        4
# 3154417.0        4
# 3194987.0        4
# 3158850.0        4
# 11073085.0       4
# 3172851.0        4
# 1076012.0        4
# 3191198.0        4
# 3149627.0        4
# 3140392.0        4
# 1021729.0        4
# 3180352.0        4
# 3171987.0        4
# 3056047.0        4
# 938599.0         4
# 3152317.0        4
# 1899015.0        4
# 3157651.0        4
# 587932.0         4
# 3191862.0        4
# 10427184.0       4
