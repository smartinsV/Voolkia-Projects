# %%
import pandas as pd

# %% [markdown]
# ### Load all datasets

# %%
df_train = pd.read_feather("../../../../data/processed/CLTP_train_set.feather")
df_opt = pd.read_feather("../../../../data/processed/CLTP_optimization_set.feather")
df_val = pd.read_feather("../../../../data/processed/CLTP_validation_set.feather")
df_test = pd.read_feather("../../../../data/processed/CLTP_test_set.feather")

# %% [markdown]
# ## Check class distribution

# %%
df_train["CLTP"].value_counts().plot.bar()

# %%
df_opt["CLTP"].value_counts().plot.bar()

# %%
df_val["CLTP"].value_counts().plot.bar()

# %%
df_test["CLTP"].value_counts().plot.bar()
