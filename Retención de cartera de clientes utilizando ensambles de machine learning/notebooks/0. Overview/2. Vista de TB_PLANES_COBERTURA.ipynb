# %%
import pandas as pd
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %%
table = "TB_PLANES_COBERTURA.tsv"
location = "../../data/raw"
sep = '\t'
encoding = 'latin1'
decimal = ','

# %%
df = pd.read_csv(f"{location}/{table}",
                sep=sep,
                encoding=encoding,
                decimal=decimal)
df.head(15)
# Out:
#     COD_CIA  COD_RAMO  COD_PLAN  \
# 0         1         1         1
# 1         1         2         1
# 2        14         1         1
# 3         1         1         3
# 4         1         2         3
# 5        14         1         3
# 6         1         1         4
# 7         1         2         4
# 8        14         1         4
# 9         1         1         5
# 10        1         2         5
# 11       14         1         5
# 12        1         1         6
# 13        1         2         6
# 14       14         1         6
#
#                                         DESC_RAMO_VEH COBERTURA  \
# 0                          TODO RIESGO SIN FRANQUICIA        TR
# 1                          TODO RIESGO SIN FRANQUICIA        TR
# 2                          TODO RIESGO SIN FRANQUICIA        TR
# 3   TODO RIESGO CON FRANQUICIA DEL 1% (UNO POR CIE...        TR
# 4   TODO RIESGO CON FRANQUICIA DEL 1% (UNO POR CIE...        TR
# 5   TODO RIESGO CON FRANQUICIA DEL 1% (UNO POR CIE...        TR
# 6   TODO RIESGO CON FRANQUICIA DEL 2% (DOS POR CIE...        TR
# 7   TODO RIESGO CON FRANQUICIA DEL 2% (DOS POR CIE...        TR
# 8   TODO RIESGO CON FRANQUICIA DEL 2% (DOS POR CIE...        TR
# 9   TODO RIESGO - CON FRANQUICIA DEL 3% (TRES POR ...        TR
# 10  TODO RIESGO CON FRANQUICIA DEL 3% (TRES POR CI...        TR
# 11  TODO RIESGO - CON FRANQUICIA DEL 3% (TRES POR ...        TR
# 12  TODO RIESGO - CON FRANQUICIA DEL 4% (CUATRO PO...        TR
# 13  TODO RIESGO CON FRANQUICIA DEL 4% (CUATRO POR ...        TR
# 14  TODO RIESGO - CON FRANQUICIA DEL 4% (CUATRO PO...        TR
#
#              PLAN  PORC_FRANQ RECUPERADOR GRANIZO
# 0   Discontinuado         100           N       S
# 1   Discontinuado         100           N       S
# 2   Discontinuado         100           N       S
# 3   Discontinuado           1           N       S
# 4   Discontinuado           1           N       S
# 5   Discontinuado           1           N       S
# 6   Discontinuado           2           N       S
# 7   Discontinuado           2           N       S
# 8   Discontinuado           2           N       S
# 9   Discontinuado           3           N       S
# 10  Discontinuado           3           N       S
# 11  Discontinuado           3           N       S
# 12  Discontinuado           4           N       S
# 13  Discontinuado           4           N       S
# 14  Discontinuado           4           N       S
