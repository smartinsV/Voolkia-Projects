# %%
import pandas as pd
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %% [markdown]
# ## Table description generation

# %% [markdown]
# Enter the following info:
#  - Table name
#  - Location
#  - Separator
#  - Encoding (optional)
#  - Decimal mark (optional)

# %%
table = "VIGABT_POLIZAS.tsv"
location = "../../data/raw"
sep = '\t'
encoding = 'latin1'
decimal = ','

# %% [markdown]
# ### Make a first view of the dataset to check most interesting columns

# %% [markdown]
# **Run this if it's a big file**

# %%
for chunk in pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000):
    df = chunk
    break
# Out:
# /home/voolkia/anaconda3/envs/test/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (13,18,25,27,28,37,43,49,50,57,58,59,62,63,64,67,68,69,70,71,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **Run this if it's a relatively small file**

# %%
df = pd.read_csv(f"{location}/{table}",
                sep=sep,
                encoding=encoding,
                decimal=decimal)

# %%
df.head(15)
# Out:
#      NUM_SECU_POL  COD_ZONA_RC  COD_ZONA_ROBO       NUM_POL1  \
# 0   1754486179999            1              1  5450048179903
# 1   1754487779999            1              2  6010037470403
# 2   1754488299999            1              4  6040052855502
# 3   1754488439999            3             10  5170025278501
# 4   1754488459999            8              7  6130013104203
# 5   1754488699999            6              9  5030014123103
# 6   1754489119999           30             30  5250008795301
# 7   1754489249999            1              1  5400042562902
# 8   1754483839999            1              4  6040052855203
# 9   1754483869999            6              9  6130013104103
# 10  1754484149999            4              9  5110017786101
# 11  1754484699999            1              4  6040052855401
# 12  1754485039999            6             11  5070015489101
# 13  1754485139999            9             18  5490015047402
# ...

# %%
df.dtypes
# Out:
# NUM_SECU_POL                      int64
# COD_ZONA_RC                       int64
# COD_ZONA_ROBO                     int64
# NUM_POL1                          int64
# COD_AGENCIA_EMISORA               int64
# NUM_POL_ANT                       int64
# RENOVADA_POR                      int64
# COD_CIA                           int64
# COD_SECC                          int64
# COD_RAMO                          int64
# FECHA_VIG_POL                    object
# FECHA_VENC_POL                   object
# COD_PLAN                          int64
# MCA_INDIVIDUO_AGRUPADO           object
# CIF_ID_EMPRESA                  float64
# PORC_DESCUENTO                  float64
# COD_PROD                          int64
# COD_COBRO                        object
# POLIZA_AL_50                     object
# ESTADO_CIVIL_ASEGURADO           object
# COD_POSTAL                        int64
# IMP_BONIFICACION_MES            float64
# IMP_PREMIO_MES                  float64
# ...

# %%
df.columns
# Out:
# Index(['NUM_SECU_POL', 'COD_ZONA_RC', 'COD_ZONA_ROBO', 'NUM_POL1',
#        'COD_AGENCIA_EMISORA', 'NUM_POL_ANT', 'RENOVADA_POR', 'COD_CIA',
#        'COD_SECC', 'COD_RAMO', 'FECHA_VIG_POL', 'FECHA_VENC_POL', 'COD_PLAN',
#        'MCA_INDIVIDUO_AGRUPADO', 'CIF_ID_EMPRESA', 'PORC_DESCUENTO',
#        'COD_PROD', 'COD_COBRO', 'POLIZA_AL_50', 'ESTADO_CIVIL_ASEGURADO',
#        'COD_POSTAL', 'IMP_BONIFICACION_MES', 'IMP_PREMIO_MES',
#        'IMP_PRIMA_FACT_MES', 'FECHA_PROCESO', 'MCA_MOVIMIENTO', 'MCA_VIGENCIA',
#        'MCA_BAJA', 'COD_COBRO_ANTERIOR', 'FECHA_VIG_ORIG_POL', 'MCA_AGRAVANTE',
#        'MCA_EMPLEADO', 'COD_AGENCIA_PRESU', 'COD_AGENCIA_SOLIC',
#        'COD_AGENCIA_EMI', 'COD_AGENCIA', 'COD_AGENCIA_PROD', 'ALTA_REAL',
#        'COD_INICIADOR', 'CAPITAL_VEHICULO', 'CAPITAL_ACCESORIOS',
#        'CAPITAL_ASEGURADO_COTIZACION', 'COD_RIES', 'NRO_SOLIC_EXTERNA',
#        'ANTIGUEDAD', 'ANTIGUEDAD_TRADELTA', 'MCA_CENTRALIZADA', 'MCA_VENCIDA',
# ...

# %% [markdown]
# *Based on last output, fill this list to mark most relevant columns*

# %%
to_use = ['NUM_SECU_POL', 'COD_ZONA_RC', 'COD_ZONA_ROBO', 'NUM_POL1',
       'COD_AGENCIA_EMISORA', 'NUM_POL_ANT', 'RENOVADA_POR', 'COD_CIA',
       'COD_SECC', 'COD_RAMO', 'FECHA_VIG_POL', 'FECHA_VENC_POL', 'COD_PLAN',
       'MCA_INDIVIDUO_AGRUPADO', 'CIF_ID_EMPRESA', 'PORC_DESCUENTO',
       'COD_PROD', 'COD_COBRO', 'POLIZA_AL_50', 'ESTADO_CIVIL_ASEGURADO',
       'COD_POSTAL', 'IMP_BONIFICACION_MES', 'IMP_PREMIO_MES',
       'IMP_PRIMA_FACT_MES', 'FECHA_PROCESO', 'MCA_MOVIMIENTO', 'MCA_VIGENCIA',
       'MCA_BAJA', 'COD_COBRO_ANTERIOR', 'FECHA_VIG_ORIG_POL', 'MCA_AGRAVANTE',
       'MCA_EMPLEADO', 'COD_AGENCIA_PRESU', 'COD_AGENCIA_SOLIC',
       'COD_AGENCIA_EMI', 'COD_AGENCIA', 'COD_AGENCIA_PROD', 'ALTA_REAL',
       'COD_INICIADOR', 'CAPITAL_VEHICULO', 'CAPITAL_ACCESORIOS',
       'CAPITAL_ASEGURADO_COTIZACION', 'COD_RIES', 'NRO_SOLIC_EXTERNA',
       'ANTIGUEDAD', 'ANTIGUEDAD_TRADELTA', 'MCA_CENTRALIZADA', 'MCA_VENCIDA',
       'IMP_BONIFICACION_A_MES', 'PRENDARIO', 'NEGOCIO', 'AGRUPADOR_DIRECTO',
       'COD_AGENCIA_GES', 'NUM_POL_ORI', 'MCA_POLIZA_VIP', 'FECHA_EMI',
       'CANT_RENOVACION', 'FECHA_ANTIG', 'ANTIG', 'FECHA_VIG_POL_NPO',
       'SEGMENTO', 'SEGMENTO_2', 'COD_ZONA_CASCO', 'PROXIMA_FECHA_RENOV',
       'NEGOCIO_DESC', 'TIPO_BAJA', 'COD_SITUACION',
       'ULTIMA_COD_SITUACION', 'CIF_ID', 'SEGMENTO_CLIENTE']

# %% [markdown]
# ### Now write the file

# %% [markdown]
# **If it was a big file, read it completely with this line**

# %%
chunks = pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000,
                         usecols=to_use)
df = pd.concat(chunks)
# Out:
# /home/voolkia/anaconda3/envs/test/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (13,18,25,27,28,37,43,49,50,62,63,64,67,71,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df["FECHA_EQUIPO"].value_counts().head().to_string()
# Out:
# '06/04/2019    283655\n06/03/2019    239644\n06/05/2019    234558\n05/03/2019    233488\n01/04/2019    197252'

# %%
f = open(f'../../docs/{table} feature description.csv','w')
f.write('Column;Used;Null Rate; Type; Unique values; Values\n')
for column in df.columns:
    
    null_rate = round(df[column].isna().mean()*100,2)
    
    unique_vals = df[column].nunique()
    
    if (column in to_use) and null_rate < .5 and unique_vals > 1:
        used = 'X'
    else:
        used=''
    
    dtype = df[column].dtype
    
    if(dtype == 'object'):
        values = f"Top 10:\n{df[column].value_counts(dropna=False).head(10).to_string()}"
    else:
        values = f'[{df[column].min()};{df[column].max()}]'
        
    f.write(f'{column};{used};{null_rate};{dtype};{unique_vals};"{values}"\n')
    
f.close()
