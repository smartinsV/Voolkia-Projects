# %%
import pandas as pd
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %% [markdown]
# ## Table description generation

# %% [markdown]
# Enter the following info:
#  - Table name
#  - Location
#  - Separator
#  - Encoding (optional)
#  - Decimal mark (optional)

# %%
table = "TB_COTIZACIONES.tsv"
location = "../../data/raw"
sep = '\t'
encoding = 'latin1'
decimal = ','

# %% [markdown]
# ### Make a first view of the dataset to check most interesting columns

# %% [markdown]
# **Run this if it's a big file**

# %%
for chunk in pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000):
    df = chunk
    break

# %% [markdown]
# **Run this if it's a relatively small file**

# %%
df = pd.read_csv(f"{location}/{table}",
                sep=separator,
                encoding=encoding,
                decimal=decimal)

# %%
df.head(15)
# Out:
#      NUM_SECU_POL  COD_ZONA_RC  COD_ZONA_ROBO       NUM_POL1  \
# 0   1883348309999           31             31  4001010810003
# 1   1883348439999            6             11  5280008816503
# 2   1883348519999            1              2  6010040998803
# 3   1883348579999            1              4  5450053609603
# 4   1883348679999            1              4  6040057835503
# 5   1883348799999            8              7  6130014094503
# 6   1883349219999            4             12  5190013006003
# 7   1883349239999            1              3  6100020641503
# 8   1883349409999            1              2  6010040998903
# 9   1883349599999           31             31  5470025460302
# 10  1883349649999            1              3  5330079627003
# 11  1883349729999            8              7  5010035144403
# 12  1883349909999            1              3  6300021341003
# 13  1874021439999           31             31  4005013043212
# 14  1874021469999           31             31  4005013043312
#
#     COD_AGENCIA_EMISORA    NUM_POL_ANT   RENOVADA_POR  COD_CIA  COD_SECC  \
# 0                  4001  4001010810002  4001010810004       14         4
# 1                  5280  5280008816502  5280008816504        1         4
# 2                  6010  6010040998802  6010040998804        1         4
# 3                  5450  5450053609602  5450053609604        1         4
# 4                  6040  6040057835502  6040057835504        1         4
# 5                  6130  6130014094502  6130014094504        1         4
# 6                  5190  5190013006002  5190013006004        1         4
# 7                  6100  6100020641502  6100020641504        1         4
# 8                  6010  6010040998902  6010040998904        1         4
# 9                  5470  5470025460301  5470025460303        1         4
# 10                 5330  5330079627002  5330079627004        1         4
# 11                 5010  5010035144402  5010035144404        1         4
# 12                 6300  6300021341002  6300021341004        1         4
# 13                 4005  4005013043211  4005013967601       14         4
# 14                 4005  4005013043311  4005013967701       14         4
#
#     COD_RAMO FECHA_VIG_POL FECHA_VENC_POL  COD_PLAN MCA_INDIVIDUO_AGRUPADO  \
# 0          1    05/01/2019     05/02/2019     963.0                    NaN
# 1          1    05/01/2019     05/02/2019     942.0                    NaN
# 2          1    05/01/2019     05/02/2019     724.0                    NaN
# 3          1    06/01/2019     06/02/2019     969.0                    NaN
# 4          1    05/01/2019     05/02/2019     723.0                    NaN
# 5          1    05/01/2019     05/02/2019     961.0                    NaN
# 6          1    01/01/2019     01/02/2019     967.0                    NaN
# 7          1    06/01/2019     06/02/2019     920.0                    NaN
# 8          1    05/01/2019     05/02/2019     963.0                    NaN
# 9          1    05/12/2018     05/01/2019     964.0                    NaN
# 10         1    02/01/2019     02/02/2019     942.0                    NaN
# 11         1    05/01/2019     05/02/2019     921.0                    NaN
# 12         1    05/01/2019     05/02/2019     920.0                    NaN
# 13         1    21/01/2019     21/02/2019     444.0                    NaN
# 14         1    02/01/2019     02/02/2019     964.0                    NaN
#
#     CIF_ID_EMPRESA  PORC_DESCUENTO  COD_PROD COD_COBRO POLIZA_AL_50  \
# 0              NaN             NaN     74329        BA          NaN
# 1              NaN             NaN     72043        PP          NaN
# 2              NaN             NaN     73852        TM          NaN
# 3              NaN             NaN     25674        TM          NaN
# 4              NaN             NaN     73925        TM          NaN
# 5              NaN             NaN      6130        TM          NaN
# 6              NaN             NaN     72532        PP          NaN
# 7              NaN             NaN      5660        TM          NaN
# 8              NaN             NaN     23686        TM          NaN
# 9              NaN             NaN     74289        TM          NaN
# 10             NaN             NaN      5660        TM          NaN
# 11             NaN             NaN      5660        TM          NaN
# 12             NaN             NaN      5660        BA          NaN
# 13             NaN             NaN     72900        CC          NaN
# 14             NaN             NaN     72319        CC          NaN
#
#    ESTADO_CIVIL_ASEGURADO  COD_POSTAL  IMP_BONIFICACION_MES  IMP_PREMIO_MES  \
# 0                      SO     6500004                 -0.16         1873.21
# 1                      CA     6300000                 -0.20         1881.32
# 2                      SO     1888032                  0.00          727.61
# 3                      SO     1716000                  0.00         2538.93
# 4                      SO     1663015                  0.00          192.74
# 5                      SO     5009029                 -0.07         1504.99
# 6                      CA     3600000                  0.00         3220.79
# 7                      SO     1437000                  0.00         1700.46
# 8                      CA     1888032                 -0.48         4171.46
# 9                      CA     6640000                  0.00         1806.92
# 10                     SO     1414000                  0.00         1653.52
# 11                     CA     5000050                  0.00          921.79
# 12                     SO     1440000                  0.00         1651.89
# 13                     CA     2804006                 -0.42         2554.44
# 14                     SO     2720000                 -0.16         1466.07
#
#     IMP_PRIMA_FACT_MES  IMP_IMPUESTO_MES FECHA_PROCESO MCA_MOVIMIENTO  \
# 0              1502.45            370.76    31/01/2019            NaN
# 1              1504.50            376.83    31/01/2019            NaN
# 2               583.59            144.02    31/01/2019            NaN
# 3              2036.37            502.55    31/01/2019            NaN
# 4               154.59             38.15    31/01/2019            NaN
# 5              1211.75            293.25    31/01/2019            NaN
# 6              2593.26            627.56    31/01/2019            NaN
# 7              1380.26            320.21    31/01/2019            NaN
# 8              3345.82            825.68    31/01/2019            NaN
# 9              1449.28            357.66    31/01/2019            NaN
# 10             1342.17            311.37    31/01/2019            NaN
# 11              742.20            179.60    31/01/2019            NaN
# 12             1340.84            311.06    31/01/2019            NaN
# 13             2048.83            505.61    31/01/2019            NaN
# 14             1175.88            290.19    31/01/2019            NaN
#
#    MCA_VIGENCIA MCA_BAJA COD_COBRO_ANTERIOR  COD_MON FECHA_VIG_ORIG_POL  \
# 0             S      NaN                 BA        1         05/11/2018
# 1             S      NaN                 PP        1         05/11/2018
# 2             S      NaN                 TM        1         05/11/2018
# 3             S      NaN                 TM        1         06/11/2018
# 4             S      NaN                 TM        1         05/11/2018
# 5             S      NaN                 TM        1         05/11/2018
# 6             S      NaN                 PP        1         05/11/2018
# 7             S      NaN                 TM        1         06/11/2018
# 8             S      NaN                 TM        1         05/11/2018
# 9           NaN        S                 TM        1         05/11/2018
# 10            S      NaN                 TM        1         02/11/2018
# 11            S      NaN                 TM        1         05/11/2018
# 12            S      NaN                 BA        1         05/11/2018
# 13            S      NaN                 CC        1         01/03/2011
# 14            S      NaN                 CC        1         02/02/2012
#
#    MCA_AGRAVANTE MCA_EMPLEADO  COD_AGENCIA_PRESU  COD_AGENCIA_SOLIC  \
# 0              N            N             4001.0             4001.0
# 1              N            N             3401.0             3401.0
# 2              S            N             3402.0             3402.0
# 3              N            N             6020.0             3402.0
# 4              S            N             3402.0             3402.0
# 5              N            N             6130.0             6130.0
# 6              N            N             3402.0             3402.0
# 7              N            N               20.0               20.0
# 8              N            N             3402.0             3402.0
# 9              N            N             3401.0             3401.0
# 10             N            N             5775.0             5660.0
# 11             N            N             5775.0             5660.0
# 12             N            N               20.0               20.0
# 13             N            N             4005.0             4005.0
# 14             N            N             4005.0             4005.0
#
#     COD_AGENCIA_EMI  COD_AGENCIA  COD_AGENCIA_PROD ALTA_REAL CLIENTE_PERDIDO  \
# 0              4001         4001            4001.0       NaN             NaN
# 1              5000         5280            3401.0       NaN             NaN
# 2              6010         6010            3402.0       NaN             NaN
# 3              6020         5450            3402.0       NaN             NaN
# 4              5000         6040            3402.0       NaN             NaN
# 5              6130         6130            6130.0       NaN             NaN
# 6              5000         5190            3402.0       NaN             NaN
# 7              6080         6100            5660.0       NaN             NaN
# 8              9840         6010            3402.0       NaN             NaN
# 9              5000         5470            3401.0       NaN               S
# 10             6330         5330            5660.0       NaN             NaN
# 11             6280         5010            5660.0       NaN             NaN
# 12             6100         6300            5660.0       NaN             NaN
# 13               10         4005            4005.0       NaN             NaN
# 14               10         4005            4005.0       NaN             NaN
#
#     COD_INICIADOR  CAPITAL_VEHICULO  CAPITAL_ACCESORIOS  \
# 0         72170.0          438600.0              1080.0
# 1         72043.0          801000.0              1080.0
# 2         73806.0           82800.0                 0.0
# 3         73379.0          438000.0              1080.0
# 4         73806.0               0.0                 0.0
# 5             NaN           88700.0              2050.0
# 6         72532.0          645000.0              1080.0
# 7             NaN          260100.0              1080.0
# 8         73716.0          567000.0              1080.0
# 9         72556.0          234600.0              1080.0
# 10            NaN          138700.0              1080.0
# 11            NaN           92800.0               250.0
# 12            NaN          237600.0              1080.0
# 13        72239.0          171300.0              1080.0
# 14        72239.0          204000.0              1080.0
#
#     CAPITAL_ASEGURADO_COTIZACION  COD_RIES NRO_SOLIC_EXTERNA  ANTIGUEDAD  \
# 0                       428400.0         1               NaN       801.0
# 1                       663000.0         1         003249533      1798.0
# 2                        79500.0         1          5KXNI3BH        87.0
# 3                       367200.0         1               NaN      1960.0
# 4                        18900.0         1          I1W5WSVX        87.0
# 5                        88700.0         1               NaN       659.0
# 6                       540600.0         1          44412193        87.0
# 7                       260100.0         1               NaN        87.0
# 8                       428400.0         1          37365770        87.0
# 9                       234600.0         1               NaN         NaN
# 10                      138700.0         1               NaN       212.0
# 11                       92800.0         1               NaN       150.0
# 12                      237600.0         1               NaN       325.0
# 13                      163200.0         1               NaN      2893.0
# 14                      209100.0         1               NaN      3548.0
#
#     ANTIGUEDAD_TRADELTA  MCA_CENTRALIZADA  MCA_VENCIDA  \
# 0                   NaN               NaN          NaN
# 1                   NaN               NaN          NaN
# 2                   NaN               NaN          NaN
# 3                   NaN               NaN          NaN
# 4                   NaN               NaN          NaN
# 5                   NaN               NaN          NaN
# 6                   NaN               NaN          NaN
# 7                   NaN               NaN          NaN
# 8                   NaN               NaN          NaN
# 9                   NaN               NaN          NaN
# 10                  NaN               NaN          NaN
# 11                  NaN               NaN          NaN
# 12                  NaN               NaN          NaN
# 13                  NaN               NaN          NaN
# 14                  NaN               NaN          NaN
#
#     IMP_BONIFICACION_A_MES PRENDARIO NEGOCIO  AGRUPADOR_DIRECTO  \
# 0                  -643.91         N    DEFD                NaN
# 1                      NaN         S      PP                NaN
# 2                      NaN         N    AMV2                NaN
# 3                  -359.36         N    DEFB                NaN
# 4                      NaN         N    AMV2                NaN
# 5                  -213.84         N     DEF                NaN
# 6                      NaN         S      PP                NaN
# 7                  -243.58         N     DEF                NaN
# 8                  -590.44         N     DEF                NaN
# 9                      NaN         N     DEF                NaN
# 10                 -236.85         N     DEF                NaN
# 11                 -130.98         N     DEF                NaN
# 12                 -236.62         N     DEF                NaN
# 13                     NaN         N     DEF                NaN
# 14                     NaN         N     M15                NaN
#
#     COD_AGENCIA_GES    NUM_POL_ORI MCA_POLIZA_VIP   FECHA_EMI  CAMPAN_ID  \
# 0               NaN  4001010810001              S  05/11/2018        NaN
# 1               NaN  5280008816501              S  05/11/2018        NaN
# 2               NaN  6010040998801              N  05/11/2018        NaN
# 3               NaN  5450053609601              S  05/11/2018        NaN
# 4               NaN  6040057835501              N  05/11/2018        NaN
# 5               NaN  6130014094501              S  05/11/2018        NaN
# 6               NaN  5190013006001              S  05/11/2018        NaN
# 7               NaN  6100020641501              N  05/11/2018        NaN
# 8               NaN  6010040998901              S  05/11/2018        NaN
# 9               NaN  5470025460301              S  05/11/2018        NaN
# 10           5775.0  5330079627001              S  05/11/2018   124760.0
# 11           5775.0  5010035144401              N  05/11/2018   125259.0
# 12              NaN  6300021341001              N  05/11/2018        NaN
# 13              NaN  4005003556501              S  13/10/2018        NaN
# 14              NaN  4005004859401              S  13/10/2018        NaN
#
#    CONV_COMISIONARIO  PORC_COMISION  IMP_COMISION_LOCAL  CANT_RENOVACION  \
# 0         CX_1000000           24.0              360.55              3.0
# 1            1000100            0.0                0.00              3.0
# 2         CS_1000166           31.0              180.91              3.0
# 3            1000100           22.0              448.00              3.0
# 4         CS_1000166           31.0               47.92              3.0
# 5                NaN            0.0                0.00              3.0
# 6            1000100           32.0              829.84              3.0
# 7                NaN            0.0                0.00              3.0
# 8            1000100           25.0              836.34              3.0
# 9            1000100           18.0              260.87              2.0
# 10               NaN            0.0                0.00              3.0
# 11               NaN            0.0                0.00              3.0
# 12               NaN            0.0                0.00              3.0
# 13        CX_1000016           25.0              512.10             96.0
# 14        CX_1000018           21.0              246.90             84.0
#
#    CLIENTE_PERDIDO_60 CLIENTE_PERDIDO_90 FECHA_ANTIG   ANTIG  \
# 0                 NaN                NaN  21/11/2016   775.0
# 1                 NaN                NaN  28/02/2014  1772.0
# 2                 NaN                NaN  05/11/2018    61.0
# 3                 NaN                NaN  16/09/2013  1938.0
# 4                 NaN                NaN  05/11/2018    61.0
# 5                 NaN                NaN  08/05/2017   607.0
# 6                 NaN                NaN  22/11/2012  2231.0
# 7                 NaN                NaN  06/11/2018    61.0
# 8                 NaN                NaN  22/04/2015  1354.0
# 9                   S                  S  05/11/2018    30.0
# 10                NaN                NaN  29/08/2013  1952.0
# 11                NaN                NaN  18/04/2001  6471.0
# 12                NaN                NaN  11/06/2014  1669.0
# 13                NaN                NaN  01/03/2011  2883.0
# 14                NaN                NaN  15/05/2009  3519.0
#
#     CLI_PERDIDO_VIG_R9 CLIENTE_SUSCRIPTO FECHA_VIG_POL_NPO  MCA_SMS SEGMENTO  \
# 0                  NaN                 N        05/11/2018      NaN     ALTO
# 1                  NaN                 S        05/11/2018      NaN     ALTO
# 2                  NaN                 S        05/11/2018      NaN      NaN
# 3                  NaN                 N        06/11/2018      NaN     ALTO
# 4                  NaN                 S        05/11/2018      NaN      NaN
# 5                  NaN                 S        05/11/2018      NaN    BBAJO
# 6                  NaN                 N        05/11/2018      NaN     ALTO
# 7                  NaN                 S        06/11/2018      NaN    MALTO
# 8                  NaN                 N        05/11/2018      NaN     ALTO
# 9                  NaN                 N        05/11/2018      NaN     ALTO
# 10                 NaN                 S        02/11/2018      NaN    MEDIO
# 11                 NaN                 S        05/11/2018      NaN     BAJO
# 12                 NaN                 S        05/11/2018      NaN    MALTO
# 13                 NaN                 N        01/03/2011      NaN     ALTO
# 14                 NaN                 N        02/02/2012      NaN     ALTO
#
#    CLI_PERDIDO_SECC2 SEGMENTO_2  COD_ZONA_CASCO USUARIO_WEB  \
# 0                NaN       ALTO              11         NaN
# 1                NaN       ALTO               2         NaN
# 2                NaN        NaN               1         NaN
# 3                NaN       ALTO               1         NaN
# 4                NaN        NaN               1         NaN
# 5                NaN      BBAJO               2         NaN
# 6                NaN       ALTO               2         NaN
# 7                NaN      MEDIO               1         NaN
# 8                NaN       ALTO               1         NaN
# 9                NaN       ALTO              11         NaN
# 10               NaN      MEDIO               1         NaN
# 11               NaN       BAJO               2         NaN
# 12               NaN      MALTO               1         NaN
# 13               NaN      MALTO              11         NaN
# 14               NaN       ALTO              11         NaN
#
#    PROXIMA_FECHA_RENOV        NEGOCIO_DESC  COD_USR_MAN_AUT  \
# 0           05/05/2019         MOSTRADOR D              NaN
# 1           05/02/2019          Prendarios              NaN
# 2           05/02/2019  AMV CONCESIONARIOS              NaN
# 3           06/05/2019         MOSTRADOR B              NaN
# 4           05/05/2019  AMV CONCESIONARIOS              NaN
# 5           05/02/2019           Mostrador              NaN
# 6           01/05/2019          Prendarios              NaN
# 7           06/05/2019           Mostrador              NaN
# 8           05/05/2019           Mostrador              NaN
# 9           05/02/2019           Mostrador              NaN
# 10          02/05/2019           Mostrador              NaN
# 11          05/05/2019           Mostrador              NaN
# 12          05/05/2019           Mostrador              NaN
# 13          21/05/2019           Mostrador              NaN
# 14          02/05/2019             DESC 10              NaN
#
#    CLIENTE_PERDIDO_SECC CLIENTE_PERDIDO_SECC_60 CLIENTE_PERDIDO_SECC_90  \
# 0                   NaN                     NaN                     NaN
# 1                   NaN                     NaN                     NaN
# 2                   NaN                     NaN                     NaN
# 3                   NaN                     NaN                     NaN
# 4                   NaN                     NaN                     NaN
# 5                   NaN                     NaN                     NaN
# 6                   NaN                     NaN                     NaN
# 7                   NaN                     NaN                     NaN
# 8                   NaN                     NaN                     NaN
# 9                     S                       S                       S
# 10                  NaN                     NaN                     NaN
# 11                  NaN                     NaN                     NaN
# 12                  NaN                     NaN                     NaN
# 13                  NaN                     NaN                     NaN
# 14                  NaN                     NaN                     NaN
#
#    TIPO_BAJA COD_SITUACION  ULTIMA_COD_SITUACION  CLAU_AJUSTE  COEF_POL  \
# 0        NaN            CT                   NaN          5.0  0.083333
# 1        NaN            EP                   NaN          5.0  0.083333
# 2        NaN            CT                   NaN          NaN  0.083333
# 3        NaN            CT                   NaN          5.0  0.083333
# 4        NaN            CT                   NaN          NaN  0.083333
# 5        NaN            CT                   NaN          5.0  0.083333
# 6        NaN            EP                   NaN          NaN  0.083333
# 7        NaN            CT                   NaN          5.0  0.083333
# 8        NaN            CT                   NaN          5.0  0.083333
# 9          M           NaN                   NaN          5.0  0.083333
# 10       NaN            CT                   NaN          5.0  0.083333
# 11       NaN            CT                   NaN          5.0  0.083333
# 12       NaN            CT                   NaN          5.0  0.083333
# 13       NaN            CT                   NaN          5.0  0.083333
# 14       NaN            CT                   NaN          5.0  0.083333
#
#        OPERACION  RULE_ID_RESPUESTA  IMP_BONIFICACION_A_MES_CONT  CONTRATO_ID  \
# 0   1.883348e+12            95357.0                          0.0          NaN
# 1   1.883348e+12            95357.0                          NaN          NaN
# 2            NaN                NaN                          NaN          NaN
# 3   1.883349e+12            95357.0                          0.0          NaN
# 4            NaN                NaN                          NaN          NaN
# 5   1.883349e+12            95357.0                          0.0          NaN
# 6   1.883349e+12            95357.0                          NaN          NaN
# 7   1.883349e+12            95357.0                          0.0          NaN
# 8   1.883349e+12            95357.0                          0.0          NaN
# 9   1.883350e+12            95357.0                          NaN          NaN
# 10  1.883350e+12            95357.0                          0.0          NaN
# 11  1.883350e+12            95357.0                          0.0          NaN
# 12  1.883350e+12            95357.0                          0.0          NaN
# 13  1.837854e+12            76558.0                          NaN          NaN
# 14  1.837854e+12            76558.0                          NaN          NaN
#
#         CIF_ID MCA_IPOL  SEGMENTO_CLIENTE
# 0   21477852.0      NaN                 2
# 1   10359740.0      NaN                 2
# 2   22833168.0      NaN                 3
# 3   19244514.0      NaN                 2
# 4   22833170.0      NaN                 3
# 5   21190915.0      NaN                 2
# 6   15622375.0      NaN                 1
# 7   22831964.0      NaN                 2
# 8    7312256.0      NaN                 2
# 9   22833179.0      NaN                 2
# 10  19017054.0      NaN                 2
# 11   1506273.0      NaN                 2
# 12  19662370.0      NaN                 2
# 13   7591571.0      NaN                 2
# 14  15502296.0      NaN                 2

# %%
df.dtypes
# Out:
# NUM_SECU_POL                      int64
# COD_ZONA_RC                       int64
# COD_ZONA_ROBO                     int64
# NUM_POL1                          int64
# COD_AGENCIA_EMISORA               int64
# NUM_POL_ANT                       int64
# RENOVADA_POR                      int64
# COD_CIA                           int64
# COD_SECC                          int64
# COD_RAMO                          int64
# FECHA_VIG_POL                    object
# FECHA_VENC_POL                   object
# COD_PLAN                        float64
# MCA_INDIVIDUO_AGRUPADO           object
# CIF_ID_EMPRESA                  float64
# PORC_DESCUENTO                  float64
# COD_PROD                          int64
# COD_COBRO                        object
# POLIZA_AL_50                     object
# ESTADO_CIVIL_ASEGURADO           object
# COD_POSTAL                        int64
# IMP_BONIFICACION_MES            float64
# IMP_PREMIO_MES                  float64
# IMP_PRIMA_FACT_MES              float64
# IMP_IMPUESTO_MES                float64
# FECHA_PROCESO                    object
# MCA_MOVIMIENTO                   object
# MCA_VIGENCIA                     object
# MCA_BAJA                         object
# COD_COBRO_ANTERIOR               object
# COD_MON                           int64
# FECHA_VIG_ORIG_POL               object
# MCA_AGRAVANTE                    object
# MCA_EMPLEADO                     object
# COD_AGENCIA_PRESU               float64
# COD_AGENCIA_SOLIC               float64
# COD_AGENCIA_EMI                   int64
# COD_AGENCIA                       int64
# COD_AGENCIA_PROD                float64
# ALTA_REAL                        object
# CLIENTE_PERDIDO                  object
# COD_INICIADOR                   float64
# CAPITAL_VEHICULO                float64
# CAPITAL_ACCESORIOS              float64
# CAPITAL_ASEGURADO_COTIZACION    float64
# COD_RIES                          int64
# NRO_SOLIC_EXTERNA                object
# ANTIGUEDAD                      float64
# ANTIGUEDAD_TRADELTA             float64
# MCA_CENTRALIZADA                float64
# MCA_VENCIDA                     float64
# IMP_BONIFICACION_A_MES          float64
# PRENDARIO                        object
# NEGOCIO                          object
# AGRUPADOR_DIRECTO               float64
# COD_AGENCIA_GES                 float64
# NUM_POL_ORI                       int64
# MCA_POLIZA_VIP                   object
# FECHA_EMI                        object
# CAMPAN_ID                       float64
# CONV_COMISIONARIO                object
# PORC_COMISION                   float64
# IMP_COMISION_LOCAL              float64
# CANT_RENOVACION                 float64
# CLIENTE_PERDIDO_60               object
# CLIENTE_PERDIDO_90               object
# FECHA_ANTIG                      object
# ANTIG                           float64
# CLI_PERDIDO_VIG_R9              float64
# CLIENTE_SUSCRIPTO                object
# FECHA_VIG_POL_NPO                object
# MCA_SMS                         float64
# SEGMENTO                         object
# CLI_PERDIDO_SECC2                object
# SEGMENTO_2                       object
# COD_ZONA_CASCO                    int64
# USUARIO_WEB                      object
# PROXIMA_FECHA_RENOV              object
# NEGOCIO_DESC                     object
# COD_USR_MAN_AUT                 float64
# CLIENTE_PERDIDO_SECC             object
# CLIENTE_PERDIDO_SECC_60          object
# CLIENTE_PERDIDO_SECC_90          object
# TIPO_BAJA                        object
# COD_SITUACION                    object
# ULTIMA_COD_SITUACION            float64
# CLAU_AJUSTE                     float64
# COEF_POL                        float64
# OPERACION                       float64
# RULE_ID_RESPUESTA               float64
# IMP_BONIFICACION_A_MES_CONT     float64
# CONTRATO_ID                     float64
# CIF_ID                          float64
# MCA_IPOL                         object
# SEGMENTO_CLIENTE                  int64
# dtype: object

# %%
df.columns
# Out:
# Index(['NRO_PRESUP', 'CIF_ID', 'COD_CIA', 'COD_SECC', 'COD_RAMO',
#        'FECHA_EQUIPO', 'FECHA_SOLIC', 'COD_AGENCIA_PRESU', 'COD_AGENCIA_SOLIC',
#        'COD_INICIADOR', 'ESTADO', 'COD_MARCA', 'COD_MOD', 'COD_PLAN',
#        'SUMA_ASEG', 'TIPO_COMBUSTIBLE', 'GRUPO_COMBUSTIBLE', 'ORIGEN',
#        'FOR_COBRO', 'NEGOCIO', 'COD_PROD', 'COD_POSTAL', 'AGRUPADOR_DIRECTO',
#        'COD_AGENCIA_GES', 'FECHA_COTIZ_ANT', 'CANAL_ORIGEN', 'ORIGEN_DESC',
#        'REGION', 'NOM_ORIGEN_PRESU', 'SOLICITA_MISMO_AUTO', 'NUM_SECU_POL',
#        'EDAD', 'SEXO', 'ESTADO_CIVIL', 'BANCO', 'MARCA_MODELO', 'PUERTAS',
#        'LOCALIDAD', 'PROVINCIA', 'MARCA', 'VERSION', 'NACIONAL_IMPORT',
#        'TRACCION', 'TIPO', 'MCA_0KM', 'REC_TR_REAL', 'REC_TC_REAL',
#        'REC_RC_REAL', 'COMPRO_PLAN', 'COMPRO_PACK', 'REC_TC_VIGENTE', 'REC2_1',
#        'REDU_TIPO'],
#       dtype='object')

# %% [markdown]
# *Based on last output, fill this list to mark most relevant columns*

# %%
to_use = ['NRO_PRESUP', 'CIF_ID', 'COD_CIA', 'COD_SECC', 'COD_RAMO',
       'FECHA_EQUIPO', 'FECHA_SOLIC', 'COD_AGENCIA_PRESU', 'COD_AGENCIA_SOLIC',
       'COD_INICIADOR', 'ESTADO', 'COD_MARCA', 'COD_MOD', 'COD_PLAN',
       'SUMA_ASEG', 'TIPO_COMBUSTIBLE', 'GRUPO_COMBUSTIBLE', 'ORIGEN',
       'FOR_COBRO', 'NEGOCIO', 'COD_PROD', 'COD_POSTAL', 'AGRUPADOR_DIRECTO',
       'COD_AGENCIA_GES', 'FECHA_COTIZ_ANT', 'CANAL_ORIGEN', 'ORIGEN_DESC',
       'REGION', 'NOM_ORIGEN_PRESU', 'SOLICITA_MISMO_AUTO', 'NUM_SECU_POL',
       'EDAD', 'SEXO', 'ESTADO_CIVIL', 'BANCO', 'MARCA_MODELO', 'PUERTAS',
       'LOCALIDAD', 'PROVINCIA', 'MARCA', 'VERSION', 'NACIONAL_IMPORT',
       'TRACCION', 'TIPO', 'MCA_0KM', 'REC_TR_REAL', 'REC_TC_REAL',
       'REC_RC_REAL', 'COMPRO_PLAN', 'COMPRO_PACK', 'REC_TC_VIGENTE', 'REC2_1',
       'REDU_TIPO']

# %% [markdown]
# ### Now write the file

# %% [markdown]
# **If it was a big file, read it completely with this line**

# %%
chunks = pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000)
df = pd.concat(chunks)

# %%
f = open(f'../../docs/{table} feature description.csv','w')
f.write('Column;Used;Null Rate; dtype; Unique values; values\n')
for column in df.columns:
    
    null_rate = round(df[column].isna().mean() * 100, 2)
    
    unique_vals = df[column].nunique()
    
    if (column in to_use) and null_rate < 50 and unique_vals > 1:
        used = 'X'
    else:
        used=''
    
    dtype = df[column].dtype
    
    if(dtype == 'object'):
        values = df[column].value_counts().head(10)
    else:
        values = f'[{df[column].min()};{df[column].max()}]' 
        
    f.write(f'{column};{used};{null_rate};{dtype};{unique_vals};"{values}"\n')
    
f.close()
