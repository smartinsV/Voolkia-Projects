# %%
import pandas as pd
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %% [markdown]
# ## Table description generation

# %% [markdown]
# Enter the following info:
#  - Table name
#  - Location
#  - Separator
#  - Encoding (optional)
#  - Decimal mark (optional)

# %%
table = "TB_PROSPECT.tsv"
location = "../../data/raw"
sep = '\t'
encoding = 'latin1'
decimal = ','

# %% [markdown]
# ### Make a first view of the dataset to check most interesting columns

# %% [markdown]
# **Run this if it's a big file**

# %%
for chunk in pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000):
    df = chunk
    break
# Out:
# C:\Users\Santi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (13,18,26,28,29,39,40,46,52,53,57,58,60,64,65,66,69,70,72,73,74,76,77,78,80,81,82,83,84,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **Run this if it's a relatively small file**

# %%
df = pd.read_csv(f"{location}/{table}",
                sep=sep,
                encoding=encoding,
                decimal=decimal)
# Out:
# C:\Users\Santi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (26,36,46,49,53,59,63,67,74,80,105,110,112) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(15)
# Out:
#           ID TIPO_DOCUMENTO  NUMERO_DOCUMENTO APELLIDO NOMBRES ORIGEN SEXO  \
# 0     781234            DOC          11111111    LOPEZ   JUAN     083    F
# 1    9089921            DOC          11111111    LOPEZ   JUAN     083    F
# 2     781235            DOC          11111111    LOPEZ   JUAN     083    M
# 3    9089922            DOC          11111111    LOPEZ   JUAN     083    M
# 4    9089923            DOC          11111111    LOPEZ   JUAN     083    M
# 5   10453622            DOC          11111111    LOPEZ   JUAN     043    M
# 6   10453623            DOC          11111111    LOPEZ   JUAN     043    F
# 7          8            DOC          11111111    LOPEZ   JUAN     082    F
# 8   10453624            DOC          11111111    LOPEZ   JUAN     043    F
# 9   10453627            DOC          11111111    LOPEZ   JUAN     043    M
# 10  10453629            DOC          11111111    LOPEZ   JUAN     043    F
# 11  10453630            DOC          11111111    LOPEZ   JUAN     095    M
# 12  10453632            DOC          11111111    LOPEZ   JUAN     043    M
# 13  10453633            DOC          11111111    LOPEZ   JUAN     043    M
# 14        23            DOC          11111111    LOPEZ   JUAN     003    M
#
#    CLIENTE    CUIT_CUIL FECHA_NACIMIENTO FECHA_DEFUNCION ACT_U_DOMICILIOS  \
# 0      NaN  20111111110       05/05/1929             NaN              NaN
# 1      NaN  20111111110       20/11/1990             NaN              NaN
# 2      NaN  20111111110       13/03/1953             NaN       VILLANUEVA
# 3      NaN  20111111110       06/05/1957             NaN     OPS$QUIROZJM
# 4      NaN  20111111110       09/06/1984             NaN     OPS$VAZQUEZF
# 5        S  20111111110       08/03/1965             NaN       OPS$MITLON
# 6        S  20111111110       29/07/1969             NaN      OPS$LOPEZAL
# 7        S  20111111110       19/12/1974             NaN              NaN
# 8        S  20111111110       05/04/1969             NaN     OPS$PASSAREL
# 9        S  20111111110       06/05/1955             NaN              NaN
# 10       S  20111111110       10/03/1957             NaN              NaN
# 11     NaN  20111111110       20/06/1953             NaN              NaN
# 12       S  20111111110       04/03/1968             NaN              NaN
# 13       S  20111111110       18/08/1958             NaN              NaN
# 14     NaN  20111111110       18/02/1948             NaN              NaN
#
#     ACT_U_EDAD ACT_U_TELEFONOS PADRON ESTADO_CIVIL DOMICILIO_NUMERO  \
# 0          NaN             NaN    NaN      Soltero              NaN
# 1          NaN             NaN    NaN      Soltero              NaN
# 2          NaN             NaN    NaN       Casado              NaN
# 3          NaN             NaN    NaN       Casado             5121
# 4          NaN             NaN    NaN      Soltero              NaN
# 5          NaN             NaN    NaN       Casado               39
# 6          NaN             NaN    NaN       Casado               13
# 7          NaN             NaN    NaN      Soltero              NaN
# 8          NaN             NaN    NaN       Casado              471
# 9          NaN             NaN    NaN       Casado              NaN
# 10         NaN             NaN    NaN          NaN              NaN
# 11         NaN             NaN      S       Casado              NaN
# 12         NaN             NaN    NaN       Casado              NaN
# 13         NaN             NaN    NaN   Divorciado              NaN
# 14         NaN             NaN    NaN       Casado              NaN
#
#                   ACT_F_SEXO  DOMICILIO_CODIGO_POSTAL DOMICILIO_DEPTO  \
# 0   02/07/1998 03:55:01 p.m.                      NaN             NaN
# 1   12/10/2001 10:02:25 a.m.                      NaN             NaN
# 2   03/04/1998 05:01:32 a.m.                      NaN             NaN
# 3   12/10/2001 10:02:25 a.m.                3400001.0             NaN
# 4   12/10/2001 10:02:26 a.m.                1635000.0             NaN
# 5   19/11/2002 12:37:31 p.m.                1870011.0             NaN
# 6   19/11/2002 12:37:31 p.m.                5700005.0             NaN
# 7   09/12/1999 11:14:06 a.m.                      NaN             NaN
# 8   19/11/2002 12:37:32 p.m.                1722006.0             NaN
# 9   19/11/2002 12:38:44 p.m.                      NaN             NaN
# 10  19/11/2002 12:39:50 p.m.                      NaN             NaN
# 11  19/11/2002 12:41:03 p.m.                      NaN             NaN
# 12  19/11/2002 12:42:57 p.m.                      NaN             NaN
# 13  19/11/2002 12:43:11 p.m.                      NaN             NaN
# 14  22/01/1998 02:04:39 p.m.                      NaN             NaN
#
#    DOMICILIO_PISO  CARACTERISTICA_TELEFONO  NUMERO_TELEFONO TIPO_PERSONA  \
# 0             NaN                      NaN              NaN            F
# 1             NaN                      NaN              NaN            F
# 2             NaN                      NaN              NaN            F
# 3             NaN                      NaN              NaN            F
# 4             NaN                      NaN              NaN            F
# 5             NaN                      NaN              NaN            F
# 6             NaN                      NaN              NaN            F
# 7             NaN                      NaN              NaN            F
# 8             NaN                      NaN              NaN            F
# 9             NaN                      NaN              NaN            F
# 10            NaN                      NaN              NaN            F
# 11            NaN                      NaN              NaN            F
# 12            NaN                      NaN              NaN            F
# 13            NaN                      NaN              NaN            F
# 14            NaN                      NaN              NaN            F
#
#                   FECHA_ALTA       FECHA_ACTUALIZACION NACIONALIDAD  \
# 0   20/11/1997 07:02:35 p.m.  12/09/1999 11:51:37 a.m.          NaN
# 1   12/10/2001 10:02:25 a.m.  19/12/2001 10:32:53 a.m.          NaN
# 2   20/11/1997 07:02:35 p.m.  28/01/2000 01:25:42 a.m.          NaN
# 3   12/10/2001 10:02:25 a.m.  03/08/2012 06:28:17 p.m.          NaN
# 4   12/10/2001 10:02:26 a.m.                       NaN          NaN
# 5                        NaN  31/10/2005 02:12:44 p.m.          NaN
# 6                        NaN  02/10/2014 12:21:29 p.m.          NaN
# 7                 13/02/1996  27/01/2005 04:39:53 p.m.          NaN
# 8                        NaN  07/01/2014 12:00:15 p.m.          NaN
# 9                        NaN  24/08/2017 10:13:14 a.m.          NaN
# 10                       NaN                       NaN          NaN
# 11  19/11/2002 12:41:02 p.m.  19/11/2002 12:41:02 p.m.          NaN
# 12                       NaN  10/02/2009 12:15:43 p.m.          NaN
# 13                       NaN  30/12/2005 10:38:55 a.m.          NaN
# 14                13/02/1996  06/11/1999 05:35:23 a.m.          NaN
#
#    HABILITADO DATECO_TRABAJA ACT_F_TELEFONOS    ACT_F_APELLIDO_NOMBRES  \
# 0           S            NaN             NaN  19/01/2000 06:33:33 p.m.
# 1           S            NaN             NaN  12/10/2001 10:02:25 a.m.
# 2           S            NaN             NaN  28/01/2000 01:25:42 a.m.
# 3           S            NaN             NaN  12/10/2001 10:02:25 a.m.
# 4           S            NaN             NaN  12/10/2001 10:02:26 a.m.
# 5         NaN            NaN             NaN  31/10/2005 02:12:44 p.m.
# 6         NaN            NaN             NaN  02/10/2014 12:21:29 p.m.
# 7           S            NaN             NaN  09/12/1999 11:14:06 a.m.
# 8         NaN            NaN             NaN  17/04/2006 03:52:13 p.m.
# 9         NaN            NaN             NaN  24/08/2017 10:13:15 a.m.
# 10        NaN            NaN             NaN  19/11/2002 12:39:50 p.m.
# 11        NaN              N             NaN  19/11/2002 12:41:03 p.m.
# 12        NaN            NaN             NaN  22/06/2006 10:59:46 a.m.
# 13        NaN            NaN             NaN  19/11/2002 12:43:11 p.m.
# 14          S            NaN             NaN  08/10/1999 06:10:07 a.m.
#
#           ACT_F_ESTADO_CIVIL          ACT_F_HABILITADO  \
# 0   02/07/1998 03:55:01 p.m.  02/07/1998 03:55:01 p.m.
# 1   12/10/2001 10:02:25 a.m.  12/10/2001 10:02:25 a.m.
# 2   03/04/1998 05:01:32 a.m.  03/04/1998 05:01:32 a.m.
# 3   12/10/2001 10:02:25 a.m.  12/10/2001 10:02:25 a.m.
# 4   12/10/2001 10:02:26 a.m.  12/10/2001 10:02:26 a.m.
# 5   04/08/2005 08:01:38 p.m.                       NaN
# 6   02/10/2014 12:21:29 p.m.                       NaN
# 7   27/01/2005 04:39:54 p.m.  31/08/1999 06:29:57 a.m.
# 8   06/10/2006 10:00:41 a.m.                       NaN
# 9   24/08/2017 10:13:15 a.m.                       NaN
# 10                       NaN                       NaN
# 11  19/11/2002 12:41:03 p.m.                       NaN
# 12  22/06/2006 10:59:46 a.m.                       NaN
# 13  30/12/2005 10:38:56 a.m.                       NaN
# 14  08/10/1999 06:10:07 a.m.  11/08/1998 10:49:27 a.m.
#
#    DOMICILIO_OBSERVACIONES DOMICILIO_BARRIO  \
# 0                      NaN              NaN
# 1                      NaN              NaN
# 2                      NaN              NaN
# 3                 B° APIPE              NaN
# 4                      NaN              NaN
# 5                      NaN              NaN
# 6                      NaN              NaN
# 7                      NaN              NaN
# 8                      NaN              NaN
# 9                      NaN              NaN
# 10                     NaN              NaN
# 11                     NaN              NaN
# 12                     NaN              NaN
# 13                     NaN              NaN
# 14             ENCUESTABLE              NaN
#
#                            DOMICILIO_CALLE DOMICILIO_EDIFICIO  \
# 0                                      NaN                NaN
# 1                                      NaN                NaN
# 2                                      NaN                NaN
# 3                                  SICILIA                NaN
# 4                         TORO Y SARMIENTO                NaN
# 5                              GRAL GUEMES                NaN
# 6   BARRIO TESERA DE CALCUTA MZA A CASA 13                NaN
# 7                                      NaN                NaN
# 8                                    MAIPU                NaN
# 9                                      NaN                NaN
# 10                                     NaN                NaN
# 11                                     NaN                NaN
# 12                                     NaN                NaN
# 13                                     NaN                NaN
# 14                                     NaN                NaN
#
#    DOMICILIO_CALLE_ENTRE1 DOMICILIO_CALLE_ENTRE2 DATART_CLAVE_CLIENTE  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN                    NaN                  NaN
# 5                     NaN                    NaN                  NaN
# 6                     NaN                    NaN                  NaN
# 7                     NaN                    NaN                  NaN
# 8                     NaN                    NaN                  NaN
# 9                     NaN                    NaN                  NaN
# 10                    NaN                    NaN                  NaN
# 11                    NaN                    NaN                  NaN
# 12                    NaN                    NaN                  NaN
# 13                    NaN                    NaN                  NaN
# 14                    NaN                    NaN                  NaN
#
#     DATECO_CUIT_EMPLEADOR  DATECO_INGRESO_FAMILIAR  DATECO_INGRESO_PERSONAL  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN                      NaN                      NaN
# 3                     NaN                      NaN                      NaN
# 4                     NaN                      NaN                      NaN
# 5            3.062698e+10                      NaN                      NaN
# 6            3.062698e+10                      NaN                      NaN
# 7            3.064884e+10                      NaN                      NaN
# 8            3.062698e+10                      NaN                      NaN
# 9            3.062698e+10                      NaN                      NaN
# 10           3.062698e+10                      NaN                      NaN
# 11                    NaN                      NaN                      NaN
# 12           3.062698e+10                      NaN                      NaN
# 13           3.062698e+10                      NaN                      NaN
# 14                    NaN                      NaN                      NaN
#
#    DATECO_AUTONOMO DATECO_RAZON_SOCIAL_EMPLEADOR     DATECO_ACT_F_AUTONOMO  \
# 0              NaN          AMES JOSE FERNANDO .                       NaN
# 1              NaN                           NaN                       NaN
# 2              NaN                           NaN                       NaN
# 3              NaN                           NaN                       NaN
# 4              NaN                           NaN                       NaN
# 5              NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 6              NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 7              NaN     POLICIA PROV BUENOS AIRES                       NaN
# 8              NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 9              NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 10             NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 11               N                           NaN  19/11/2002 12:41:03 p.m.
# 12             NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 13             NaN   MINISTERIO DE SALUD PROV BA                       NaN
# 14             NaN                           NaN                       NaN
#
#    DATECO_ACT_F_INGRESO_FAMILIAR DATECO_ACT_F_INGRESO_PERSONAL  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
# 10                           NaN                           NaN
# 11                           NaN                           NaN
# 12                           NaN                           NaN
# 13                           NaN                           NaN
# 14                           NaN                           NaN
#
#         DATECO_ACT_F_TRABAJA DATECO_OBSERVACIONES DATECO_TELEFONO_EMPLEADOR  \
# 0                        NaN                  NaN                       NaN
# 1                        NaN                  NaN                       NaN
# 2                        NaN                  NaN                       NaN
# 3                        NaN                  NaN                       NaN
# 4                        NaN                  NaN                       NaN
# 5                        NaN                  NaN                       NaN
# 6                        NaN                  NaN                       NaN
# 7                        NaN                  NaN                       NaN
# 8                        NaN                  NaN                       NaN
# 9                        NaN                  NaN                       NaN
# 10                       NaN                  NaN                       NaN
# 11  19/11/2002 12:41:03 p.m.                  NaN                       NaN
# 12                       NaN                  NaN                       NaN
# 13                       NaN                  NaN                       NaN
# 14                       NaN                  NaN                       NaN
#
#    DATECO_DOMICILIO_EMPLEADOR  DATMAR_CANTIDAD_HIJOS DATMAR_CLUB  \
# 0                LIBERTAD 365                    NaN         NaN
# 1                         NaN                    NaN         NaN
# 2                         NaN                    NaN         NaN
# 3                         NaN                    NaN         NaN
# 4                         NaN                    NaN         NaN
# 5                         NaN                    NaN         NaN
# 6                         NaN                    NaN         NaN
# 7                         NaN                    NaN         NaN
# 8                         NaN                    NaN         NaN
# 9                         NaN                    NaN         NaN
# 10                        NaN                    NaN         NaN
# 11                        NaN                    NaN         NaN
# 12                        NaN                    NaN         NaN
# 13                        NaN                    NaN         NaN
# 14                        NaN                    NaN         NaN
#
#    DATMAR_COMPLETO_ESTUDIOS DATMAR_NIVEL_EDUCACION  DATMAR_PUNTAJE  \
# 0                         S             SECUNDARIO             NaN
# 1                       NaN                    NaN             NaN
# 2                       NaN                    NaN             NaN
# 3                       NaN                    NaN             NaN
# 4                       NaN                    NaN             NaN
# 5                       NaN                    NaN             NaN
# 6                       NaN                    NaN             NaN
# 7                       NaN                    NaN             NaN
# 8                       NaN                    NaN             NaN
# 9                       NaN                    NaN             NaN
# 10                      NaN                    NaN             NaN
# 11                        N                    NaN             NaN
# 12                      NaN                    NaN             NaN
# 13                      NaN                    NaN             NaN
# 14                      NaN                    NaN             NaN
#
#     DATMAR_VIAJES_ANUALES DATMAR_ACT_F_CANTIDAD_HIJOS DATMAR_ACT_F_CLUB  \
# 0                     NaN    22/12/1998 06:53:16 p.m.               NaN
# 1                     NaN                         NaN               NaN
# 2                     NaN                         NaN               NaN
# 3                     NaN                         NaN               NaN
# 4                     NaN                         NaN               NaN
# 5                     NaN                         NaN               NaN
# 6                     NaN                         NaN               NaN
# 7                     NaN                         NaN               NaN
# 8                     NaN                         NaN               NaN
# 9                     NaN                         NaN               NaN
# 10                    NaN                         NaN               NaN
# 11                    NaN                         NaN               NaN
# 12                    NaN                         NaN               NaN
# 13                    NaN                         NaN               NaN
# 14                    NaN                         NaN               NaN
#
#    DATMAR_ACT_F_COMPLETO_ESTUDIOS DATMAR_ACT_F_NIVEL_EDUCACION  \
# 0        07/10/1998 01:54:52 p.m.     07/10/1998 01:54:52 p.m.
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# 5                             NaN                          NaN
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 9                             NaN                          NaN
# 10                            NaN                          NaN
# 11       19/11/2002 12:41:03 p.m.                          NaN
# 12                            NaN                          NaN
# 13                            NaN                          NaN
# 14                            NaN                          NaN
#
#     DATMAR_ACT_F_PUNTAJE DATMAR_ACT_F_VIAJES_ANUALES     OPERADOR  \
# 0                    NaN                         NaN     OPERADOR
# 1                    NaN                         NaN          NaN
# 2                    NaN                         NaN  OPS$CONSOLA
# 3                    NaN                         NaN          NaN
# 4                    NaN                         NaN          NaN
# 5                    NaN                         NaN          NaN
# 6                    NaN                         NaN          NaN
# 7                    NaN                         NaN     OPERADOR
# 8                    NaN                         NaN          NaN
# 9                    NaN                         NaN          NaN
# 10                   NaN                         NaN          NaN
# 11                   NaN                         NaN          NaN
# 12                   NaN                         NaN          NaN
# 13                   NaN                         NaN          NaN
# 14                   NaN                         NaN     OPERADOR
#
#    DATECO_TIPO_ACTIVIDAD DATMAR_VACACIONES DATMAR_HOBBIE  DOMICILIO_TRAMO_ID  \
# 0                   COME               NaN           NaN                 NaN
# 1                    NaN               NaN           NaN                 NaN
# 2                    NaN               NaN           NaN                 NaN
# 3                    NaN               NaN           NaN                 NaN
# 4                    NaN               NaN           NaN                 NaN
# 5                    NaN               NaN           NaN                 NaN
# 6                    NaN               NaN           NaN                 NaN
# 7                    NaN               NaN           NaN                 NaN
# 8                   MEDI               NaN           NaN                 NaN
# 9                    NaN               NaN           NaN                 NaN
# 10                   NaN               NaN           NaN                 NaN
# 11                   NaN               NaN           NaN                 NaN
# 12                   NaN               NaN           NaN                 NaN
# 13                   NaN               NaN           NaN                 NaN
# 14                   NaN               NaN           NaN                 NaN
#
#     DOMICILIO_ID_ENTRE_1  DOMICILIO_ID_ENTRE_2                     ACT_F  \
# 0                    NaN                   NaN  02/05/2006 08:57:59 p.m.
# 1                    NaN                   NaN  02/05/2006 08:57:59 p.m.
# 2                    NaN                   NaN  02/05/2006 08:57:59 p.m.
# 3                    NaN                   NaN  03/08/2012 06:31:01 p.m.
# 4                    NaN                   NaN  02/11/2012 12:38:52 p.m.
# 5                    NaN                   NaN  06/12/2017 05:35:35 p.m.
# 6                    NaN                   NaN  02/10/2014 12:22:48 p.m.
# 7                    NaN                   NaN  02/05/2006 08:43:59 p.m.
# 8                    NaN                   NaN  15/01/2015 01:57:42 p.m.
# 9                    NaN                   NaN  24/08/2017 10:13:15 a.m.
# 10                   NaN                   NaN  25/01/2008 11:04:22 a.m.
# 11                   NaN                   NaN  02/05/2006 09:57:23 p.m.
# 12                   NaN                   NaN  10/02/2009 03:50:12 p.m.
# 13                   NaN                   NaN  17/07/2014 08:37:34 a.m.
# 14                   NaN                   NaN  02/05/2006 06:17:42 p.m.
#
#            ACT_U DOMICILIO_SEMAFORO TELEFONO_SEMAFORO  ESTADO_CIVIL_SEMAFORO  \
# 0        PATALLO                NaN               NaN                    NaN
# 1        PATALLO                NaN               NaN                    NaN
# 2        PATALLO                NaN               NaN                    NaN
# 3   OPS$QUIROZJM                NaN               NaN                    NaN
# 4   OPS$VAZQUEZF                  A               NaN                    NaN
# 5      OPS$ROMEU                NaN               NaN                    NaN
# 6    OPS$LOPEZAL                  V               NaN                    NaN
# 7        PATALLO                NaN               NaN                    NaN
# 8     OPS$AIRALA                NaN               NaN                    NaN
# 9   OPS$ESTIRIGO                NaN               NaN                    NaN
# 10    OPS$ARRUIZ                NaN               NaN                    NaN
# 11       PATALLO                NaN               NaN                    NaN
# 12  OPS$PIACENTE                NaN               NaN                    NaN
# 13     OPS$PRUMG                NaN               NaN                    NaN
# 14       PATALLO                NaN               NaN                    NaN
#
#     FECHA_NACIMIENTO_SEMAFORO TIPO_DOMICILIO  PREFIJO_INTERNACIONAL  \
# 0                         NaN           PART                    NaN
# 1                         NaN            NaN                    NaN
# 2                         NaN           PART                    NaN
# 3                         NaN            NaN                    NaN
# 4                         NaN            NaN                    NaN
# 5                         NaN            NaN                    NaN
# 6                         NaN            NaN                    NaN
# 7                         NaN           LABO                    NaN
# 8                         NaN            NaN                    NaN
# 9                         NaN            NaN                    NaN
# 10                        NaN            NaN                    NaN
# 11                        NaN            NaN                    NaN
# 12                        NaN            NaN                    NaN
# 13                        NaN            NaN                    NaN
# 14                        NaN           PART                    NaN
#
#     PREFIJO_INTERURBANO TIPO_TELEFONO CODIGO_NACION            ACT_F_APELLIDO  \
# 0                   NaN           NaN           NaN  19/01/2000 06:33:33 p.m.
# 1                   NaN           NaN          ARGE  12/10/2001 10:02:25 a.m.
# 2                   NaN           NaN           NaN  28/01/2000 01:25:42 a.m.
# 3                   NaN           NaN          ARGE  12/10/2001 10:02:25 a.m.
# 4                   NaN           NaN          ARGE  12/10/2001 10:02:26 a.m.
# 5                   NaN           NaN          ARGE  19/11/2002 12:37:31 p.m.
# 6                   NaN           NaN          ARGE  19/11/2002 12:37:31 p.m.
# 7                   NaN           NaN          ARGE  09/12/1999 11:14:06 a.m.
# 8                   NaN           NaN          ARGE  19/11/2002 12:37:32 p.m.
# 9                   NaN           NaN          ARGE  19/11/2002 12:38:44 p.m.
# 10                  NaN           NaN          ARGE  19/11/2002 12:39:50 p.m.
# 11                  NaN           NaN          ARGE  19/11/2002 12:41:03 p.m.
# 12                  NaN           NaN          ARGE  22/06/2006 10:59:46 a.m.
# 13                  NaN           NaN          ARGE  19/11/2002 12:43:11 p.m.
# 14                  NaN           NaN          ARGE  08/10/1999 06:10:07 a.m.
#
#                ACT_F_NOMBRES  ANO_DE_NACIMIENTO  TELEFONO_ID  DOMICILIO_ID  \
# 0   19/01/2000 06:33:33 p.m.             1929.0    3911577.0     9158965.0
# 1   12/10/2001 10:02:25 a.m.             1990.0          NaN    13841283.0
# 2   28/01/2000 01:25:42 a.m.             1953.0     240565.0        5036.0
# 3   12/10/2001 10:02:25 a.m.             1957.0    9904204.0    12087155.0
# 4   12/10/2001 10:02:26 a.m.             1984.0          NaN    18714683.0
# 5   31/10/2005 02:12:44 p.m.             1965.0    7255675.0    15002107.0
# 6   02/10/2014 12:21:29 p.m.             1969.0          NaN    19716420.0
# 7   09/12/1999 11:14:06 a.m.             1974.0    2432040.0     5718928.0
# 8   17/04/2006 03:52:13 p.m.             1969.0    6667930.0    14598967.0
# 9   24/08/2017 10:13:15 a.m.             1955.0          NaN    15789359.0
# 10  19/11/2002 12:39:50 p.m.             1957.0          NaN    15460415.0
# 11  19/11/2002 12:41:03 p.m.             1953.0          NaN           NaN
# 12  22/06/2006 10:59:46 a.m.             1968.0    7714626.0    14672308.0
# 13  19/11/2002 12:43:11 p.m.             1958.0    6596384.0           NaN
# 14  11/08/1998 10:49:27 a.m.             1948.0         16.0     5076458.0
#
#     DOMICILIO_LATITUD  DOMICILIO_LONGITUD  POSICION_IVA  POSICION_IB  \
# 0                 NaN                 NaN           5.0          3.0
# 1                 NaN                 NaN           5.0          3.0
# 2                 NaN                 NaN           5.0          NaN
# 3          -58.785420          -27.458243           5.0          3.0
# 4                 NaN                 NaN           5.0          NaN
# 5          -58.355398          -34.669269           5.0          3.0
# 6                 NaN                 NaN           5.0          NaN
# 7                 NaN                 NaN           5.0          NaN
# 8          -58.724428          -34.668356           5.0          3.0
# 9                 NaN                 NaN           5.0          NaN
# 10                NaN                 NaN           5.0          NaN
# 11                NaN                 NaN           5.0          3.0
# 12                NaN                 NaN           5.0          3.0
# 13                NaN                 NaN           5.0          3.0
# 14                NaN                 NaN           5.0          NaN
#
#     NUMERO_IB DATECO_ACT_U_TIPO_ACTIVIDAD DATECO_ACT_F_TIPO_ACTIVIDAD  \
# 0         NaN                  CEJASPARDO    07/10/1998 01:54:52 p.m.
# 1         NaN                         NaN                         NaN
# 2         NaN                         NaN                         NaN
# 3         NaN                         NaN                         NaN
# 4         NaN                         NaN                         NaN
# 5         NaN                         NaN                         NaN
# 6         NaN                         NaN                         NaN
# 7         NaN                         NaN                         NaN
# 8         NaN                OPS$CIAPRIAN    07/01/2014 12:00:15 p.m.
# 9         NaN                         NaN                         NaN
# 10        NaN                         NaN                         NaN
# 11        NaN                         NaN                         NaN
# 12        NaN                         NaN                         NaN
# 13        NaN                         NaN                         NaN
# 14        NaN                         NaN                         NaN
#
#         ACT_F_TIPO_DOCUMENTO    ACT_F_NUMERO_DOCUMENTO VALIDO  NEWSLETTER  \
# 0                        NaN                       NaN    NaN         NaN
# 1                        NaN                       NaN      S         NaN
# 2                        NaN                       NaN    NaN         NaN
# 3                        NaN                       NaN      S         NaN
# 4                        NaN                       NaN      S         NaN
# 5   19/11/2002 12:37:31 p.m.  19/11/2002 12:37:31 p.m.      S         NaN
# 6   19/11/2002 12:37:31 p.m.  19/11/2002 12:37:31 p.m.      S         NaN
# 7                        NaN  04/05/2000 10:58:27 a.m.      S         NaN
# 8   19/11/2002 12:37:32 p.m.  19/11/2002 12:37:32 p.m.      S         NaN
# 9   19/11/2002 12:38:44 p.m.  19/11/2002 12:38:44 p.m.      S         NaN
# 10  19/11/2002 12:39:50 p.m.  19/11/2002 12:39:50 p.m.      S         NaN
# 11                       NaN                       NaN      S         NaN
# 12  19/11/2002 12:42:58 p.m.  19/11/2002 12:42:58 p.m.      S         NaN
# 13  19/11/2002 12:43:11 p.m.  19/11/2002 12:43:11 p.m.      S         NaN
# 14                       NaN                       NaN    NaN         NaN
#
#     SEGMENTABLE ESTADO_CLIENTE  PADRE TIPO_ORGANIZACION  ACTIVIDAD_SEGURO  \
# 0           NaN            NaN    NaN               NaN               NaN
# 1           NaN            NaN    NaN               NaN               NaN
# 2           NaN            NaN    NaN               NaN               NaN
# 3           NaN            NaN    NaN               NaN               NaN
# 4           NaN            NaN    NaN               NaN               NaN
# 5           NaN            NaN    NaN               NaN               NaN
# 6           NaN            NaN    NaN               NaN               NaN
# 7           NaN            NaN    NaN               NaN               NaN
# 8           NaN            NaN    NaN               NaN               NaN
# 9           NaN            NaN    NaN               NaN               NaN
# 10          NaN            NaN    NaN               NaN               NaN
# 11          NaN            NaN    NaN               NaN               NaN
# 12          NaN            NaN    NaN               NaN               NaN
# 13          NaN            NaN    NaN               NaN               NaN
# 14          NaN            NaN    NaN               NaN               NaN
#
#    MCA_LAVADO PKUNIVAL FORMA_JURIDICA  TELEFONO_CEL_ID    MAIL_ID  \
# 0         NaN      NaN            NaN              NaN        NaN
# 1         NaN      NaN            NaN              NaN        NaN
# 2         NaN      NaN            NaN              NaN        NaN
# 3         NaN        S            NaN              NaN        NaN
# 4         NaN      NaN            NaN              NaN        NaN
# 5         NaN        S            NaN        9340676.0  2608244.0
# 6         NaN        S            NaN              NaN        NaN
# 7         NaN        S            NaN              NaN        NaN
# 8         NaN        S            NaN       11324400.0  1740320.0
# 9         NaN        S            NaN              NaN        NaN
# 10        NaN      NaN            NaN              NaN        NaN
# 11        NaN      NaN            NaN              NaN        NaN
# 12        NaN        S            NaN              NaN        NaN
# 13        NaN        S            NaN              NaN        NaN
# 14        NaN      NaN            NaN              NaN        NaN
#
#    LUGAR_NACIMIENTO POLITICAMENTE_EXPUESTA F_INSC_REGISTRAL  \
# 0               NaN                    NaN              NaN
# 1               NaN                    NaN              NaN
# 2               NaN                    NaN              NaN
# 3               NaN                    NaN              NaN
# 4               NaN                    NaN              NaN
# 5               NaN                    NaN              NaN
# 6               NaN                    NaN              NaN
# 7               NaN                    NaN              NaN
# 8               NaN                    NaN              NaN
# 9               NaN                    NaN              NaN
# 10              NaN                    NaN              NaN
# 11              NaN                    NaN              NaN
# 12              NaN                    NaN              NaN
# 13              NaN                    NaN              NaN
# 14              NaN                    NaN              NaN
#
#     NRO_INSC_REGISTRAL F_CONTRATO_SOCIAL MCA_SUSP_COBERTURA  \
# 0                  NaN               NaN                NaN
# 1                  NaN               NaN                NaN
# 2                  NaN               NaN                NaN
# 3                  NaN               NaN                NaN
# 4                  NaN               NaN                NaN
# 5                  NaN               NaN                NaN
# 6                  NaN               NaN                NaN
# 7                  NaN               NaN                NaN
# 8                  NaN               NaN                NaN
# 9                  NaN               NaN                NaN
# 10                 NaN               NaN                NaN
# 11                 NaN               NaN                NaN
# 12                 NaN               NaN                NaN
# 13                 NaN               NaN                NaN
# 14                 NaN               NaN                NaN
#
#     MOTIVO_MCA_LAVADO POLITICAMENTE_EXPUESTA_DDJJ DATECO_FECHA_TIPO_ACT  \
# 0                 NaN                         NaN                   NaN
# 1                 NaN                         NaN                   NaN
# 2                 NaN                         NaN                   NaN
# 3                 NaN                         NaN                   NaN
# 4                 NaN                         NaN                   NaN
# 5                 NaN                         NaN                   NaN
# 6                 NaN                         NaN                   NaN
# 7                 NaN                         NaN                   NaN
# 8                 NaN                         NaN                   NaN
# 9                 NaN                         NaN                   NaN
# 10                NaN                         NaN                   NaN
# 11                NaN                         NaN                   NaN
# 12                NaN                         NaN                   NaN
# 13                NaN                         NaN                   NaN
# 14                NaN                         NaN                   NaN
#
#              CONFIRMADO_FNAC  USUARIO_RED_SOCIAL_ID  OBSERVACION_LAVADO
# 0                        NaN                    NaN                 NaN
# 1                        NaN                    NaN                 NaN
# 2                        NaN                    NaN                 NaN
# 3                        NaN                    NaN                 NaN
# 4                        NaN                    NaN                 NaN
# 5   06/12/2017 05:35:35 p.m.                    NaN                 NaN
# 6                        NaN                    NaN                 NaN
# 7                        NaN                    NaN                 NaN
# 8                        NaN                    NaN                 NaN
# 9                        NaN                    NaN                 NaN
# 10                       NaN                    NaN                 NaN
# 11                       NaN                    NaN                 NaN
# 12                       NaN                    NaN                 NaN
# 13                       NaN                    NaN                 NaN
# 14                       NaN                    NaN                 NaN

# %%
df.dtypes
# Out:
# ID                                  int64
# TIPO_DOCUMENTO                     object
# NUMERO_DOCUMENTO                    int64
# APELLIDO                           object
# NOMBRES                            object
# ORIGEN                             object
# SEXO                               object
# CLIENTE                            object
# CUIT_CUIL                           int64
# FECHA_NACIMIENTO                   object
# FECHA_DEFUNCION                    object
# ACT_U_DOMICILIOS                   object
# ACT_U_EDAD                        float64
# ACT_U_TELEFONOS                    object
# PADRON                             object
# ESTADO_CIVIL                       object
# DOMICILIO_NUMERO                   object
# ACT_F_SEXO                         object
# DOMICILIO_CODIGO_POSTAL           float64
# DOMICILIO_DEPTO                    object
# DOMICILIO_PISO                     object
# CARACTERISTICA_TELEFONO           float64
# NUMERO_TELEFONO                   float64
# TIPO_PERSONA                       object
# FECHA_ALTA                         object
# FECHA_ACTUALIZACION                object
# NACIONALIDAD                       object
# HABILITADO                         object
# DATECO_TRABAJA                     object
# ACT_F_TELEFONOS                    object
# ACT_F_APELLIDO_NOMBRES             object
# ACT_F_ESTADO_CIVIL                 object
# ACT_F_HABILITADO                   object
# DOMICILIO_OBSERVACIONES            object
# DOMICILIO_BARRIO                   object
# DOMICILIO_CALLE                    object
# DOMICILIO_EDIFICIO                 object
# DOMICILIO_CALLE_ENTRE1             object
# DOMICILIO_CALLE_ENTRE2             object
# DATART_CLAVE_CLIENTE               object
# DATECO_CUIT_EMPLEADOR             float64
# DATECO_INGRESO_FAMILIAR           float64
# DATECO_INGRESO_PERSONAL           float64
# DATECO_AUTONOMO                    object
# DATECO_RAZON_SOCIAL_EMPLEADOR      object
# DATECO_ACT_F_AUTONOMO              object
# DATECO_ACT_F_INGRESO_FAMILIAR      object
# DATECO_ACT_F_INGRESO_PERSONAL      object
# DATECO_ACT_F_TRABAJA               object
# DATECO_OBSERVACIONES               object
# DATECO_TELEFONO_EMPLEADOR          object
# DATECO_DOMICILIO_EMPLEADOR         object
# DATMAR_CANTIDAD_HIJOS             float64
# DATMAR_CLUB                        object
# DATMAR_COMPLETO_ESTUDIOS           object
# DATMAR_NIVEL_EDUCACION             object
# DATMAR_PUNTAJE                    float64
# DATMAR_VIAJES_ANUALES             float64
# DATMAR_ACT_F_CANTIDAD_HIJOS        object
# DATMAR_ACT_F_CLUB                  object
# DATMAR_ACT_F_COMPLETO_ESTUDIOS     object
# DATMAR_ACT_F_NIVEL_EDUCACION       object
# DATMAR_ACT_F_PUNTAJE              float64
# DATMAR_ACT_F_VIAJES_ANUALES        object
# OPERADOR                           object
# DATECO_TIPO_ACTIVIDAD              object
# DATMAR_VACACIONES                  object
# DATMAR_HOBBIE                      object
# DOMICILIO_TRAMO_ID                float64
# DOMICILIO_ID_ENTRE_1              float64
# DOMICILIO_ID_ENTRE_2              float64
# ACT_F                              object
# ACT_U                              object
# DOMICILIO_SEMAFORO                 object
# TELEFONO_SEMAFORO                  object
# ESTADO_CIVIL_SEMAFORO             float64
# FECHA_NACIMIENTO_SEMAFORO         float64
# TIPO_DOMICILIO                     object
# PREFIJO_INTERNACIONAL             float64
# PREFIJO_INTERURBANO               float64
# TIPO_TELEFONO                      object
# CODIGO_NACION                      object
# ACT_F_APELLIDO                     object
# ACT_F_NOMBRES                      object
# ANO_DE_NACIMIENTO                 float64
# TELEFONO_ID                       float64
# DOMICILIO_ID                      float64
# DOMICILIO_LATITUD                 float64
# DOMICILIO_LONGITUD                float64
# POSICION_IVA                      float64
# POSICION_IB                       float64
# NUMERO_IB                         float64
# DATECO_ACT_U_TIPO_ACTIVIDAD        object
# DATECO_ACT_F_TIPO_ACTIVIDAD        object
# ACT_F_TIPO_DOCUMENTO               object
# ACT_F_NUMERO_DOCUMENTO             object
# VALIDO                             object
# NEWSLETTER                        float64
# SEGMENTABLE                       float64
# ESTADO_CLIENTE                     object
# PADRE                             float64
# TIPO_ORGANIZACION                  object
# ACTIVIDAD_SEGURO                  float64
# MCA_LAVADO                         object
# PKUNIVAL                           object
# FORMA_JURIDICA                     object
# TELEFONO_CEL_ID                   float64
# MAIL_ID                           float64
# LUGAR_NACIMIENTO                   object
# POLITICAMENTE_EXPUESTA             object
# F_INSC_REGISTRAL                   object
# NRO_INSC_REGISTRAL                float64
# F_CONTRATO_SOCIAL                  object
# MCA_SUSP_COBERTURA                 object
# MOTIVO_MCA_LAVADO                 float64
# POLITICAMENTE_EXPUESTA_DDJJ        object
# DATECO_FECHA_TIPO_ACT              object
# CONFIRMADO_FNAC                    object
# USUARIO_RED_SOCIAL_ID             float64
# OBSERVACION_LAVADO                float64
# dtype: object

# %%
"','".join(df.columns)
# Out:
# "ID','TIPO_DOCUMENTO','NUMERO_DOCUMENTO','APELLIDO','NOMBRES','ORIGEN','SEXO','CLIENTE','CUIT_CUIL','FECHA_NACIMIENTO','FECHA_DEFUNCION','ACT_U_DOMICILIOS','ACT_U_EDAD','ACT_U_TELEFONOS','PADRON','ESTADO_CIVIL','DOMICILIO_NUMERO','ACT_F_SEXO','DOMICILIO_CODIGO_POSTAL','DOMICILIO_DEPTO','DOMICILIO_PISO','CARACTERISTICA_TELEFONO','NUMERO_TELEFONO','TIPO_PERSONA','FECHA_ALTA','FECHA_ACTUALIZACION','NACIONALIDAD','HABILITADO','DATECO_TRABAJA','ACT_F_TELEFONOS','ACT_F_APELLIDO_NOMBRES','ACT_F_ESTADO_CIVIL','ACT_F_HABILITADO','DOMICILIO_OBSERVACIONES','DOMICILIO_BARRIO','DOMICILIO_CALLE','DOMICILIO_EDIFICIO','DOMICILIO_CALLE_ENTRE1','DOMICILIO_CALLE_ENTRE2','DATART_CLAVE_CLIENTE','DATECO_CUIT_EMPLEADOR','DATECO_INGRESO_FAMILIAR','DATECO_INGRESO_PERSONAL','DATECO_AUTONOMO','DATECO_RAZON_SOCIAL_EMPLEADOR','DATECO_ACT_F_AUTONOMO','DATECO_ACT_F_INGRESO_FAMILIAR','DATECO_ACT_F_INGRESO_PERSONAL','DATECO_ACT_F_TRABAJA','DATECO_OBSERVACIONES','DATECO_TELEFONO_EMPLEADOR','DATECO_DOMICILIO_EMPLEADOR','DATMAR_CANTIDAD_HIJOS','DATMAR_CLUB','DATMAR_COMPLETO_ESTUDIOS','DATMAR_NIVEL_EDUCACION','DATMAR_PUNTAJE','DATMAR_VIAJES_ANUALES','DATMAR_ACT_F_CANTIDAD_HIJOS','DATMAR_ACT_F_CLUB','DATMAR_ACT_F_COMPLETO_ESTUDIOS','DATMAR_ACT_F_NIVEL_EDUCACION','DATMAR_ACT_F_PUNTAJE','DATMAR_ACT_F_VIAJES_ANUALES','OPERADOR','DATECO_TIPO_ACTIVIDAD','DATMAR_VACACIONES','DATMAR_HOBBIE','DOMICILIO_TRAMO_ID','DOMICILIO_ID_ENTRE_1','DOMICILIO_ID_ENTRE_2','ACT_F','ACT_U','DOMICILIO_SEMAFORO','TELEFONO_SEMAFORO','ESTADO_CIVIL_SEMAFORO','FECHA_NACIMIENTO_SEMAFORO','TIPO_DOMICILIO','PREFIJO_INTERNACIONAL','PREFIJO_INTERURBANO','TIPO_TELEFONO','CODIGO_NACION','ACT_F_APELLIDO','ACT_F_NOMBRES','ANO_DE_NACIMIENTO','TELEFONO_ID','DOMICILIO_ID','DOMICILIO_LATITUD','DOMICILIO_LONGITUD','POSICION_IVA','POSICION_IB','NUMERO_IB','DATECO_ACT_U_TIPO_ACTIVIDAD','DATECO_ACT_F_TIPO_ACTIVIDAD','ACT_F_TIPO_DOCUMENTO','ACT_F_NUMERO_DOCUMENTO','VALIDO','NEWSLETTER','SEGMENTABLE','ESTADO_CLIENTE','PADRE','TIPO_ORGANIZACION','ACTIVIDAD_SEGURO','MCA_LAVADO','PKUNIVAL','FORMA_JURIDICA','TELEFONO_CEL_ID','MAIL_ID','LUGAR_NACIMIENTO','POLITICAMENTE_EXPUESTA','F_INSC_REGISTRAL','NRO_INSC_REGISTRAL','F_CONTRATO_SOCIAL','MCA_SUSP_COBERTURA','MOTIVO_MCA_LAVADO','POLITICAMENTE_EXPUESTA_DDJJ','DATECO_FECHA_TIPO_ACT','CONFIRMADO_FNAC','USUARIO_RED_SOCIAL_ID','OBSERVACION_LAVADO"

# %% [markdown]
# *Based on last output, fill this list to mark most relevant columns*

# %%
to_use = ['ID','TIPO_DOCUMENTO','NUMERO_DOCUMENTO','APELLIDO','NOMBRES','ORIGEN','SEXO','CLIENTE','CUIT_CUIL','FECHA_NACIMIENTO','FECHA_DEFUNCION','ACT_U_DOMICILIOS','ACT_U_EDAD','ACT_U_TELEFONOS','PADRON','ESTADO_CIVIL','DOMICILIO_NUMERO','ACT_F_SEXO','DOMICILIO_CODIGO_POSTAL','DOMICILIO_DEPTO','DOMICILIO_PISO','CARACTERISTICA_TELEFONO','NUMERO_TELEFONO','TIPO_PERSONA','FECHA_ALTA','FECHA_ACTUALIZACION','NACIONALIDAD','HABILITADO','DATECO_TRABAJA','ACT_F_TELEFONOS','ACT_F_APELLIDO_NOMBRES','ACT_F_ESTADO_CIVIL','ACT_F_HABILITADO','DOMICILIO_OBSERVACIONES','DOMICILIO_BARRIO','DOMICILIO_CALLE','DOMICILIO_EDIFICIO','DOMICILIO_CALLE_ENTRE1','DOMICILIO_CALLE_ENTRE2','DATART_CLAVE_CLIENTE','DATECO_CUIT_EMPLEADOR','DATECO_INGRESO_FAMILIAR','DATECO_INGRESO_PERSONAL','DATECO_AUTONOMO','DATECO_RAZON_SOCIAL_EMPLEADOR','DATECO_ACT_F_AUTONOMO','DATECO_ACT_F_INGRESO_FAMILIAR','DATECO_ACT_F_INGRESO_PERSONAL','DATECO_ACT_F_TRABAJA','DATECO_OBSERVACIONES','DATECO_TELEFONO_EMPLEADOR','DATECO_DOMICILIO_EMPLEADOR','DATMAR_CANTIDAD_HIJOS','DATMAR_CLUB','DATMAR_COMPLETO_ESTUDIOS','DATMAR_NIVEL_EDUCACION','DATMAR_PUNTAJE','DATMAR_VIAJES_ANUALES','DATMAR_ACT_F_CANTIDAD_HIJOS','DATMAR_ACT_F_CLUB','DATMAR_ACT_F_COMPLETO_ESTUDIOS','DATMAR_ACT_F_NIVEL_EDUCACION','DATMAR_ACT_F_PUNTAJE','DATMAR_ACT_F_VIAJES_ANUALES','OPERADOR','DATECO_TIPO_ACTIVIDAD','DATMAR_VACACIONES','DATMAR_HOBBIE','DOMICILIO_TRAMO_ID','DOMICILIO_ID_ENTRE_1','DOMICILIO_ID_ENTRE_2','ACT_F','ACT_U','DOMICILIO_SEMAFORO','TELEFONO_SEMAFORO','ESTADO_CIVIL_SEMAFORO','FECHA_NACIMIENTO_SEMAFORO','TIPO_DOMICILIO','PREFIJO_INTERNACIONAL','PREFIJO_INTERURBANO','TIPO_TELEFONO','CODIGO_NACION','ACT_F_APELLIDO','ACT_F_NOMBRES','ANO_DE_NACIMIENTO','TELEFONO_ID','DOMICILIO_ID','DOMICILIO_LATITUD','DOMICILIO_LONGITUD','POSICION_IVA','POSICION_IB','NUMERO_IB','DATECO_ACT_U_TIPO_ACTIVIDAD','DATECO_ACT_F_TIPO_ACTIVIDAD','ACT_F_TIPO_DOCUMENTO','ACT_F_NUMERO_DOCUMENTO','VALIDO','NEWSLETTER','SEGMENTABLE','ESTADO_CLIENTE','PADRE','TIPO_ORGANIZACION','ACTIVIDAD_SEGURO','MCA_LAVADO','PKUNIVAL','FORMA_JURIDICA','TELEFONO_CEL_ID','MAIL_ID','LUGAR_NACIMIENTO','POLITICAMENTE_EXPUESTA','F_INSC_REGISTRAL','NRO_INSC_REGISTRAL','F_CONTRATO_SOCIAL','MCA_SUSP_COBERTURA','MOTIVO_MCA_LAVADO','POLITICAMENTE_EXPUESTA_DDJJ','DATECO_FECHA_TIPO_ACT','CONFIRMADO_FNAC','USUARIO_RED_SOCIAL_ID','OBSERVACION_LAVADO']

# %% [markdown]
# ### Now write the file

# %% [markdown]
# **If it was a big file, read it completely with this line**

# %%
chunks = pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000)
df = pd.concat(chunks)
# Out:
# /home/voolkia/anaconda3/envs/test/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (26,36,46,49,53,59,63,67,74,80,105,110,112) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
f = open(f'../../docs/{table} feature description.csv','w')
f.write('Column;Used;Null Rate; Type; Unique values; Values\n')
for column in df.columns:
    
    null_rate = round(df[column].isna().mean()*100,2)
    
    unique_vals = df[column].nunique()
    
    if (column in to_use) and null_rate < .5 and unique_vals > 1:
        used = 'X'
    else:
        used=''
    
    dtype = df[column].dtype
    
    if(dtype == 'object'):
        values = f"Top 10:\n{df[column].value_counts(dropna=False).head(10).to_string()}"
    else:
        values = f'[{df[column].min()};{df[column].max()}]'
        
    f.write(f'{column};{used};{null_rate};{dtype};{unique_vals};"{values}"\n')
    
f.close()
