# %%
import pandas as pd
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %% [markdown]
# ## Table description generation

# %% [markdown]
# Enter the following info:
#  - Table name
#  - Location
#  - Separator
#  - Encoding (optional)
#  - Decimal mark (optional)

# %%
table = "DSS_SINIESTROS_AUTOS.csv "
location = "../../data/raw"
sep = ';'
encoding = 'latin1'
decimal = ','

# %% [markdown]
# ### Make a first view of the dataset to check most interesting columns

# %% [markdown]
# **Run this if it's a big file**

# %%
for chunk in pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000):
    df = chunk
    break
# Out:
# /home/voolkia/anaconda3/envs/test/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (44,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **Run this if it's a relatively small file**

# %%
df = pd.read_csv(f"{location}/{table}",
                sep=sep,
                encoding=encoding,
                decimal=decimal)
# Out:
# C:\Users\Santi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (21,22,27,32,33,34,36,37,39,41,42,46,88,89,95,99,125,126,132,151,158,160,161,174) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(15)
# Out:
#      NUM_SECU_POL  NUM_SECU_SINI  NUM_SECU_EXPED  NUM_SECU_LIQ  NUM_SECU_JUI  \
# 0   1891124879999  1892772189999   1892772219999           NaN           NaN
# 1   1862726779999  1892919229999   1892923599999           NaN           NaN
# 2   1877586669999  1892947709999   1892947749999           NaN           NaN
# 3   1867224549999  1893192429999   1893192439999           NaN           NaN
# 4   1842589309999  1893101989999   1893102589999           NaN           NaN
# 5   1879132169999  1893100429999   1893101209999           NaN           NaN
# 6   1780510489999  1893098649999   1893099089999           NaN           NaN
# 7   1884366249999  1935785559999   1935786189999           NaN           NaN
# 8   1885861839999  1935790859999   1935791279999           NaN           NaN
# 9   1897840659999  1935849059999   1935850059999           NaN           NaN
# 10  1927693449999  1935873779999   1935874379999           NaN           NaN
# 11  1862489019999  1935871009999   1935871249999           NaN           NaN
# 12  1895682519999  1935933529999   1935934129999           NaN           NaN
# 13  1908650079999  1935890179999   1935891179999           NaN           NaN
# 14  1900616649999  1935982279999   1935982289999           NaN           NaN
#
#     COD_CIA  COD_AGENCIA  COD_AGEN_EMI  COD_SECC  COD_RAMO  COD_COBERTURA  \
# 0         1         6030          5450         4         1           24.0
# 1         1         6030          6080         4         1            1.0
# 2         1         6030          6030         4         1            1.0
# 3         1         6030          6300         4         1           24.0
# 4         1         6030          6030         4         1           10.0
# 5         1         6030          6030         4         1            1.0
# 6         1         6030          6300         4         1           10.0
# 7         1         6030          6030         4         1           24.0
# 8         1         6030          5450         4         1           24.0
# 9         1         6030          6030         4         1           24.0
# 10        1         6030          6030         4         1           24.0
# 11        1         6030          5450         4         1           24.0
# 12        1         6030          6030         4         1           24.0
# 13        1         6030          5190         4         1            1.0
# 14        1         6030          5450         4         1           24.0
#
#    TIPO_SUCURSAL     NUM_SINI  COD_CAUSA_SINI       NUM_POL1  \
# 0              A  60300014689             501  5450053926801
# 1              A  60300014700             503  6080015598103
# 2              A  60300014702             501  6030020087302
# 3              A  60300014721             501  6300020679705
# 4              A  60300014708              55  6030019732003
# 5              A  60300014706             501  6030019732004
# 6              A  60300014705              55  6300019588601
# 7              A  60300015595             501  6030020142501
# 8              A  60300015596             501  5450049765412
# 9              A  60300015602             501  6030019952105
# 10             A  60300015606             501  6030020577101
# 11             A  60300015603             501  5450052732404
# 12             A  60300015610             501  6030020253503
# 13             A  60300015608             501  5190012938705
# 14             A  60300015616             501  5450054318802
#
#    FECHA_VIG_POL_DESDE FECHA_VIG_POL_HASTA  COD_RIES  FECHA_SINI  \
# 0           01/11/2018          01/12/2018         1  01/12/2018
# 1           11/11/2018          11/12/2018         1  21/11/2018
# 2           01/11/2018          01/12/2018         1  30/11/2018
# 3           26/11/2018          26/12/2018         1  03/12/2018
# 4           26/10/2018          26/11/2018         1  01/11/2018
# 5           26/11/2018          26/12/2018         1  30/11/2018
# 6           01/03/2018          01/04/2018         1  23/03/2018
# 7           03/12/2018          03/01/2019         1  29/12/2018
# 8           12/02/2019          12/03/2019         1  11/03/2019
# 9           15/02/2019          15/03/2019         1  14/03/2019
# 10          01/03/2019          01/04/2019         1  13/03/2019
# 11          07/10/2018          07/04/2019         1  14/03/2019
# 12          06/03/2019          06/04/2019         1  15/03/2019
# 13          08/03/2019          08/04/2019         1  14/03/2019
# 14          26/02/2019          26/03/2019         1  15/03/2019
#
#    FEC_DENU_SINI  NRO_EXPED TIPO_EXPED MCA_JUICIO  COD_MON IMPORTE_RESERVA  \
# 0     03/12/2018          2        003        NaN        1         2500.00
# 1     03/12/2018          3        010        NaN        1        11000.00
# 2     03/12/2018          3        010        NaN        1        11000.00
# 3     04/12/2018          1        003        NaN        1         2500.00
# 4     04/12/2018          1        010        NaN        1        11097.90
# 5     04/12/2018          2        010        NaN        1         5063.08
# 6     04/12/2018          1        010        NaN        1        12734.90
# 7     14/03/2019          1        003        NaN        1            1.00
# 8     14/03/2019          2        003        NaN        1            1.00
# 9     14/03/2019          1        003        NaN        1            1.00
# 10    15/03/2019          1        003        NaN        1            1.00
# 11    15/03/2019          1        003        NaN        1            1.00
# 12    15/03/2019          1        003        NaN        1            1.00
# 13    15/03/2019          2        010        NaN        1            1.00
# 14    16/03/2019          1        003        NaN        1            1.00
#
#     COD_CONCEP_RVA IMPORTE_LIQUIDADO MCA_COASEG IMPORTE_COASEG IMPORTE_REASEG  \
# 0                3              0.00        NaN           0.00           0.00
# 1               10              0.00        NaN           0.00           0.00
# 2               10              0.00        NaN           0.00           0.00
# 3                3              0.00        NaN           0.00           0.00
# 4               10              0.00        NaN           0.00           0.00
# 5               10              0.00        NaN           0.00           0.00
# 6               10              0.00        NaN           0.00           0.00
# 7                3              0.00        NaN           0.00           0.00
# 8                3              0.00        NaN           0.00           0.00
# 9                3              0.00        NaN           0.00           0.00
# 10               3              0.00        NaN           0.00           0.00
# 11               3              0.00        NaN           0.00           0.00
# 12               3              0.00        NaN           0.00           0.00
# 13              10              0.00        NaN           0.00           0.00
# 14               3              0.00        NaN           0.00           0.00
#
#    IMPORTE_NETO IMPORTE_NETO_PESOS ESTADO FECHA_ESTADO FECHA_REAPERTURA  \
# 0       2500.00            2500.00    NaN          NaN              NaN
# 1      11000.00           11000.00    NaN          NaN              NaN
# 2      11000.00           11000.00    NaN          NaN              NaN
# 3       2500.00            2500.00    NaN          NaN              NaN
# 4      11097.90           11097.90    NaN          NaN              NaN
# 5       5063.08            5063.08    NaN          NaN              NaN
# 6      12734.90           12734.90    NaN          NaN              NaN
# 7          1.00               1.00    NaN          NaN              NaN
# 8          1.00               1.00    NaN          NaN              NaN
# 9          1.00               1.00    NaN          NaN              NaN
# 10         1.00               1.00    NaN          NaN              NaN
# 11         1.00               1.00    NaN          NaN              NaN
# 12         1.00               1.00    NaN          NaN              NaN
# 13         1.00               1.00    NaN          NaN              NaN
# 14         1.00               1.00    NaN          NaN              NaN
#
#     CODIGO_REAPERTURA FECHA_RESERVA  FECHA_BAJA  CODIGO_BAJA  \
# 0                 NaN           NaN  30/04/2019         20.0
# 1                 NaN           NaN  30/04/2019         20.0
# 2                 NaN           NaN  30/04/2019         20.0
# 3                 NaN           NaN  30/04/2019         20.0
# 4                 NaN           NaN  30/04/2019         20.0
# 5                 NaN           NaN  30/04/2019         20.0
# 6                 NaN           NaN  30/04/2019         20.0
# 7                 NaN           NaN  30/04/2019         20.0
# 8                 NaN           NaN  30/04/2019         20.0
# 9                 NaN           NaN  30/04/2019         20.0
# 10                NaN           NaN  09/04/2019         10.0
# 11                NaN           NaN  30/04/2019         20.0
# 12                NaN           NaN  30/04/2019         20.0
# 13                NaN           NaN  30/04/2019         20.0
# 14                NaN           NaN  30/04/2019         20.0
#
#    FECHA_LIQUIDACION  NUMERO_LIQUIDACION CONCEPTO_LIQUIDACION TIPO_LIQ  \
# 0                NaN                 NaN                  NaN      NaN
# 1                NaN                 NaN                  NaN      NaN
# 2                NaN                 NaN                  NaN      NaN
# 3                NaN                 NaN                  NaN      NaN
# 4                NaN                 NaN                  NaN      NaN
# 5                NaN                 NaN                  NaN      NaN
# 6                NaN                 NaN                  NaN      NaN
# 7                NaN                 NaN                  NaN      NaN
# 8                NaN                 NaN                  NaN      NaN
# 9                NaN                 NaN                  NaN      NaN
# 10               NaN                 NaN                  NaN      NaN
# 11               NaN                 NaN                  NaN      NaN
# 12               NaN                 NaN                  NaN      NaN
# 13               NaN                 NaN                  NaN      NaN
# 14               NaN                 NaN                  NaN      NaN
#
#     CODIGO_TEXTO  SUBCODIGO_TEXTO  NUM_ORD_PAGO FECHA_PAGO  CODIGO_VEHICULO  \
# 0            NaN              NaN           NaN        NaN           4528.0
# 1            NaN              NaN           NaN        NaN          26486.0
# 2            NaN              NaN           NaN        NaN          18122.0
# 3            NaN              NaN           NaN        NaN          18340.0
# 4            NaN              NaN           NaN        NaN          14221.0
# 5            NaN              NaN           NaN        NaN          14221.0
# 6            NaN              NaN           NaN        NaN           4541.0
# 7            NaN              NaN           NaN        NaN          23786.0
# 8            NaN              NaN           NaN        NaN          19183.0
# 9            NaN              NaN           NaN        NaN          12280.0
# 10           NaN              NaN           NaN        NaN          18602.0
# 11           NaN              NaN           NaN        NaN           3932.0
# 12           NaN              NaN           NaN        NaN           5391.0
# 13           NaN              NaN           NaN        NaN          24438.0
# 14           NaN              NaN           NaN        NaN           5767.0
#
#      COLOR            DESCRIPCION_VEHICULO  MODELO_VEHICULO            MOTOR  \
# 0   BLANCO  FIAT UNO 1.4 5P ATTRACTIVE TOP           2015.0   327A0552458832
# 1     AZUL      CHEVROLET ZAFIRA 2 GLS 2.0           2006.0        1N0002879
# 2     GRIS    TOYOTA COROLLA 1.8 SE-G L/14           2014.0       2ZRM208438
# 3   BLANCO  VOLKSWAGEN GOL TREND 1.6 5P HI           2015.0        CFZP08650
# 4     GRIS  RENAULT CLIO MIO 1.2 5P CONFOR           2014.0   D4FG728Q200615
# 5     GRIS  RENAULT CLIO MIO 1.2 5P CONFOR           2014.0   D4FG728Q200615
# 6       NI  FIAT PALIO 1.4 5P ATTRACT L/14           2015.0          2132332
# 7    BORDO      RENAULT R 21 NEVADA DIESEL           1996.0          5675884
# 8      NaN     VOLKSWAGEN GOL TREND 1.6 5P           2012.0        CFZ890853
# 9     GRIS      PEUGEOT 206 XR 1.6 D/A  3P           1999.0    10FX1T0514537
# 10    GRIS  VOLKSWAGEN FOX 1.6 COMFORTLINE           2010.0        CFZ762550
# 11     S/I  FIAT PALIO ATTRACTIVE 1.4 8V T           2017.0    327A055039231
# 12   NEGRO               FIAT IDEA ELX 1.4           2008.0  178F30118467831
# 13     NaN  TOYOTA HILUX L/16 2.4 DC 4X2 T           2017.0       2GDC254288
# 14  BLANCO  FORD FIESTA TITANIUM KD 5 L/13           2018.0      HXJCJ593252
#
#                CHASIS   PATENTE  TIPO      DESCRIPCION_TIPO  USO  \
# 0   9BD195354F0685070  OWK00094     3  AUTOS, CAMIONE.RURAL    1
# 1   9BGTT75F06C223226  FUO00267     3  AUTOS, CAMIONE.RURAL    1
# 2   9BRBU3HE1F0001707  NUZ00658     3  AUTOS, CAMIONE.RURAL    1
# 3   9BWAB45U4FP570039  OYP00355     3  AUTOS, CAMIONE.RURAL    1
# 4   8A1BB2U01FL700491  OLX00295     3  AUTOS, CAMIONE.RURAL    1
# 5   8A1BB2U01FL700491  OLX00295     3  AUTOS, CAMIONE.RURAL    1
# 6   00000000004107768  OPB00600     3  AUTOS, CAMIONE.RURAL    1
# 7   8A1K48DZZSS000177  APX00632     3  AUTOS, CAMIONE.RURAL    1
# 8   9BWAB05U3CT159906  KWL00928     3  AUTOS, CAMIONE.RURAL    1
# 9   VF32CNFZWXW004821  DCE00272     3  AUTOS, CAMIONE.RURAL    1
# 10  9BWAB05Z9B4010744  IYR00692     3  AUTOS, CAMIONE.RURAL    1
# 11   8AP19675H4193662   AB240GB     3  AUTOS, CAMIONE.RURAL    1
# 12  9BD13561492108687  HPV00490     3  AUTOS, CAMIONE.RURAL    1
# 13  8AJCB8DD7J3997824   AC064NI     9  JEEPS DE +4 CIL.Y PI    1
# 14  9BFZD55N7JB593252   AC362FH     6  AUTOS, CAM.RURAL IMP    1
#
#               DESCRIPCION_USO  COD_ACT_BENEF  ALT_COBERTURA  \
# 0   PARTICULAR EXCLUSIVAMENTE            NaN            963
# 1   PARTICULAR EXCLUSIVAMENTE            NaN            909
# 2   PARTICULAR EXCLUSIVAMENTE            NaN            957
# 3   PARTICULAR EXCLUSIVAMENTE            NaN            904
# 4   PARTICULAR EXCLUSIVAMENTE            NaN            964
# 5   PARTICULAR EXCLUSIVAMENTE            NaN            964
# 6   PARTICULAR EXCLUSIVAMENTE            NaN            963
# 7   PARTICULAR EXCLUSIVAMENTE            NaN            120
# 8   PARTICULAR EXCLUSIVAMENTE            NaN            967
# 9   PARTICULAR EXCLUSIVAMENTE            NaN            121
# 10  PARTICULAR EXCLUSIVAMENTE            NaN            921
# 11  PARTICULAR EXCLUSIVAMENTE            NaN            951
# 12  PARTICULAR EXCLUSIVAMENTE            NaN            951
# 13  PARTICULAR EXCLUSIVAMENTE            NaN            969
# 14  PARTICULAR EXCLUSIVAMENTE            NaN            977
#
#    SUMA_ASEG_VEHICULO SUMA_ASEG_COBERTURA  \
# 0           196800.00          3000000.00
# 1           178500.00           178500.00
# 2           393700.00           393700.00
# 3           247800.00          3000000.00
# 4           177400.00           177400.00
# 5           177400.00           177400.00
# 6           205200.00           205200.00
# 7            67300.00          3000000.00
# 8           153000.00          3000000.00
# 9           118300.00          3000000.00
# 10          155000.00          3000000.00
# 11          283500.00          3000000.00
# 12          139700.00          3000000.00
# 13          698700.00           698700.00
# 14          540600.00          3000000.00
#
#                                      LUGAR_OCURRENCIA  COD_POST_OCURRENCIA  \
# 0            RUTA 3, PROVINCIAS UNIDAS Y LA HAYA 7200              1765006
# 1                         MANUEL UGARTE  Y MONTAÑESES              1001000
# 2                                       RUTA 2 KM 190              7100002
# 3                                       ARENALES 3200              1646002
# 4                       AV VIRREY VERTIZ  Y JURAMENTO              1001000
# 5                               DR IGNACIO ARIETA 203              1754001
# 6                                 LASCANO  Y BERMUDEZ              1001000
# 7                                      CAMARONES 4300              1407000
# 8               ANTARTIDA ARGENTINA Y VICTOR MARTINEZ              1757000
# 9                           PERIBEBUY  Y MI ESPERANZA              1765006
# 10         OLAVARRIA E/ FRUCTOSO RIVERA Y GRAL PINTOS              1772002
# 11                           JOSE IGNACIO THAMES 3300              1754001
# 12  AU TTE GRAL PABLO RICCHIERI  Y AU TTE GRAL PAB...              1770000
# 13                         CIRC 1 SECCION 2 MANZANA 2              1778000
# 14                    AVDA JUAN BAUTISTA ALBERDI 6400              1440000
#
#    FUERA_TERRITORIO TIPO_SINIESTRO FORMAL FECHA_PASE_FORMAL IMP_VALOR_PRESUP  \
# 0                 N              N      N               NaN             0.00
# 1                 N              C    NaN               NaN         11000.00
# 2                 N              N    NaN               NaN         11000.00
# 3                 N              N      N               NaN             0.00
# 4                 N              N    NaN               NaN         11097.90
# 5                 N              N    NaN               NaN         11000.00
# 6                 N              N    NaN               NaN         12734.90
# 7                 N              E      N               NaN             0.00
# 8                 N              N      N               NaN             0.00
# 9                 N              H      N               NaN             0.00
# 10                N              E      N               NaN             0.00
# 11                N              E      N               NaN             0.00
# 12                N              E      N               NaN             0.00
# 13                N              N    NaN               NaN         11000.00
# 14                N              N      N               NaN             0.00
#
#     OPCION_PAGO_EXP20  CONDICION_ROBO_EXP50 SUBROGABLE SALVATAJE  POLIZA_REAL  \
# 0                 NaN                   NaN        NaN       NaN          NaN
# 1                 NaN                   NaN          N       NaN          NaN
# 2                 NaN                   NaN          N       NaN          NaN
# 3                 NaN                   NaN        NaN       NaN          NaN
# 4                 NaN                   NaN          N       NaN          NaN
# 5                 NaN                   NaN          N       NaN          NaN
# 6                 NaN                   NaN          N       NaN          NaN
# 7                 NaN                   NaN        NaN       NaN          NaN
# 8                 NaN                   NaN        NaN       NaN          NaN
# 9                 NaN                   NaN        NaN       NaN          NaN
# 10                NaN                   NaN        NaN       NaN          NaN
# 11                NaN                   NaN        NaN       NaN          NaN
# 12                NaN                   NaN        NaN       NaN          NaN
# 13                NaN                   NaN          N       NaN          NaN
# 14                NaN                   NaN        NaN       NaN          NaN
#
#     TIPO_RC  SEGURO FALTANTE FECHA_RECEPCION FECHA_ENTREGA RECHAZO  \
# 0       9.0       1        S      03/12/2018           NaN       N
# 1       9.0       1        N      03/12/2018    03/12/2018       N
# 2       9.0       1        S      03/12/2018           NaN       N
# 3       9.0       1        S      04/12/2018           NaN       N
# 4       9.0       1        N      04/12/2018    04/12/2018       N
# 5       9.0       1        N      04/12/2018    04/12/2018       N
# 6       9.0       1        N      04/12/2018    04/12/2018       N
# 7       9.0       1        S      14/03/2019           NaN       N
# 8       9.0       1        S      14/03/2019           NaN       N
# 9       9.0       1        S      14/03/2019           NaN       N
# 10      9.0       1        S      15/03/2019           NaN       N
# 11      9.0       1        S      15/03/2019           NaN       N
# 12      9.0       1        S      15/03/2019           NaN       N
# 13      9.0       1        S      15/03/2019           NaN       N
# 14      9.0       1        S      16/03/2019           NaN       N
#
#    FECHA_RECHAZO  MOTIVO_RECHAZO IMPORTE_ADJUDICADO IMPORTE_DEDUCCIONES  \
# 0            NaN             NaN               0.00                0.00
# 1            NaN             NaN               0.00                0.00
# 2            NaN             NaN               0.00                0.00
# 3            NaN             NaN               0.00                0.00
# 4            NaN             NaN               0.00                0.00
# 5            NaN             NaN               0.00                0.00
# 6            NaN             NaN               0.00                0.00
# 7            NaN             NaN               0.00                0.00
# 8            NaN             NaN               0.00                0.00
# 9            NaN             NaN               0.00                0.00
# 10           NaN             NaN               0.00                0.00
# 11           NaN             NaN               0.00                0.00
# 12           NaN             NaN               0.00                0.00
# 13           NaN             NaN               0.00                0.00
# 14           NaN             NaN               0.00                0.00
#
#    IMPORTE_FRANQUICIA IMPORTE_PRENDARIO USER_SINI USER_EXPED USER_LIQ  \
# 0                0.00              0.00   CICEROJ   BAJARVAS      NaN
# 1                0.00              0.00  CHAVEZCM   BAJARVAS      NaN
# 2                0.00              0.00  SINISWEB   BAJARVAS      NaN
# 3                0.00              0.00   CICEROJ   BAJARVAS      NaN
# 4                0.00              0.00  CHAVEZCM   BAJARVAS      NaN
# 5                0.00              0.00  CHAVEZCM   BAJARVAS      NaN
# 6                0.00              0.00  CHAVEZCM   BAJARVAS      NaN
# 7                0.00              0.00   CICEROJ   BAJARVAS      NaN
# 8                0.00              0.00    GARAYM   BAJARVAS      NaN
# 9                0.00              0.00  APARICIJ   BAJARVAS      NaN
# 10               0.00              0.00  DECAMINA   CHAVEZCM      NaN
# 11               0.00              0.00    GARAYM   BAJARVAS      NaN
# 12               0.00              0.00  CHAVEZCM   BAJARVAS      NaN
# 13               0.00              0.00  DECAMINA   BAJARVAS      NaN
# 14               0.00              0.00   CICEROJ   BAJARVAS      NaN
#
#    USER_JUI AJUSTE_RESERVA FECHA_APER_SINI FECHA_MODI_SINI FECHA_APER_EXP  \
# 0       NaN           0.00      03/12/2018      18/01/2019     03/12/2018
# 1       NaN           0.00      03/12/2018      03/12/2018     03/12/2018
# 2       NaN           0.00      03/12/2018             NaN     03/12/2018
# 3       NaN           0.00      04/12/2018      07/01/2019     04/12/2018
# 4       NaN           0.00      04/12/2018             NaN     04/12/2018
# 5       NaN           0.00      04/12/2018             NaN     04/12/2018
# 6       NaN           0.00      04/12/2018             NaN     04/12/2018
# 7       NaN           0.00      14/03/2019      15/04/2019     14/03/2019
# 8       NaN           0.00      14/03/2019             NaN     14/03/2019
# 9       NaN           0.00      14/03/2019             NaN     14/03/2019
# 10      NaN           0.00      15/03/2019             NaN     15/03/2019
# 11      NaN           0.00      15/03/2019             NaN     15/03/2019
# 12      NaN           0.00      15/03/2019      15/03/2019     15/03/2019
# 13      NaN           0.00      15/03/2019             NaN     15/03/2019
# 14      NaN           0.00      16/03/2019      21/03/2019     16/03/2019
#
#    FECHA_MODI_EXP FECHA_ANU_LIQ RESERVA_ANTEPENULTIMA TOTAL_LIQUIDADO  \
# 0      30/04/2019           NaN                  0.00            0.00
# 1      30/04/2019           NaN                  0.00            0.00
# 2      30/04/2019           NaN                  0.00            0.00
# 3      30/04/2019           NaN                  0.00            0.00
# 4      30/04/2019           NaN                  0.00            0.00
# 5      30/04/2019           NaN                  0.00            0.00
# 6      30/04/2019           NaN                  0.00            0.00
# 7      30/04/2019           NaN                  0.00            0.00
# 8      30/04/2019           NaN                  0.00            0.00
# 9      30/04/2019           NaN                  0.00            0.00
# 10     09/04/2019           NaN                  0.00            0.00
# 11     30/04/2019           NaN                  0.00            0.00
# 12     30/04/2019           NaN                  0.00            0.00
# 13     30/04/2019           NaN                  0.00            0.00
# 14     30/04/2019           NaN                  0.00            0.00
#
#    RESERVA_DENUNCIADO RECUPERADOR_050  COD_AGEN_TRAMI    STATUS FECHA_PROCESO  \
# 0                0.00             NaN            5770  CERRADOS    30/04/2019
# 1                0.00             NaN            6030  CERRADOS    30/04/2019
# 2                0.00             NaN            6030  CERRADOS    30/04/2019
# 3                0.00             NaN            5770  CERRADOS    30/04/2019
# 4                0.00             NaN            6030  CERRADOS    30/04/2019
# 5                0.00             NaN            6030  CERRADOS    30/04/2019
# 6                0.00             NaN            6030  CERRADOS    30/04/2019
# 7                0.00             NaN            5770  CERRADOS    30/04/2019
# 8                0.00             NaN            5770  CERRADOS    30/04/2019
# 9                0.00             NaN            5770  CERRADOS    30/04/2019
# 10               0.00             NaN            5770  CERRADOS    30/04/2019
# 11               0.00             NaN            5770  CERRADOS    30/04/2019
# 12               0.00             NaN            5770  CERRADOS    30/04/2019
# 13               0.00             NaN            6030  CERRADOS    30/04/2019
# 14               0.00             NaN            5770  CERRADOS    30/04/2019
#
#     KM_REC_AL_ASEGURAR IMP_VALOR_PRESU_EXP10  ESTAD_VEH_ASEG  \
# 0              72777.0                  0.00             3.0
# 1              97491.0                  0.00             3.0
# 2              78813.0                  0.00             3.0
# 3              49950.0                  0.00             3.0
# 4              20472.0                  0.00             3.0
# 5              20472.0                  0.00             3.0
# 6                  NaN                  0.00             3.0
# 7                  NaN                  0.00             3.0
# 8                100.0                  0.00             3.0
# 9              77510.0                  0.00             3.0
# 10             47253.0                  0.00             2.0
# 11                 0.0                  0.00             3.0
# 12            132256.0                  0.00             3.0
# 13                 0.0                  0.00             5.0
# 14                 NaN                  0.00             5.0
#
#               NOMBRE_CONDUCTOR TIPO_DOCUM_COND  NRO_DOCUM_COND  \
# 0   RIQUELME NATALIA ALEJANDRA              DU        25060974
# 1     COCERES, HECTOR LEONARDO              DU        31349782
# 2       FLORIO DIEGO ALEJANDRO              CT     20256580838
# 3     CANDIDO FRANCISCO MARTIN              DU        25797736
# 4                  ROLDAN ERIC              DU        39464792
# 5                  ROLDAN ERIC              DU        39464792
# 6    STEININGER DIEGO EMILIANO              DU        36298197
# 7             YAUNACE, ROBERTO              LE         4516471
# 8         CORREA JORGE EDUARDO              DU        17829535
# 9        QUIROGA, LUIS IGNACIO              DU        45315799
# 10          CORTI MIGUEL ANGEL              DU        22735448
# 11          VIERA JOSE EDUARDO              DU        33074533
# 12          NEYRA TORRES OSCAR              DU        94559105
# 13      PRIETO MARIA ELIZABETH              DU        30699068
# 14           MORE MONICA MABEL              DU        22492921
#
#    VALUACION_DANIO   INSPECTOR  CODIGO_CARATULA TIPO_LESION RESERVA_INICIAL  \
# 0             1.00  22285151.0              NaN         NaN         2500.00
# 1         10309.75  10504712.0              NaN         NaN        11000.00
# 2              NaN  33020159.0              NaN         NaN        11000.00
# 3              NaN  12349117.0              NaN         NaN         2500.00
# 4          3641.96  23611562.0              NaN         NaN        11000.00
# 5          3641.96  23611562.0              NaN         NaN        11000.00
# 6              NaN         NaN              NaN         NaN        11000.00
# 7              NaN         NaN              NaN         NaN            1.00
# 8              NaN         NaN              NaN         NaN            1.00
# 9         11034.02  21707472.0              NaN         NaN            1.00
# 10         5345.81  20430077.0              NaN         NaN            1.00
# 11             NaN         NaN              NaN         NaN            1.00
# 12        13973.71  23611562.0              NaN         NaN            1.00
# 13             NaN         NaN              NaN         NaN        11000.00
# 14             NaN         NaN              NaN         NaN         2500.00
#
#    USER_INICIAL RESERVA_FORMAL FECHA_FORMAL USER_FORMAL RESERVA_CIERRE  \
# 0      SINISWEB           0.00          NaN         NaN           0.00
# 1      CHAVEZCM           0.00          NaN         NaN           0.00
# 2      SINISWEB           0.00          NaN         NaN           0.00
# 3      SINISWEB           0.00          NaN         NaN           0.00
# 4      CHAVEZCM           0.00          NaN         NaN           0.00
# 5      CHAVEZCM           0.00          NaN         NaN           0.00
# 6      CHAVEZCM           0.00          NaN         NaN           0.00
# 7      DECAMINA           0.00          NaN         NaN           0.00
# 8        GARAYM           0.00          NaN         NaN           0.00
# 9      APARICIJ           0.00          NaN         NaN           0.00
# 10     DECAMINA           0.00          NaN         NaN           0.00
# 11       GARAYM           0.00          NaN         NaN           0.00
# 12     CHAVEZCM           0.00          NaN         NaN           0.00
# 13     DECAMINA           0.00          NaN         NaN           0.00
# 14     SINISWEB           0.00          NaN         NaN           0.00
#
#     FECHA_CIERRE  USER_CIERRE  CIA_COASEG NOMBRE_COASEG FECHA_VIG_ORIG_POL  \
# 0            NaN          NaN         NaN           NaN         01/11/2018
# 1            NaN          NaN         NaN           NaN         11/09/2018
# 2            NaN          NaN         NaN           NaN         01/10/2018
# 3            NaN          NaN         NaN           NaN         26/07/2018
# 4            NaN          NaN         NaN           NaN         26/08/2018
# 5            NaN          NaN         NaN           NaN         26/08/2018
# 6            NaN          NaN         NaN           NaN         01/03/2018
# 7            NaN          NaN         NaN           NaN         03/12/2018
# 8            NaN          NaN         NaN           NaN         12/03/2018
# 9            NaN          NaN         NaN           NaN         15/10/2018
# 10           NaN          NaN         NaN           NaN         01/03/2019
# 11           NaN          NaN         NaN           NaN                NaN
# 12           NaN          NaN         NaN           NaN         06/01/2019
# 13           NaN          NaN         NaN           NaN         08/11/2018
# 14           NaN          NaN         NaN           NaN         26/01/2019
#
#    RESERVA_JUDICIAL FECHA_JUDICIAL USER_JUDICIAL RECLAMO_EXTRAJUD  \
# 0              0.00            NaN           NaN                M
# 1              0.00            NaN           NaN              NaN
# 2              0.00            NaN           NaN              NaN
# 3              0.00            NaN           NaN                M
# 4              0.00            NaN           NaN              NaN
# 5              0.00            NaN           NaN              NaN
# 6              0.00            NaN           NaN              NaN
# 7              0.00            NaN           NaN                M
# 8              0.00            NaN           NaN                M
# 9              0.00            NaN           NaN                M
# 10             0.00            NaN           NaN                M
# 11             0.00            NaN           NaN                M
# 12             0.00            NaN           NaN                M
# 13             0.00            NaN           NaN              NaN
# 14             0.00            NaN           NaN                M
#
#    TIPO_DENUNCIA RESOLUCION TOTAL_EXPED_003  COD_AGENCIA_PAGO COD_DOCUM_BENEF  \
# 0              W          N            0.00               NaN             NaN
# 1              S        NaN            0.00               NaN             NaN
# 2              W        NaN            0.00               NaN             NaN
# 3              W          N            0.00               NaN             NaN
# 4              S        NaN            0.00               NaN             NaN
# 5              S        NaN            0.00               NaN             NaN
# 6              S        NaN            0.00               NaN             NaN
# 7              S          N            0.00               NaN             NaN
# 8              S          N            0.00               NaN             NaN
# 9              T          N            0.00               NaN             NaN
# 10             S          N            0.00               NaN             NaN
# 11             S          N            0.00               NaN             NaN
# 12             S          N            0.00               NaN             NaN
# 13             S        NaN            0.00               NaN             NaN
# 14             W          N            0.00               NaN             NaN
#
#     COD_BENEF TIPO_DOCUM_ASEG  NRO_DOCUM_ASEG TIPO_DOCUMENTO_TERC  \
# 0         NaN              DU        25060974                 NaN
# 1         NaN              DU        23844283                 NaN
# 2         NaN              CT     20256580838                 NaN
# 3         NaN              DU        25797736                 NaN
# 4         NaN              DU        39464792                 NaN
# 5         NaN              DU        39464792                 NaN
# 6         NaN              DU        36298197                 NaN
# 7         NaN              DU        31205906                 NaN
# 8         NaN              DU        17829535                 NaN
# 9         NaN              DU        40081995                  DU
# 10        NaN              DU        22735448                  DU
# 11        NaN              DU        33074533                 NaN
# 12        NaN              DU        94559105                 NaN
# 13        NaN              DU        30699068                 NaN
# 14        NaN              DU        22492921                  DU
#
#     NRO_DOCUMENTO_TERC APELLIDO_ASEG        NOMBRE_ASEG ESTADO_CIVIL  \
# 0                  NaN      RIQUELME  NATALIA ALEJANDRA           SO
# 1                  NaN      MARTINEZ      LILIANA NOEMI           SO
# 2                  NaN        FLORIO    DIEGO ALEJANDRO           CA
# 3                  NaN       CANDIDO   FRANCISCO MARTIN           SO
# 4                  NaN        ROLDAN               ERIC           SO
# 5                  NaN        ROLDAN               ERIC           SO
# 6                  NaN    STEININGER     DIEGO EMILIANO           CA
# 7                  NaN       YAUNACE   MARIELA VERONICA           CA
# 8           20469404.0        CORREA      JORGE EDUARDO           CA
# 9           40080815.0         AUGER      MELINA DAIANA           SO
# 10          92879292.0         CORTI       MIGUEL ANGEL           SO
# 11          28169588.0         VIERA       JOSE EDUARDO           SO
# 12                 NaN  NEYRA TORRES              OSCAR           SO
# 13                 NaN        PRIETO    MARIA ELIZABETH           CA
# 14          42723955.0          MORE       MONICA MABEL           SO
#
#    FECHA_NAC_ASEG SEXO  OCUPACION_ASEG  \
# 0      15/04/1976    F             5.0
# 1      27/12/1984    M           999.0
# 2      04/12/1976    M             5.0
# 3      28/07/1977    M             5.0
# 4      10/05/1996    M            44.0
# 5      10/05/1996    M            44.0
# 6      05/06/1991    M             5.0
# 7      08/02/1945    M             5.0
# 8      23/12/1965    M             5.0
# 9      25/08/1996    M           999.0
# 10     13/06/1972    M             5.0
# 11     31/05/1987    M            32.0
# 12     25/03/1970    M             8.0
# 13     28/11/1983    F             5.0
# 14     04/02/1972    F            44.0
#
#                                  APELLIDO_NOMBRE_TERC        DOMICILIO_TERC  \
# 0                                       SIN MAS DATOS                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                   MIGUEL ANGEL RUIZ                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                                 NaN                   NaN
# 7                 CARLOS ALBERTO IRIONDO DNI 13522357                   NaN
# 8                                     OSVALDO ANDRADA                   NaN
# 9   LINEA 630 - INT 309 - CHOFER: BENITEZ LEANDRO ...                   NaN
# 10                           CHOQUE FLORES, MARCELINO  RICARDO LEVENNE 2015
# 11                                 FRAGA DIEGO JAVIER                   NaN
# 12                               CZEREVIN CESAR OSCAR                   NaN
# 13                                                NaN                   NaN
# 14                                       REY EMILIANO                   NaN
#
#    ESTADO_CIVIL_TERC FECHA_NAC_TERC SEXO_TERC  COD_POST_TERC TELEFONO_TERC  \
# 0                NaN            NaN         M            NaN           NaN
# 1                NaN            NaN       NaN            NaN           NaN
# 2                NaN            NaN       NaN            NaN           NaN
# 3                NaN            NaN         M            NaN           NaN
# 4                NaN            NaN       NaN            NaN           NaN
# 5                NaN            NaN       NaN            NaN           NaN
# 6                NaN            NaN       NaN            NaN           NaN
# 7                NaN            NaN         M            NaN           NaN
# 8                NaN            NaN         M            NaN           NaN
# 9                NaN            NaN         M            NaN           NaN
# 10                CA     02/06/1970         M      1768000.0    1549974943
# 11               NaN            NaN         M            NaN           NaN
# 12               NaN            NaN         M            NaN           NaN
# 13               NaN            NaN       NaN            NaN           NaN
# 14               NaN            NaN         M            NaN           NaN
#
#    TIPO_LESION_MAXIMA USER_RESOLUCION DANOS_MATERIALES OFRECIMIENTO  \
# 0                 NaN             NaN             0.00         0.00
# 1                 NaN             NaN             0.00         0.00
# 2                 NaN             NaN             0.00         0.00
# 3                 NaN             NaN             0.00         0.00
# 4                 NaN             NaN             0.00         0.00
# 5                 NaN             NaN             0.00         0.00
# 6                 NaN             NaN             0.00         0.00
# 7                 NaN             NaN             0.00         0.00
# 8                 NaN             NaN             0.00         0.00
# 9                 NaN             NaN             0.00         0.00
# 10                NaN             NaN             0.00         0.00
# 11                NaN             NaN             0.00         0.00
# 12                NaN             NaN             0.00         0.00
# 13                NaN             NaN             0.00         0.00
# 14                NaN             NaN             0.00         0.00
#
#    USER_APER_SINI USER_APER_EXP  NRO_EQUIPO JEFE_EQUIPO  MON FECHA_MONEDA  \
# 0        SINISWEB      SINISWEB         NaN         NaN  NaN          NaN
# 1        CHAVEZCM      CHAVEZCM         NaN         NaN  NaN          NaN
# 2        SINISWEB      SINISWEB         NaN         NaN  NaN          NaN
# 3        SINISWEB      SINISWEB         NaN         NaN  NaN          NaN
# 4        CHAVEZCM      CHAVEZCM         NaN         NaN  NaN          NaN
# 5        CHAVEZCM      CHAVEZCM         NaN         NaN  NaN          NaN
# 6        CHAVEZCM      CHAVEZCM         NaN         NaN  NaN          NaN
# 7        DECAMINA      DECAMINA         NaN         NaN  NaN          NaN
# 8          GARAYM        GARAYM         NaN         NaN  NaN          NaN
# 9        APARICIJ      APARICIJ         NaN         NaN  NaN          NaN
# 10       DECAMINA      DECAMINA         NaN         NaN  NaN          NaN
# 11         GARAYM        GARAYM         NaN         NaN  NaN          NaN
# 12       CHAVEZCM      CHAVEZCM         NaN         NaN  NaN          NaN
# 13       DECAMINA      DECAMINA         NaN         NaN  NaN          NaN
# 14       SINISWEB      SINISWEB         NaN         NaN  NaN          NaN
#
#    NRO_CPACF  COD_PRODUCTOR                         NOM_PRODUCTOR  \
# 0        NaN           5660    TELEMARKETING CAJA DE SEGUROS S.A.
# 1        NaN           5660    TELEMARKETING CAJA DE SEGUROS S.A.
# 2        NaN           5660    TELEMARKETING CAJA DE SEGUROS S.A.
# 3        NaN           6300                       CX DIRECTORIO .
# 4        NaN           6030            CAJA EXPRESS - SAN JUSTO .
# 5        NaN           6030            CAJA EXPRESS - SAN JUSTO .
# 6        NaN          72536    ARGENTINA S,A FIAT CHRYSKER RIMACO
# 7        NaN           6030            CAJA EXPRESS - SAN JUSTO .
# 8        NaN          74289  ASESORES DE SEGUROS S.A SUDAMERICANA
# 9        NaN           6030            CAJA EXPRESS - SAN JUSTO .
# 10       NaN           6030            CAJA EXPRESS - SAN JUSTO .
# 11       NaN          72038               BANCO SANTANDER RÍO S A
# 12       NaN           6030            CAJA EXPRESS - SAN JUSTO .
# 13       NaN          26559                            PRANA CONC
# 14       NaN          23402                 AUTOMAN CONCESIONARIA
#
#     COD_AGENCIA_SOLIC USER_CAT_DEN USER_CAT_EXP FIN_INVESTIGACION  \
# 0              5660.0            N            N               NaN
# 1                20.0            N            N               NaN
# 2                20.0            N            N               NaN
# 3              6300.0            N            N               NaN
# 4              6030.0            N            N               NaN
# 5              6030.0            N            N               NaN
# 6              3402.0            N            N               NaN
# 7              6030.0            N            N               NaN
# 8              3401.0            N            N               NaN
# 9              6030.0            S            S               NaN
# 10             6030.0            N            N               NaN
# 11             3401.0            N            N               NaN
# 12             6030.0            N            N               NaN
# 13             3402.0            N            N               NaN
# 14             3402.0            N            N               NaN
#
#     NRO_ORDEN_EXP MCA_VIP REPOSICION OPCION_LIQUIDACION NEGOCIACION  \
# 0               3       S          N                NaN          SR
# 1               1       N          N                NaN           N
# 2               1       N          N                NaN           N
# 3               2       N          N                NaN          SR
# 4               2       S          N                NaN           N
# 5               2       S          N                NaN           N
# 6               2       S          N                NaN           N
# 7               1       N          N                NaN          SR
# 8               1       S          N                NaN          SR
# 9               1       N          N                NaN          SR
# 10              2       N          N                NaN          SR
# 11              1       N          N                NaN          SR
# 12              1       N          N                NaN          SR
# 13              2       S          N                NaN           N
# 14              2       S          N                NaN          SR
#
#     COD_INICIADOR NRO_EQUIPO_RECUP FECHA_INSTAL_EQUIPO MODELO_EQUIPO  \
# 0             NaN              NaN                 NaN           NaN
# 1             NaN              NaN                 NaN           NaN
# 2             NaN           714398          24/08/2018         SMART
# 3             NaN              NaN                 NaN           NaN
# 4             NaN              NaN                 NaN           NaN
# 5             NaN              NaN                 NaN           NaN
# 6         72536.0              NaN                 NaN           NaN
# 7             NaN              NaN                 NaN           NaN
# 8         72556.0              NaN                 NaN           NaN
# 9             NaN              NaN                 NaN           NaN
# 10            NaN              NaN                 NaN           NaN
# 11        72038.0           843078          15/05/2017       VLU3.5M
# 12            NaN           660500          26/11/2015         SMART
# 13        73577.0              NaN                 NaN           NaN
# 14        23400.0           683767          02/02/2018         SMART
#
#     COD_PAGO IMP_FRANQUICIA_POLIZA COD_DOCUM_TOM  NRO_DOCUMTO_TOM  \
# 0        NaN               4740.00            DU         25060974
# 1        NaN              38400.00            DU         23844283
# 2        NaN              37550.00            CT      20256580838
# 3        NaN               9300.00            DU         25797736
# 4        NaN               4902.00            DU         39464792
# 5        NaN               4980.00            DU         39464792
# 6        NaN               3265.00            DU         36298197
# 7        NaN                  0.00            DU         31205906
# 8        NaN              21950.00            DU         17829535
# 9        NaN                  0.00            DU         40081995
# 10       NaN                  0.00            DU         22735448
# 11       NaN                  0.00            DU         33074533
# 12       NaN                  0.00            DU         94559105
# 13       NaN              97700.00            DU         30699068
# 14       NaN              35800.00            DU         22492921
#
#     COD_POST_POLIZA METRO  RAJ CERRADURA_BAUL CERRADURA_DERECHA  \
# 0           1757000     S  NaN            NaN               NaN
# 1           1405000     S  NaN              N                 N
# 2           1778000     S  NaN              N                 N
# 3           1752000     S  NaN            NaN               NaN
# 4           1754001     S  NaN              N                 N
# 5           1754001     S  NaN              N                 N
# 6           1706002     S  NaN              N                 N
# 7           1678002     S  NaN            NaN               NaN
# 8           1768000     S  NaN            NaN               NaN
# 9           1765006     S  NaN            NaN               NaN
# 10          1704001     S  NaN            NaN               NaN
# 11          1759017     S  NaN            NaN               NaN
# 12          1759017     S  NaN            NaN               NaN
# 13          3610000     N  NaN              N                 N
# 14          1759017     S  NaN            NaN               NaN
#
#    CERRADURA_IZQUIERDA LUNETA PARABRISAS  RUEDA_EN_RODAJE RUEDA_ALEACION  \
# 0                  NaN    NaN        NaN              NaN            NaN
# 1                    N      N          N              NaN            NaN
# 2                    N      N          N              NaN            NaN
# 3                  NaN    NaN        NaN              NaN            NaN
# 4                    N      N          N              NaN            NaN
# 5                    N      N          N              NaN            NaN
# 6                    N      N          N              NaN            NaN
# 7                  NaN    NaN        NaN              NaN            NaN
# 8                  NaN    NaN        NaN              NaN            NaN
# 9                  NaN    NaN        NaN              NaN            NaN
# 10                 NaN    NaN        NaN              NaN            NaN
# 11                 NaN    NaN        NaN              NaN            NaN
# 12                 NaN    NaN        NaN              NaN            NaN
# 13                   N      N          N              NaN            NaN
# 14                 NaN    NaN        NaN              NaN            NaN
#
#    RUEDA_CHAPA RUEDA_AUXILIO_ALEACION RUEDA_AUXILIO_CHAPA VENTANILLA_D_D  \
# 0          NaN                    NaN                 NaN            NaN
# 1          NaN                    NaN                 NaN              N
# 2          NaN                    NaN                 NaN              N
# 3          NaN                    NaN                 NaN            NaN
# 4          NaN                    NaN                 NaN              N
# 5          NaN                    NaN                 NaN              N
# 6          NaN                    NaN                 NaN              N
# 7          NaN                    NaN                 NaN            NaN
# 8          NaN                    NaN                 NaN            NaN
# 9          NaN                    NaN                 NaN            NaN
# 10         NaN                    NaN                 NaN            NaN
# 11         NaN                    NaN                 NaN            NaN
# 12         NaN                    NaN                 NaN            NaN
# 13         NaN                    NaN                 NaN              N
# 14         NaN                    NaN                 NaN            NaN
#
#    VENTANILLA_D_I VENTANILLA_T_D VENTANILLA_T_I VENTILETE_D_D VENTILETE_D_I  \
# 0             NaN            NaN            NaN           NaN           NaN
# 1               N              N              N             N             N
# 2               N              N              N             N             N
# 3             NaN            NaN            NaN           NaN           NaN
# 4               N              N              N             N             N
# 5               N              N              N             N             N
# 6               N              N              N             N             N
# 7             NaN            NaN            NaN           NaN           NaN
# 8             NaN            NaN            NaN           NaN           NaN
# 9             NaN            NaN            NaN           NaN           NaN
# 10            NaN            NaN            NaN           NaN           NaN
# 11            NaN            NaN            NaN           NaN           NaN
# 12            NaN            NaN            NaN           NaN           NaN
# 13              N              N              N             N             N
# 14            NaN            NaN            NaN           NaN           NaN
#
#    VENTILETE_T_D VENTILETE_T_I OTROS_ED CATASTROFICO
# 0            NaN           NaN     0.00           NO
# 1              N             N     0.00           NO
# 2              N             N     0.00           NO
# 3            NaN           NaN     0.00           NO
# 4              N             N     0.00           NO
# 5              N             N     0.00           NO
# 6              N             N     0.00           NO
# 7            NaN           NaN     0.00           NO
# 8            NaN           NaN     0.00           NO
# 9            NaN           NaN     0.00           NO
# 10           NaN           NaN     0.00           NO
# 11           NaN           NaN     0.00           NO
# 12           NaN           NaN     0.00           NO
# 13             N             N     0.00           NO
# 14           NaN           NaN     0.00           NO

# %%
df.dtypes
# Out:
# NRO_PRESUP               int64
# CIF_ID                   int64
# COD_CIA                  int64
# COD_SECC                 int64
# COD_RAMO                 int64
# FECHA_EQUIPO            object
# FECHA_SOLIC             object
# COD_AGENCIA_PRESU        int64
# COD_AGENCIA_SOLIC      float64
# COD_INICIADOR          float64
# ESTADO                  object
# COD_MARCA                int64
# COD_MOD                  int64
# COD_PLAN               float64
# SUMA_ASEG              float64
# TIPO_COMBUSTIBLE        object
# GRUPO_COMBUSTIBLE      float64
# ORIGEN                  object
# FOR_COBRO               object
# NEGOCIO                 object
# COD_PROD                 int64
# COD_POSTAL               int64
# AGRUPADOR_DIRECTO      float64
# COD_AGENCIA_GES        float64
# FECHA_COTIZ_ANT        float64
# CANAL_ORIGEN            object
# ORIGEN_DESC             object
# REGION                  object
# NOM_ORIGEN_PRESU        object
# SOLICITA_MISMO_AUTO    float64
# NUM_SECU_POL           float64
# EDAD                   float64
# SEXO                    object
# ESTADO_CIVIL            object
# BANCO                  float64
# MARCA_MODELO            object
# PUERTAS                float64
# LOCALIDAD               object
# PROVINCIA               object
# MARCA                   object
# VERSION                 object
# NACIONAL_IMPORT         object
# TRACCION                object
# TIPO                    object
# MCA_0KM                 object
# REC_TR_REAL             object
# REC_TC_REAL             object
# REC_RC_REAL             object
# COMPRO_PLAN             object
# COMPRO_PACK             object
# REC_TC_VIGENTE          object
# REC2_1                  object
# REDU_TIPO               object
# dtype: object

# %%
", ".join(sorted(df.columns))
# Out:
# 'AJUSTE_RESERVA, ALT_COBERTURA, APELLIDO_ASEG, APELLIDO_NOMBRE_TERC, CATASTROFICO, CERRADURA_BAUL, CERRADURA_DERECHA, CERRADURA_IZQUIERDA, CHASIS, CIA_COASEG, CODIGO_BAJA, CODIGO_CARATULA, CODIGO_REAPERTURA, CODIGO_TEXTO, CODIGO_VEHICULO, COD_ACT_BENEF, COD_AGENCIA, COD_AGENCIA_PAGO, COD_AGENCIA_SOLIC, COD_AGEN_EMI, COD_AGEN_TRAMI, COD_BENEF, COD_CAUSA_SINI, COD_CIA, COD_COBERTURA, COD_CONCEP_RVA, COD_DOCUM_BENEF, COD_DOCUM_TOM, COD_INICIADOR, COD_MON, COD_PAGO, COD_POST_OCURRENCIA, COD_POST_POLIZA, COD_POST_TERC, COD_PRODUCTOR, COD_RAMO, COD_RIES, COD_SECC, COLOR, CONCEPTO_LIQUIDACION, CONDICION_ROBO_EXP50, DANOS_MATERIALES, DESCRIPCION_TIPO, DESCRIPCION_USO, DESCRIPCION_VEHICULO, DOMICILIO_TERC, ESTADO, ESTADO_CIVIL, ESTADO_CIVIL_TERC, ESTAD_VEH_ASEG, FALTANTE, FECHA_ANU_LIQ, FECHA_APER_EXP, FECHA_APER_SINI, FECHA_BAJA, FECHA_CIERRE, FECHA_ENTREGA, FECHA_ESTADO, FECHA_FORMAL, FECHA_INSTAL_EQUIPO, FECHA_JUDICIAL, FECHA_LIQUIDACION, FECHA_MODI_EXP, FECHA_MODI_SINI, FECHA_MONEDA, FECHA_NAC_ASEG, FECHA_NAC_TERC, FECHA_PAGO, FECHA_PASE_FORMAL, FECHA_PROCESO, FECHA_REAPERTURA, FECHA_RECEPCION, FECHA_RECHAZO, FECHA_RESERVA, FECHA_SINI, FECHA_VIG_ORIG_POL, FECHA_VIG_POL_DESDE, FECHA_VIG_POL_HASTA, FEC_DENU_SINI, FIN_INVESTIGACION, FORMAL, FUERA_TERRITORIO, IMPORTE_ADJUDICADO, IMPORTE_COASEG, IMPORTE_DEDUCCIONES, IMPORTE_FRANQUICIA, IMPORTE_LIQUIDADO, IMPORTE_NETO, IMPORTE_NETO_PESOS, IMPORTE_PRENDARIO, IMPORTE_REASEG, IMPORTE_RESERVA, IMP_FRANQUICIA_POLIZA, IMP_VALOR_PRESUP, IMP_VALOR_PRESU_EXP10, INSPECTOR, JEFE_EQUIPO, KM_REC_AL_ASEGURAR, LUGAR_OCURRENCIA, LUNETA, MCA_COASEG, MCA_JUICIO, MCA_VIP, METRO, MODELO_EQUIPO, MODELO_VEHICULO, MON, MOTIVO_RECHAZO, MOTOR, NEGOCIACION, NOMBRE_ASEG, NOMBRE_COASEG, NOMBRE_CONDUCTOR, NOM_PRODUCTOR, NRO_CPACF, NRO_DOCUMENTO_TERC, NRO_DOCUMTO_TOM, NRO_DOCUM_ASEG, NRO_DOCUM_COND, NRO_EQUIPO, NRO_EQUIPO_RECUP, NRO_EXPED, NRO_ORDEN_EXP, NUMERO_LIQUIDACION, NUM_ORD_PAGO, NUM_POL1, NUM_SECU_EXPED, NUM_SECU_JUI, NUM_SECU_LIQ, NUM_SECU_POL, NUM_SECU_SINI, NUM_SINI, OCUPACION_ASEG, OFRECIMIENTO, OPCION_LIQUIDACION, OPCION_PAGO_EXP20, OTROS_ED, PARABRISAS, PATENTE, POLIZA_REAL, RAJ, RECHAZO, RECLAMO_EXTRAJUD, RECUPERADOR_050, REPOSICION, RESERVA_ANTEPENULTIMA, RESERVA_CIERRE, RESERVA_DENUNCIADO, RESERVA_FORMAL, RESERVA_INICIAL, RESERVA_JUDICIAL, RESOLUCION, RUEDA_ALEACION, RUEDA_AUXILIO_ALEACION, RUEDA_AUXILIO_CHAPA, RUEDA_CHAPA, RUEDA_EN_RODAJE, SALVATAJE, SEGURO, SEXO, SEXO_TERC, STATUS, SUBCODIGO_TEXTO, SUBROGABLE, SUMA_ASEG_COBERTURA, SUMA_ASEG_VEHICULO, TELEFONO_TERC, TIPO, TIPO_DENUNCIA, TIPO_DOCUMENTO_TERC, TIPO_DOCUM_ASEG, TIPO_DOCUM_COND, TIPO_EXPED, TIPO_LESION, TIPO_LESION_MAXIMA, TIPO_LIQ, TIPO_RC, TIPO_SINIESTRO, TIPO_SUCURSAL, TOTAL_EXPED_003, TOTAL_LIQUIDADO, USER_APER_EXP, USER_APER_SINI, USER_CAT_DEN, USER_CAT_EXP, USER_CIERRE, USER_EXPED, USER_FORMAL, USER_INICIAL, USER_JUDICIAL, USER_JUI, USER_LIQ, USER_RESOLUCION, USER_SINI, USO, VALUACION_DANIO, VENTANILLA_D_D, VENTANILLA_D_I, VENTANILLA_T_D, VENTANILLA_T_I, VENTILETE_D_D, VENTILETE_D_I, VENTILETE_T_D, VENTILETE_T_I'

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# FECHA_CIERRE              1.000000
# USER_CIERRE               1.000000
# POLIZA_REAL               0.999947
# RECUPERADOR_050           0.998739
# FECHA_ANU_LIQ             0.997306
# OPCION_LIQUIDACION        0.995406
# CODIGO_REAPERTURA         0.995094
# FECHA_REAPERTURA          0.993374
# MCA_COASEG                0.991429
# RUEDA_EN_RODAJE           0.989949
# CONDICION_ROBO_EXP50      0.989793
# FECHA_RECHAZO             0.986252
# MOTIVO_RECHAZO            0.986252
# OPCION_PAGO_EXP20         0.986201
# RUEDA_AUXILIO_ALEACION    0.979237
# RUEDA_ALEACION            0.978990
# RUEDA_AUXILIO_CHAPA       0.978990
# RUEDA_CHAPA               0.978990
# CODIGO_BAJA               0.963387
# FECHA_BAJA                0.958611
# SALVATAJE                 0.954855
# USER_RESOLUCION           0.941118
# FECHA_MONEDA              0.937581
# MON                       0.937581
# FECHA_PAGO                0.936030
# FECHA_ESTADO              0.918206
# FECHA_LIQUIDACION         0.916212
# COD_AGENCIA_PAGO          0.913889
# COD_BENEF                 0.913520
# COD_PAGO                  0.913518
# SUBCODIGO_TEXTO           0.913518
# COD_DOCUM_BENEF           0.913518
# USER_LIQ                  0.913518
# CODIGO_TEXTO              0.913518
# NUM_ORD_PAGO              0.913518
# COD_ACT_BENEF             0.913518
# TIPO_LIQ                  0.913518
# NUMERO_LIQUIDACION        0.913518
# CONCEPTO_LIQUIDACION      0.913518
# NUM_SECU_LIQ              0.904621
# NOMBRE_COASEG             0.882660
# CERRADURA_IZQUIERDA       0.844416
# CERRADURA_DERECHA         0.844416
# CERRADURA_BAUL            0.844416
# VENTILETE_D_D             0.844412
# VENTILETE_T_I             0.844412
# VENTILETE_T_D             0.844412
# VENTILETE_D_I             0.844412
# VENTANILLA_T_D            0.844412
# VENTANILLA_T_I            0.844412
# VENTANILLA_D_D            0.844412
# VENTANILLA_D_I            0.844412
# LUNETA                    0.844317
# PARABRISAS                0.844313
# ESTADO                    0.831724
# TELEFONO_TERC             0.823701
# NRO_CPACF                 0.765105
# VALUACION_DANIO           0.763846
# SUBROGABLE                0.761496
# INSPECTOR                 0.652229
# FECHA_INSTAL_EQUIPO       0.647220
# NRO_EQUIPO_RECUP          0.647202
# FECHA_ENTREGA             0.646700
# RESOLUCION                0.627779
# MODELO_EQUIPO             0.627273
# FECHA_JUDICIAL            0.601905
# RAJ                       0.570563
# FECHA_MODI_SINI           0.567284
# FIN_INVESTIGACION         0.565349
# USER_JUI                  0.547557
# MCA_JUICIO                0.547557
# CODIGO_CARATULA           0.547557
# JEFE_EQUIPO               0.547557
# TIPO_LESION_MAXIMA        0.547557
# USER_JUDICIAL             0.547557
# NRO_EQUIPO                0.547557
# KM_REC_AL_ASEGURAR        0.494895
# COD_COBERTURA             0.481531
# FECHA_FORMAL              0.478125
# COD_INICIADOR             0.465431
# USER_FORMAL               0.460962
# CIA_COASEG                0.460962
# FECHA_PASE_FORMAL         0.454182
# ESTADO_CIVIL_TERC         0.453295
# FECHA_NAC_TERC            0.451741
# COD_POST_TERC             0.436920
# DOMICILIO_TERC            0.425286
# TIPO_LESION               0.376951
# TIPO_DOCUMENTO_TERC       0.370758
# NRO_DOCUMENTO_TERC        0.363931
# RECLAMO_EXTRAJUD          0.355164
# COLOR                     0.294447
# APELLIDO_NOMBRE_TERC      0.238724
# FORMAL                    0.189515
# NUM_SECU_JUI              0.183988
# SEXO_TERC                 0.180219
# ESTAD_VEH_ASEG            0.174327
# FECHA_MODI_EXP            0.145333
# FECHA_RESERVA             0.134497
# FECHA_VIG_ORIG_POL        0.078532
# NEGOCIACION               0.045323
# NOMBRE_ASEG               0.032917
# ESTADO_CIVIL              0.010492
# COD_AGENCIA_SOLIC         0.009632
# FECHA_NAC_ASEG            0.007521
# USER_CAT_DEN              0.002259
# CHASIS                    0.002054
# MOTOR                     0.001548
# OCUPACION_ASEG            0.001477
# APELLIDO_ASEG             0.000221
# RECHAZO                   0.000200
# LUGAR_OCURRENCIA          0.000170
# USER_INICIAL              0.000087
# PATENTE                   0.000055
# MODELO_VEHICULO           0.000055
# DESCRIPCION_VEHICULO      0.000055
# CODIGO_VEHICULO           0.000055
# SEXO                      0.000053
# USER_CAT_EXP              0.000040
# TIPO_RC                   0.000006
# USER_SINI                 0.000002
# USER_APER_SINI            0.000002
# COD_CIA                   0.000000
# NUM_SINI                  0.000000
# COD_AGEN_EMI              0.000000
# COD_SECC                  0.000000
# NUM_SECU_EXPED            0.000000
# COD_RAMO                  0.000000
# TIPO_SUCURSAL             0.000000
# NUM_SECU_SINI             0.000000
# COD_AGENCIA               0.000000
# IMPORTE_NETO_PESOS        0.000000
# COD_CAUSA_SINI            0.000000
# TIPO_EXPED                0.000000
# IMPORTE_REASEG            0.000000
# IMPORTE_COASEG            0.000000
# IMPORTE_LIQUIDADO         0.000000
# COD_CONCEP_RVA            0.000000
# IMPORTE_RESERVA           0.000000
# COD_MON                   0.000000
# NRO_EXPED                 0.000000
# IMPORTE_NETO              0.000000
# FEC_DENU_SINI             0.000000
# FECHA_SINI                0.000000
# COD_RIES                  0.000000
# FECHA_VIG_POL_HASTA       0.000000
# FECHA_VIG_POL_DESDE       0.000000
# NUM_POL1                  0.000000
# CATASTROFICO              0.000000
# STATUS                    0.000000
# TIPO                      0.000000
# DANOS_MATERIALES          0.000000
# NOMBRE_CONDUCTOR          0.000000
# TIPO_DOCUM_COND           0.000000
# NRO_DOCUM_COND            0.000000
# RESERVA_INICIAL           0.000000
# RESERVA_FORMAL            0.000000
# RESERVA_CIERRE            0.000000
# RESERVA_JUDICIAL          0.000000
# TIPO_DENUNCIA             0.000000
# TOTAL_EXPED_003           0.000000
# TIPO_DOCUM_ASEG           0.000000
# NRO_DOCUM_ASEG            0.000000
# OFRECIMIENTO              0.000000
# DESCRIPCION_TIPO          0.000000
# USER_APER_EXP             0.000000
# COD_PRODUCTOR             0.000000
# NOM_PRODUCTOR             0.000000
# NRO_ORDEN_EXP             0.000000
# MCA_VIP                   0.000000
# REPOSICION                0.000000
# IMP_FRANQUICIA_POLIZA     0.000000
# COD_DOCUM_TOM             0.000000
# NRO_DOCUMTO_TOM           0.000000
# COD_POST_POLIZA           0.000000
# METRO                     0.000000
# IMP_VALOR_PRESU_EXP10     0.000000
# FECHA_PROCESO             0.000000
# OTROS_ED                  0.000000
# COD_AGEN_TRAMI            0.000000
# USO                       0.000000
# DESCRIPCION_USO           0.000000
# ALT_COBERTURA             0.000000
# SUMA_ASEG_VEHICULO        0.000000
# SUMA_ASEG_COBERTURA       0.000000
# COD_POST_OCURRENCIA       0.000000
# FUERA_TERRITORIO          0.000000
# TIPO_SINIESTRO            0.000000
# IMP_VALOR_PRESUP          0.000000
# SEGURO                    0.000000
# FALTANTE                  0.000000
# FECHA_RECEPCION           0.000000
# IMPORTE_ADJUDICADO        0.000000
# IMPORTE_DEDUCCIONES       0.000000
# IMPORTE_FRANQUICIA        0.000000
# IMPORTE_PRENDARIO         0.000000
# USER_EXPED                0.000000
# AJUSTE_RESERVA            0.000000
# FECHA_APER_SINI           0.000000
# FECHA_APER_EXP            0.000000
# RESERVA_ANTEPENULTIMA     0.000000
# TOTAL_LIQUIDADO           0.000000
# RESERVA_DENUNCIADO        0.000000
# NUM_SECU_POL              0.000000
# dtype: float64

# %% [markdown]
# *Based on last output, fill this list to mark most relevant columns*

# %%
to_use = [col for col in df.columns if df[col].isna().mean() < 0.7]

# %%
sorted(to_use)
# Out:
# ['AJUSTE_RESERVA',
#  'ALT_COBERTURA',
#  'APELLIDO_ASEG',
#  'APELLIDO_NOMBRE_TERC',
#  'CATASTROFICO',
#  'CHASIS',
#  'CIA_COASEG',
#  'CODIGO_CARATULA',
#  'CODIGO_VEHICULO',
#  'COD_AGENCIA',
#  'COD_AGENCIA_SOLIC',
#  'COD_AGEN_EMI',
#  'COD_AGEN_TRAMI',
#  'COD_CAUSA_SINI',
#  'COD_CIA',
#  'COD_COBERTURA',
#  'COD_CONCEP_RVA',
#  'COD_DOCUM_TOM',
#  'COD_INICIADOR',
#  'COD_MON',
#  'COD_POST_OCURRENCIA',
#  'COD_POST_POLIZA',
#  'COD_POST_TERC',
#  'COD_PRODUCTOR',
#  'COD_RAMO',
#  'COD_RIES',
#  'COD_SECC',
#  'COLOR',
#  'DANOS_MATERIALES',
#  'DESCRIPCION_TIPO',
#  'DESCRIPCION_USO',
#  'DESCRIPCION_VEHICULO',
#  'DOMICILIO_TERC',
#  'ESTADO_CIVIL',
#  'ESTADO_CIVIL_TERC',
#  'ESTAD_VEH_ASEG',
#  'FALTANTE',
#  'FECHA_APER_EXP',
#  'FECHA_APER_SINI',
#  'FECHA_ENTREGA',
#  'FECHA_FORMAL',
#  'FECHA_INSTAL_EQUIPO',
#  'FECHA_JUDICIAL',
#  'FECHA_MODI_EXP',
#  'FECHA_MODI_SINI',
#  'FECHA_NAC_ASEG',
#  'FECHA_NAC_TERC',
#  'FECHA_PASE_FORMAL',
#  'FECHA_PROCESO',
#  'FECHA_RECEPCION',
#  'FECHA_RESERVA',
#  'FECHA_SINI',
#  'FECHA_VIG_ORIG_POL',
#  'FECHA_VIG_POL_DESDE',
#  'FECHA_VIG_POL_HASTA',
#  'FEC_DENU_SINI',
#  'FIN_INVESTIGACION',
#  'FORMAL',
#  'FUERA_TERRITORIO',
#  'IMPORTE_ADJUDICADO',
#  'IMPORTE_COASEG',
#  'IMPORTE_DEDUCCIONES',
#  'IMPORTE_FRANQUICIA',
#  'IMPORTE_LIQUIDADO',
#  'IMPORTE_NETO',
#  'IMPORTE_NETO_PESOS',
#  'IMPORTE_PRENDARIO',
#  'IMPORTE_REASEG',
#  'IMPORTE_RESERVA',
#  'IMP_FRANQUICIA_POLIZA',
#  'IMP_VALOR_PRESUP',
#  'IMP_VALOR_PRESU_EXP10',
#  'INSPECTOR',
#  'JEFE_EQUIPO',
#  'KM_REC_AL_ASEGURAR',
#  'LUGAR_OCURRENCIA',
#  'MCA_JUICIO',
#  'MCA_VIP',
#  'METRO',
#  'MODELO_EQUIPO',
#  'MODELO_VEHICULO',
#  'MOTOR',
#  'NEGOCIACION',
#  'NOMBRE_ASEG',
#  'NOMBRE_CONDUCTOR',
#  'NOM_PRODUCTOR',
#  'NRO_DOCUMENTO_TERC',
#  'NRO_DOCUMTO_TOM',
#  'NRO_DOCUM_ASEG',
#  'NRO_DOCUM_COND',
#  'NRO_EQUIPO',
#  'NRO_EQUIPO_RECUP',
#  'NRO_EXPED',
#  'NRO_ORDEN_EXP',
#  'NUM_POL1',
#  'NUM_SECU_EXPED',
#  'NUM_SECU_JUI',
#  'NUM_SECU_POL',
#  'NUM_SECU_SINI',
#  'NUM_SINI',
#  'OCUPACION_ASEG',
#  'OFRECIMIENTO',
#  'OTROS_ED',
#  'PATENTE',
#  'RAJ',
#  'RECHAZO',
#  'RECLAMO_EXTRAJUD',
#  'REPOSICION',
#  'RESERVA_ANTEPENULTIMA',
#  'RESERVA_CIERRE',
#  'RESERVA_DENUNCIADO',
#  'RESERVA_FORMAL',
#  'RESERVA_INICIAL',
#  'RESERVA_JUDICIAL',
#  'RESOLUCION',
#  'SEGURO',
#  'SEXO',
#  'SEXO_TERC',
#  'STATUS',
#  'SUMA_ASEG_COBERTURA',
#  'SUMA_ASEG_VEHICULO',
#  'TIPO',
#  'TIPO_DENUNCIA',
#  'TIPO_DOCUMENTO_TERC',
#  'TIPO_DOCUM_ASEG',
#  'TIPO_DOCUM_COND',
#  'TIPO_EXPED',
#  'TIPO_LESION',
#  'TIPO_LESION_MAXIMA',
#  'TIPO_RC',
#  'TIPO_SINIESTRO',
#  'TIPO_SUCURSAL',
#  'TOTAL_EXPED_003',
#  'TOTAL_LIQUIDADO',
#  'USER_APER_EXP',
#  'USER_APER_SINI',
#  'USER_CAT_DEN',
#  'USER_CAT_EXP',
#  'USER_EXPED',
#  'USER_FORMAL',
#  'USER_INICIAL',
#  'USER_JUDICIAL',
#  'USER_JUI',
#  'USER_SINI',
#  'USO']

# %% [markdown]
# ### Now write the file

# %% [markdown]
# **If it was a big file, read it completely with this line**

# %%
chunks = pd.read_csv(f"{location}/{table}",
                         sep=sep,
                         encoding=encoding,
                         decimal=decimal,
                         chunksize=1000000)
df = pd.concat(chunks)
# Out:
# /home/voolkia/anaconda3/envs/test/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (44,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/voolkia/anaconda3/envs/test/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
f = open(f'../../docs/{table} feature description.csv','w')
f.write('Column;Used;Null Rate; Type; Unique values; Values\n')
for column in df.columns:
    
    null_rate = round(df[column].isna().mean()*100,2)
    
    unique_vals = df[column].nunique()
    
    if (column in to_use) and null_rate < .5 and unique_vals > 1:
        used = 'X'
    else:
        used=''
    
    dtype = df[column].dtype
    
    if(dtype == 'object'):
        values = f"Top 10:\n{df[column].value_counts(dropna=False).head(10).to_string()}"
    else:
        values = f'[{df[column].min()};{df[column].max()}]'
        
    f.write(f'{column};{used};{null_rate};{dtype};{unique_vals};"{values}"\n')
    
f.close()
